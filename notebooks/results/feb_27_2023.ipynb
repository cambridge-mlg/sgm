# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
# figure size in inches
rcParams['figure.figsize'] = 12.,8.

import seaborn as sns
import pandas as pd
import wandb

pd.set_option('display.max_columns', None)

# %%
api = wandb.Api()
entity, project = "invariance-learners", "neurips2023"  # set to your entity and project 
runs = api.runs(entity + "/" + project)

# %%
summary_list, config_list, name_list, tags, ids, states = [], [], [], [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append(
        {k: v for k,v in run.config.items()
         if not k.startswith('_')})

    # .name is the human-readable name of the run.
    name_list.append(run.name)

    tags.append(run.tags)

    ids.append(run.id)

    states.append(run.state)

runs_df = pd.DataFrame({
    "summary": summary_list,
    "config": config_list,
    "name": name_list,
    "tags": tags,
    "id": ids,
    "state": states
    })

runs_df
# Out:
#                                                summary  \
# 0    {'_wandb': {'runtime': 505}, '_timestamp': 167...
# 1    {'best_val_z_kld': 101.93466186523438, 'val/lo...
# 2    {'best_val_z_kld': 102.8647689819336, 'val_rec...
# 3    {'_step': 7500, '_runtime': 501, 'val/loss': -...
# 4    {'best_val_z_kld': 102.6212921142578, 'val_rec...
# ..                                                 ...
# 340  {'train/z_kld': 526.81494140625, 'best_val_z_k...
# 341  {'train/ll': -782.53271484375, 'train/elbo': -...
# 342  {'learing_rate': 0.00010000000474974512, 'α': ...
# 343  {'_wandb': {'runtime': 557}, '_runtime': 554, ...
# 344  {'train/elbo': 761.5187377929688, 'train/loss'...
#
#                                                 config                 name  \
# 0    {'α': 1, 'β': 10, 'seed': 2, 'model': {'X_give...   hopeful-yogurt-347
# 1    {'α': 1, 'β': 10, 'seed': 0, 'model': {'X_give...    ethereal-bird-346
# 2    {'α': 1, 'β': 10, 'seed': 1, 'model': {'X_give...    youthful-wave-343
# 3    {'α': 1, 'β': 10, 'seed': 1, 'model': {'X_give...   helpful-cosmos-344
# 4    {'α': 1, 'β': 10, 'seed': 2, 'model': {'X_give...  dazzling-galaxy-345
# ..                                                 ...                  ...
# 340  {'α': 0.01, 'β': 10, 'seed': 1, 'model': {'bou...       grateful-sun-5
# 341  {'α': 0.01, 'β': 10, 'seed': 0, 'model': {'bou...    fluent-capybara-4
# 342  {'α': 0.01, 'β': 10, 'seed': 0, 'model': {'bou...       noble-valley-3
# 343  {'α': 1, 'β': 10, 'seed': 0, 'model': {'bounds...           icy-dust-2
# 344  {'α': 1, 'β': 10, 'seed': 0, 'model': {'X_give...     kind-firebrand-1
#
#                               tags        id     state
# 0    [angle_sweep, general_affine]  uv7n5gvf  finished
# 1    [angle_sweep, general_affine]  2cvy6tkr  finished
# 2    [angle_sweep, general_affine]  3tz39f01  finished
# 3    [angle_sweep, general_affine]  2k44fdvl  finished
# 4    [angle_sweep, general_affine]  201liy1d  finished
# ..                             ...       ...       ...
# 340                  [angle_sweep]  gwiipzi6  finished
# 341                  [angle_sweep]  3inf1q5s  finished
# 342                         [test]  12c84lhk  finished
# 343                         [test]  de7swj7f  finished
# 344                         [test]  1jdw5hev  finished
#
# [345 rows x 6 columns]

# %%
df_expanded = runs_df.join(pd.json_normalize(runs_df['summary'], record_prefix='summary.').add_prefix('summary.')).drop('summary', axis='columns')
df_expanded = df_expanded.join(pd.json_normalize(runs_df['config'], record_prefix='config').add_prefix('config.')).drop('config', axis='columns')

df_expanded.columns
# Out:
# Index(['name', 'tags', 'id', 'state', 'summary._timestamp',
#        'summary.train/z_kld', 'summary.best_val_z_kld', 'summary.β',
#        'summary.train/ll', 'summary.best_val_ll', 'summary.train/elbo',
#        'summary.train/loss', 'summary.learing_rate', 'summary.best_val_loss',
#        'summary.α', 'summary.val/ll', 'summary.val/elbo', 'summary.val/z_kld',
#        'summary.best_val_step', 'summary._step', 'summary._runtime',
#        'summary.val/loss', 'summary.best_val_elbo', 'summary._wandb.runtime',
#        'summary.prior_samples.path', 'summary.prior_samples.size',
#        'summary.prior_samples._type', 'summary.prior_samples.width',
#        'summary.prior_samples.format', 'summary.prior_samples.height',
#        'summary.prior_samples.sha256', 'summary.best_prior_samples._type',
#        'summary.best_prior_samples.width', 'summary.best_prior_samples.format',
#        'summary.best_prior_samples.height',
#        'summary.best_prior_samples.sha256', 'summary.best_prior_samples.path',
#        'summary.best_prior_samples.size', 'summary.val_reconstructions.size',
#        'summary.val_reconstructions._type',
#        'summary.val_reconstructions.width',
#        'summary.val_reconstructions.format',
#        'summary.val_reconstructions.height',
#        'summary.val_reconstructions.sha256',
#        'summary.val_reconstructions.path', 'summary.val/η_kld',
#        'summary.best_val_η_kld', 'summary.train/η_kld', 'config.α', 'config.β',
#        'config.seed', 'config.dataset', 'config.pp_eval', 'config.pp_train',
#        'config.val_split', 'config.batch_size', 'config.eval_every',
#        'config.model_name', 'config.optim_name', 'config.total_steps',
#        'config.train_split', 'config.learning_rate', 'config.lr_schedule_name',
#        'config.β_schedule_name', 'config.repeat_after_batch',
#        'config.data_rotation_angle', 'config.shuffle_buffer_size',
#        'config.model.X_given_Z.hidden_dims',
#        'config.model.Z_given_X.hidden_dims', 'config.model.latent_dim',
#        'config.optim.weight_decay', 'config.lr_schedule.end_value',
#        'config.lr_schedule.peak_value', 'config.lr_schedule.decay_steps',
#        'config.lr_schedule.warmup_steps', 'config.β_schedule.alpha',
#        'config.β_schedule.decay_steps', 'config.α_schedule_name',
#        'config.model.bounds', 'config.model.Eta_given_X.base.hidden_dims',
#        'config.model.Eta_given_X.bijector.num_bins',
#        'config.model.Eta_given_X.bijector.num_layers',
#        'config.model.Eta_given_X.bijector.hidden_dims',
#        'config.model.Eta_given_Z.base.hidden_dims',
#        'config.model.Eta_given_Z.bijector.num_bins',
#        'config.model.Eta_given_Z.bijector.num_layers',
#        'config.model.Eta_given_Z.bijector.hidden_dims',
#        'config.model.Xhat_given_Z.hidden_dims', 'config.α_schedule.alpha',
#        'config.α_schedule.decay_steps', 'config.model.Eta.base.hidden_dims',
#        'config.model.Eta.bijector.num_bins',
#        'config.model.Eta.bijector.num_layers',
#        'config.model.Eta.bijector.hidden_dims'],
#       dtype='object')

# %%
df_expanded
# Out:
#                     name                           tags        id     state  \
# 0     hopeful-yogurt-347  [angle_sweep, general_affine]  uv7n5gvf  finished
# 1      ethereal-bird-346  [angle_sweep, general_affine]  2cvy6tkr  finished
# 2      youthful-wave-343  [angle_sweep, general_affine]  3tz39f01  finished
# 3     helpful-cosmos-344  [angle_sweep, general_affine]  2k44fdvl  finished
# 4    dazzling-galaxy-345  [angle_sweep, general_affine]  201liy1d  finished
# ..                   ...                            ...       ...       ...
# 340       grateful-sun-5                  [angle_sweep]  gwiipzi6  finished
# 341    fluent-capybara-4                  [angle_sweep]  3inf1q5s  finished
# 342       noble-valley-3                         [test]  12c84lhk  finished
# 343           icy-dust-2                         [test]  de7swj7f  finished
# 344     kind-firebrand-1                         [test]  1jdw5hev  finished
#
#      summary._timestamp  summary.train/z_kld  summary.best_val_z_kld  \
# 0          1.677509e+09            96.399849               99.174843
# 1          1.677509e+09            99.082245              101.934662
# 2          1.677509e+09            99.475815              102.864769
# 3          1.677509e+09            77.914001               81.209373
# 4          1.677509e+09            99.734482              102.621292
# ..                  ...                  ...                     ...
# 340        1.677449e+09           526.814941              539.534302
# 341        1.677449e+09             8.685968                9.571937
# 342        1.677448e+09             3.480256                4.275969
# 343        1.677447e+09             4.075250                8.255915
# 344        1.677447e+09            75.629097               77.215858
#
#      summary.β  summary.train/ll  summary.best_val_ll  summary.train/elbo  \
# 0          1.0       1062.775635          1084.388062          966.375549
# 1          1.0       1027.590942          1052.156006          928.508545
# 2          1.0       1035.083496          1053.965820          935.607544
# 3          1.0        798.582642           812.537720          720.668457
# 4          1.0       1021.007751          1040.380615          921.273132
# ..         ...               ...                  ...                 ...
# 340        1.0       -798.290405          -818.157227        -1335.151611
# 341        1.0       -782.532715          -801.015686         -791.334106
# 342        1.0       -791.790710          -810.712524         -797.427429
# 343        1.0         75.876900            92.409081           71.801643
# 344        1.0        837.147888           847.516724          761.518738
#
#      summary.train/loss  summary.learing_rate  summary.best_val_loss  \
# 0           -966.375549                0.0001            -985.213257
# 1           -928.508545                0.0001            -950.221252
# 2           -935.607544                0.0001            -951.101135
# 3           -720.668457                0.0001            -731.328308
# 4           -921.273132                0.0001            -937.759216
# ..                  ...                   ...                    ...
# 340         1335.151611                0.0001            1367.834717
# 341          791.334106                0.0001             811.580200
# 342          797.427429                0.0001             818.379822
# 343          -71.801643                0.0001             -84.153160
# 344         -761.518738                0.0001            -770.300781
#
#      summary.α  summary.val/ll  summary.val/elbo  summary.val/z_kld  \
# 0          1.0     1084.388062        985.213257          99.174843
# 1          1.0     1052.156006        950.221252         101.934662
# 2          1.0     1053.965820        951.101135         102.864769
# 3          1.0      812.537720        731.328308          81.209373
# 4          1.0     1040.380615        937.759216         102.621292
# ..         ...             ...               ...                ...
# 340        1.0     -818.157227      -1367.834717         539.534302
# 341        1.0     -801.015686       -811.580200           9.571937
# 342        1.0     -810.712524       -818.379822           4.275969
# 343        1.0       92.409081         84.153160           8.255915
# 344        1.0      847.516724        770.300781          77.215858
#
#      summary.best_val_step  summary._step  summary._runtime  summary.val/loss  \
# 0                   7500.0         7500.0             504.0       -985.213257
# 1                   7500.0         7500.0             504.0       -950.221252
# 2                   7500.0         7500.0             503.0       -951.101135
# 3                   7500.0         7500.0             501.0       -731.328308
# 4                   7500.0         7500.0             504.0       -937.759216
# ..                     ...            ...               ...               ...
# 340                 7500.0         7500.0            1082.0       1367.834717
# 341                 7500.0         7500.0            1092.0        811.580200
# 342                 7500.0         7500.0             743.0        818.379822
# 343                 7500.0         7500.0             554.0        -84.153160
# 344                 7500.0         7500.0             355.0       -770.300781
#
#      summary.best_val_elbo  summary._wandb.runtime  \
# 0               985.213257                     505
# 1               950.221252                     506
# 2               951.101135                     505
# 3               731.328308                     503
# 4               937.759216                     506
# ..                     ...                     ...
# 340           -1367.834717                    1085
# 341            -811.580200                    1096
# 342            -818.379822                     746
# 343              84.153160                     557
# 344             770.300781                     357
#
#                             summary.prior_samples.path  \
# 0    media/images/prior_samples_7500_a60ee450c455b1...
# 1    media/images/prior_samples_7500_a8e418c14edf47...
# 2    media/images/prior_samples_7500_60ed53aab47521...
# 3    media/images/prior_samples_7500_3990419dc4b70f...
# 4    media/images/prior_samples_7500_0a44b3027394e9...
# ..                                                 ...
# 340  media/images/prior_samples_7500_c43bb4025b8ea7...
# 341  media/images/prior_samples_7500_8c0d3b91ca4585...
# 342  media/images/prior_samples_7500_3b9462fc35af0a...
# 343  media/images/prior_samples_7500_d5547146dddb7e...
# 344  media/images/prior_samples_7500_bf1b5420ca5a29...
#
#      summary.prior_samples.size summary.prior_samples._type  \
# 0                      123091.0                  image-file
# 1                      124439.0                  image-file
# 2                      123813.0                  image-file
# 3                      126715.0                  image-file
# 4                      124239.0                  image-file
# ..                          ...                         ...
# 340                    263249.0                  image-file
# 341                    251553.0                  image-file
# 342                    249770.0                  image-file
# 343                    135567.0                  image-file
# 344                    125938.0                  image-file
#
#      summary.prior_samples.width summary.prior_samples.format  \
# 0                        19200.0                          png
# 1                        19200.0                          png
# 2                        19200.0                          png
# 3                        19200.0                          png
# 4                        19200.0                          png
# ..                           ...                          ...
# 340                      19200.0                          png
# 341                      19200.0                          png
# 342                      19200.0                          png
# 343                      19200.0                          png
# 344                      19200.0                          png
#
#      summary.prior_samples.height  \
# 0                           800.0
# 1                           800.0
# 2                           800.0
# 3                           800.0
# 4                           800.0
# ..                            ...
# 340                        1600.0
# 341                        1600.0
# 342                        1600.0
# 343                         800.0
# 344                         800.0
#
#                           summary.prior_samples.sha256  \
# 0    a60ee450c455b1743d70cabb2259a2daf6acc726819653...
# 1    a8e418c14edf478a87a2cbe176d989724494658aa844b0...
# 2    60ed53aab475211f0b9d650f926e081177e8c514512b60...
# 3    3990419dc4b70fa4a95443832c4e41ebcf44d407294b22...
# 4    0a44b3027394e93f404c42f7ca01ecb60b031e433c04a7...
# ..                                                 ...
# 340  c43bb4025b8ea7f1d14ce71bf26c33e32457051d42c474...
# 341  8c0d3b91ca45853663ee4b5783826719ed2caa10b03ec7...
# 342  3b9462fc35af0a832fbdd8137aff9df08f50edd8764e19...
# 343  d5547146dddb7e59b1055cd8a5664665535e3703b7acd7...
# 344  bf1b5420ca5a29e9013f2f1041846e25996bc5ca1763a8...
#
#     summary.best_prior_samples._type  summary.best_prior_samples.width  \
# 0                         image-file                           19200.0
# 1                         image-file                           19200.0
# 2                         image-file                           19200.0
# 3                         image-file                           19200.0
# 4                         image-file                           19200.0
# ..                               ...                               ...
# 340                       image-file                           19200.0
# 341                       image-file                           19200.0
# 342                       image-file                           19200.0
# 343                       image-file                           19200.0
# 344                       image-file                           19200.0
#
#     summary.best_prior_samples.format  summary.best_prior_samples.height  \
# 0                                 png                              800.0
# 1                                 png                              800.0
# 2                                 png                              800.0
# 3                                 png                              800.0
# 4                                 png                              800.0
# ..                                ...                                ...
# 340                               png                             1600.0
# 341                               png                             1600.0
# 342                               png                             1600.0
# 343                               png                              800.0
# 344                               png                              800.0
#
#                      summary.best_prior_samples.sha256  \
# 0    a60ee450c455b1743d70cabb2259a2daf6acc726819653...
# 1    a8e418c14edf478a87a2cbe176d989724494658aa844b0...
# 2    60ed53aab475211f0b9d650f926e081177e8c514512b60...
# 3    3990419dc4b70fa4a95443832c4e41ebcf44d407294b22...
# 4    0a44b3027394e93f404c42f7ca01ecb60b031e433c04a7...
# ..                                                 ...
# 340  c43bb4025b8ea7f1d14ce71bf26c33e32457051d42c474...
# 341  8c0d3b91ca45853663ee4b5783826719ed2caa10b03ec7...
# 342  3b9462fc35af0a832fbdd8137aff9df08f50edd8764e19...
# 343  d5547146dddb7e59b1055cd8a5664665535e3703b7acd7...
# 344  bf1b5420ca5a29e9013f2f1041846e25996bc5ca1763a8...
#
#                        summary.best_prior_samples.path  \
# 0    media/images/best_prior_samples_summary_a60ee4...
# 1    media/images/best_prior_samples_summary_a8e418...
# 2    media/images/best_prior_samples_summary_60ed53...
# 3    media/images/best_prior_samples_summary_399041...
# 4    media/images/best_prior_samples_summary_0a44b3...
# ..                                                 ...
# 340  media/images/best_prior_samples_summary_c43bb4...
# 341  media/images/best_prior_samples_summary_8c0d3b...
# 342  media/images/best_prior_samples_summary_3b9462...
# 343  media/images/best_prior_samples_summary_d55471...
# 344  media/images/best_prior_samples_summary_bf1b54...
#
#      summary.best_prior_samples.size  summary.val_reconstructions.size  \
# 0                           123091.0                          214629.0
# 1                           124439.0                          214785.0
# 2                           123813.0                          214596.0
# 3                           126715.0                          217185.0
# 4                           124239.0                          214934.0
# ..                               ...                               ...
# 340                         263249.0                          287762.0
# 341                         251553.0                          295291.0
# 342                         249770.0                          287208.0
# 343                         135567.0                          225958.0
# 344                         125938.0                          216979.0
#
#     summary.val_reconstructions._type  summary.val_reconstructions.width  \
# 0                          image-file                            19200.0
# 1                          image-file                            19200.0
# 2                          image-file                            19200.0
# 3                          image-file                            19200.0
# 4                          image-file                            19200.0
# ..                                ...                                ...
# 340                        image-file                            19200.0
# 341                        image-file                            19200.0
# 342                        image-file                            19200.0
# 343                        image-file                            19200.0
# 344                        image-file                            19200.0
#
#     summary.val_reconstructions.format  summary.val_reconstructions.height  \
# 0                                  png                              1600.0
# 1                                  png                              1600.0
# 2                                  png                              1600.0
# 3                                  png                              1600.0
# 4                                  png                              1600.0
# ..                                 ...                                 ...
# 340                                png                              2400.0
# 341                                png                              2400.0
# 342                                png                              2400.0
# 343                                png                              1600.0
# 344                                png                              1600.0
#
#                     summary.val_reconstructions.sha256  \
# 0    a8b91fedca696e4d1d809dcc5fec281e4bc83623db8b4e...
# 1    ca8c9b84a53ba431d70449a64876c6a65492dcc85108c6...
# 2    7ae54a2857b60729a6bc6cf0337633dad937b955d3586d...
# 3    34d9115ce449848d1ebd044a99d7ab276a8e78eb5346f6...
# 4    d1bd8042384ee2053213cddcb088f3f6a11cbe66210618...
# ..                                                 ...
# 340  d6b1c584c79cd4c4ed512b5b272abe23913392f0aff966...
# 341  2984802042b11241fc328cfa5dc03f76919d9dedc357e4...
# 342  6374ad7cfd2ee7c1d976526cea7b14db35fafddc61aa6e...
# 343  b67d56a7800c2cdf3720d1e2fbbce87c81983b41695726...
# 344  d56578677e08e4e8a931b107568fe6d664c97dd5f9149b...
#
#                       summary.val_reconstructions.path  summary.val/η_kld  \
# 0    media/images/val_reconstructions_7500_a8b91fed...                NaN
# 1    media/images/val_reconstructions_7500_ca8c9b84...                NaN
# 2    media/images/val_reconstructions_7500_7ae54a28...                NaN
# 3    media/images/val_reconstructions_7500_34d9115c...                NaN
# 4    media/images/val_reconstructions_7500_d1bd8042...                NaN
# ..                                                 ...                ...
# 340  media/images/val_reconstructions_7500_d6b1c584...          10.142779
# 341  media/images/val_reconstructions_7500_29848020...           0.992614
# 342  media/images/val_reconstructions_7500_6374ad7c...           3.391399
# 343  media/images/val_reconstructions_7500_b67d56a7...                NaN
# 344  media/images/val_reconstructions_7500_d5657867...                NaN
#
#      summary.best_val_η_kld  summary.train/η_kld  config.α  config.β  \
# 0                       NaN                  NaN      1.00        10
# 1                       NaN                  NaN      1.00        10
# 2                       NaN                  NaN      1.00        10
# 3                       NaN                  NaN      1.00        10
# 4                       NaN                  NaN      1.00        10
# ..                      ...                  ...       ...       ...
# 340               10.142779            10.045321      0.01        10
# 341                0.992614             0.115446      0.01        10
# 342                3.391399             2.156468      0.01        10
# 343                     NaN                  NaN      1.00        10
# 344                     NaN                  NaN      1.00        10
#
#      config.seed config.dataset  \
# 0              2          MNIST
# 1              0          MNIST
# 2              1          MNIST
# 3              1          MNIST
# 4              2          MNIST
# ..           ...            ...
# 340            1          MNIST
# 341            0          MNIST
# 342            0          MNIST
# 343            0          MNIST
# 344            0          MNIST
#
#                                         config.pp_eval  \
# 0    value_range(-1, 1)|random_rotate(-90, 90, fill...
# 1    value_range(-1, 1)|random_rotate(-180, 180, fi...
# 2    value_range(-1, 1)|random_rotate(-180, 180, fi...
# 3    value_range(-1, 1)|random_rotate(-90, 90, fill...
# 4    value_range(-1, 1)|random_rotate(-180, 180, fi...
# ..                                                 ...
# 340  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 341  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 342  value_range(-1, 1)|random_rotate(-45, 45, fill...
# 343  value_range(-1, 1)|random_rotate(-45, 45, fill...
# 344  value_range(-1, 1)|random_rotate(-45, 45, fill...
#
#                                        config.pp_train config.val_split  \
# 0    value_range(-1, 1)|random_rotate(-90, 90, fill...    train[:10000]
# 1    value_range(-1, 1)|random_rotate(-180, 180, fi...    train[:10000]
# 2    value_range(-1, 1)|random_rotate(-180, 180, fi...    train[:10000]
# 3    value_range(-1, 1)|random_rotate(-90, 90, fill...    train[:10000]
# 4    value_range(-1, 1)|random_rotate(-180, 180, fi...    train[:10000]
# ..                                                 ...              ...
# 340  value_range(-1, 1)|random_rotate(-0, 0, fill_v...    train[:10000]
# 341  value_range(-1, 1)|random_rotate(-0, 0, fill_v...    train[:10000]
# 342  value_range(-1, 1)|random_rotate(-45, 45, fill...    train[:10000]
# 343  value_range(-1, 1)|random_rotate(-45, 45, fill...    train[:10000]
# 344  value_range(-1, 1)|random_rotate(-45, 45, fill...    train[:10000]
#
#      config.batch_size  config.eval_every config.model_name config.optim_name  \
# 0                  512                500               VAE             adamw
# 1                  512                500               VAE             adamw
# 2                  512                500               VAE             adamw
# 3                  512                500               VAE             adamw
# 4                  512                500               VAE             adamw
# ..                 ...                ...               ...               ...
# 340                512                500             LIVAE             adamw
# 341                512                500             LIVAE             adamw
# 342                256                500             LIVAE             adamw
# 343                256                500              IVAE             adamw
# 344                256                500               VAE             adamw
#
#      config.total_steps config.train_split  config.learning_rate  \
# 0                  7501      train[10000:]                0.0001
# 1                  7501      train[10000:]                0.0001
# 2                  7501      train[10000:]                0.0001
# 3                  7501      train[10000:]                0.0001
# 4                  7501      train[10000:]                0.0001
# ..                  ...                ...                   ...
# 340                7501      train[10000:]                0.0001
# 341                7501      train[10000:]                0.0001
# 342                7501      train[10000:]                0.0001
# 343                7501      train[10000:]                0.0001
# 344                7501      train[10000:]                0.0001
#
#           config.lr_schedule_name config.β_schedule_name  \
# 0    warmup_cosine_decay_schedule  cosine_decay_schedule
# 1    warmup_cosine_decay_schedule  cosine_decay_schedule
# 2    warmup_cosine_decay_schedule  cosine_decay_schedule
# 3    warmup_cosine_decay_schedule  cosine_decay_schedule
# 4    warmup_cosine_decay_schedule  cosine_decay_schedule
# ..                            ...                    ...
# 340  warmup_cosine_decay_schedule  cosine_decay_schedule
# 341  warmup_cosine_decay_schedule  cosine_decay_schedule
# 342  warmup_cosine_decay_schedule  cosine_decay_schedule
# 343  warmup_cosine_decay_schedule  cosine_decay_schedule
# 344  warmup_cosine_decay_schedule  cosine_decay_schedule
#
#      config.repeat_after_batch config.data_rotation_angle  \
# 0                         True                         90
# 1                         True                        180
# 2                         True                        180
# 3                         True                         90
# 4                         True                        180
# ..                         ...                        ...
# 340                       True                        NaN
# 341                       True                        NaN
# 342                       True                        NaN
# 343                       True                        NaN
# 344                       True                        NaN
#
#      config.shuffle_buffer_size config.model.X_given_Z.hidden_dims  \
# 0                         50000                     [256, 128, 64]
# 1                         50000                     [256, 128, 64]
# 2                         50000                     [256, 128, 64]
# 3                         50000                     [256, 128, 64]
# 4                         50000                     [256, 128, 64]
# ..                          ...                                ...
# 340                       50000                                NaN
# 341                       50000                                NaN
# 342                       50000                                NaN
# 343                       50000                     [256, 128, 64]
# 344                       50000                     [256, 128, 64]
#
#     config.model.Z_given_X.hidden_dims  config.model.latent_dim  \
# 0                       [64, 128, 256]                      128
# 1                       [64, 128, 256]                      128
# 2                       [64, 128, 256]                      128
# 3                       [64, 128, 256]                      128
# 4                       [64, 128, 256]                      128
# ..                                 ...                      ...
# 340                     [64, 128, 256]                      128
# 341                     [64, 128, 256]                      128
# 342                     [64, 128, 256]                      128
# 343                     [64, 128, 256]                      128
# 344                     [64, 128, 256]                      128
#
#      config.optim.weight_decay  config.lr_schedule.end_value  \
# 0                       0.0001                        0.0001
# 1                       0.0001                        0.0001
# 2                       0.0001                        0.0001
# 3                       0.0001                        0.0001
# 4                       0.0001                        0.0001
# ..                         ...                           ...
# 340                     0.0001                        0.0001
# 341                     0.0001                        0.0001
# 342                     0.0001                        0.0001
# 343                     0.0001                        0.0001
# 344                     0.0001                        0.0001
#
#      config.lr_schedule.peak_value  config.lr_schedule.decay_steps  \
# 0                            0.001                            7501
# 1                            0.001                            7501
# 2                            0.001                            7501
# 3                            0.001                            7501
# 4                            0.001                            7501
# ..                             ...                             ...
# 340                          0.001                            7501
# 341                          0.001                            7501
# 342                          0.001                            7501
# 343                          0.001                            7501
# 344                          0.001                            7501
#
#      config.lr_schedule.warmup_steps  config.β_schedule.alpha  \
# 0                               1000                      0.1
# 1                               1000                      0.1
# 2                               1000                      0.1
# 3                               1000                      0.1
# 4                               1000                      0.1
# ..                               ...                      ...
# 340                             1000                      0.1
# 341                             1000                      0.1
# 342                             1000                      0.1
# 343                             1000                      0.1
# 344                             1000                      0.1
#
#      config.β_schedule.decay_steps config.α_schedule_name  \
# 0                             7501                    NaN
# 1                             7501                    NaN
# 2                             7501                    NaN
# 3                             7501                    NaN
# 4                             7501                    NaN
# ..                             ...                    ...
# 340                           7501  cosine_decay_schedule
# 341                           7501  cosine_decay_schedule
# 342                           7501  cosine_decay_schedule
# 343                           7501                    NaN
# 344                           7501                    NaN
#
#                                    config.model.bounds  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 340  [0.25, 0.25, 3.141592653589793, 0.25, 0.25, 0....
# 341  [0.25, 0.25, 3.141592653589793, 0.25, 0.25, 0....
# 342  [0.25, 0.25, 3.141592653589793, 0.25, 0.25, 0....
# 343  [0.25, 0.25, 3.141592653589793, 0.25, 0.25, 0....
# 344                                                NaN
#
#     config.model.Eta_given_X.base.hidden_dims  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 340                                  [64, 32]
# 341                                  [64, 32]
# 342                                  [64, 32]
# 343                                       NaN
# 344                                       NaN
#
#      config.model.Eta_given_X.bijector.num_bins  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 340                                         4.0
# 341                                         4.0
# 342                                         4.0
# 343                                         NaN
# 344                                         NaN
#
#      config.model.Eta_given_X.bijector.num_layers  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 340                                           2.0
# 341                                           2.0
# 342                                           2.0
# 343                                           NaN
# 344                                           NaN
#
#     config.model.Eta_given_X.bijector.hidden_dims  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 340                                      [64, 32]
# 341                                      [64, 32]
# 342                                      [64, 32]
# 343                                           NaN
# 344                                           NaN
#
#     config.model.Eta_given_Z.base.hidden_dims  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 340                                  [64, 32]
# 341                                  [64, 32]
# 342                                  [64, 32]
# 343                                       NaN
# 344                                       NaN
#
#      config.model.Eta_given_Z.bijector.num_bins  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 340                                         4.0
# 341                                         4.0
# 342                                         4.0
# 343                                         NaN
# 344                                         NaN
#
#      config.model.Eta_given_Z.bijector.num_layers  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 340                                           2.0
# 341                                           2.0
# 342                                           2.0
# 343                                           NaN
# 344                                           NaN
#
#     config.model.Eta_given_Z.bijector.hidden_dims  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 340                                      [64, 32]
# 341                                      [64, 32]
# 342                                      [64, 32]
# 343                                           NaN
# 344                                           NaN
#
#     config.model.Xhat_given_Z.hidden_dims  config.α_schedule.alpha  \
# 0                                     NaN                      NaN
# 1                                     NaN                      NaN
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
# ..                                    ...                      ...
# 340                        [256, 128, 64]                    100.0
# 341                        [256, 128, 64]                    100.0
# 342                        [256, 128, 64]                    100.0
# 343                                   NaN                      NaN
# 344                                   NaN                      NaN
#
#      config.α_schedule.decay_steps config.model.Eta.base.hidden_dims  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# ..                             ...                               ...
# 340                         6750.0                               NaN
# 341                         6750.0                               NaN
# 342                         6750.0                               NaN
# 343                            NaN                               NaN
# 344                            NaN                               NaN
#
#      config.model.Eta.bijector.num_bins  config.model.Eta.bijector.num_layers  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
# ..                                  ...                                   ...
# 340                                 NaN                                   NaN
# 341                                 NaN                                   NaN
# 342                                 NaN                                   NaN
# 343                                 NaN                                   NaN
# 344                                 NaN                                   NaN
#
#     config.model.Eta.bijector.hidden_dims
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 340                                   NaN
# 341                                   NaN
# 342                                   NaN
# 343                                   NaN
# 344                                   NaN
#
# [345 rows x 94 columns]

# %%
# take only completed runs
df_filtered = df_expanded[df_expanded['state'] == 'finished']

# take only runs with a certain tag
df_filtered = df_filtered[df_filtered['tags'].apply(lambda x: 'angle_sweep' in x)]

# take onlt runs with the config.data_rotation_angle column
df_filtered = df_filtered[df_filtered['config.data_rotation_angle'].notna()]

# create new column to show if there is a tag called "rotation_only" or a tag called "general_affine"
df_filtered['transformation_type'] = df_filtered['tags'].apply(lambda x: 'rotation_only' if 'rotation_only' in x else ('general_affine' if 'general_affine' in x else 'unknown'))

# convert config.data_rotation_angle to an int
df_filtered['config.data_rotation_angle'] = df_filtered['config.data_rotation_angle'].astype(int)

df_filtered
# Out:
#                     name                           tags        id     state  \
# 0     hopeful-yogurt-347  [angle_sweep, general_affine]  uv7n5gvf  finished
# 1      ethereal-bird-346  [angle_sweep, general_affine]  2cvy6tkr  finished
# 2      youthful-wave-343  [angle_sweep, general_affine]  3tz39f01  finished
# 3     helpful-cosmos-344  [angle_sweep, general_affine]  2k44fdvl  finished
# 4    dazzling-galaxy-345  [angle_sweep, general_affine]  201liy1d  finished
# ..                   ...                            ...       ...       ...
# 211     sandy-galaxy-136  [angle_sweep, general_affine]  1flfqgsy  finished
# 212      amber-paper-137  [angle_sweep, general_affine]  13wn0wxy  finished
# 213    silvery-sound-134  [angle_sweep, general_affine]  jx20ppk6  finished
# 214       clear-snow-133  [angle_sweep, general_affine]  74quop8b  finished
# 215     vivid-flower-132  [angle_sweep, general_affine]  1s0btag7  finished
#
#      summary._timestamp  summary.train/z_kld  summary.best_val_z_kld  \
# 0          1.677509e+09            96.399849               99.174843
# 1          1.677509e+09            99.082245              101.934662
# 2          1.677509e+09            99.475815              102.864769
# 3          1.677509e+09            77.914001               81.209373
# 4          1.677509e+09            99.734482              102.621292
# ..                  ...                  ...                     ...
# 211        1.677503e+09             5.534964                6.267342
# 212        1.677503e+09             4.273073                4.824737
# 213        1.677503e+09             8.179256                9.144926
# 214        1.677503e+09             3.078073                2.907556
# 215        1.677503e+09             8.928679                9.413653
#
#      summary.β  summary.train/ll  summary.best_val_ll  summary.train/elbo  \
# 0          1.0       1062.775635          1084.388062          966.375549
# 1          1.0       1027.590942          1052.156006          928.508545
# 2          1.0       1035.083496          1053.965820          935.607544
# 3          1.0        798.582642           812.537720          720.668457
# 4          1.0       1021.007751          1040.380615          921.273132
# ..         ...               ...                  ...                 ...
# 211        1.0       -787.298462          -805.313782         -792.957703
# 212        1.0       -797.511047          -815.496765         -801.830811
# 213        1.0       -778.924805          -796.830139         -787.773193
# 214        1.0       -822.787476          -818.557861         -825.995728
# 215        1.0       -780.016479          -798.236511         -789.009766
#
#      summary.train/loss  summary.learing_rate  summary.best_val_loss  \
# 0           -966.375549                0.0001            -985.213257
# 1           -928.508545                0.0001            -950.221252
# 2           -935.607544                0.0001            -951.101135
# 3           -720.668457                0.0001            -731.328308
# 4           -921.273132                0.0001            -937.759216
# ..                  ...                   ...                    ...
# 211          792.957703                0.0001             812.172668
# 212          801.830811                0.0001             821.029724
# 213          787.773193                0.0001             808.029358
# 214          825.995728                0.0001             828.974121
# 215          789.009766                0.0001             807.949280
#
#      summary.α  summary.val/ll  summary.val/elbo  summary.val/z_kld  \
# 0          1.0     1084.388062        985.213257          99.174843
# 1          1.0     1052.156006        950.221252         101.934662
# 2          1.0     1053.965820        951.101135         102.864769
# 3          1.0      812.537720        731.328308          81.209373
# 4          1.0     1040.380615        937.759216         102.621292
# ..         ...             ...               ...                ...
# 211        1.0     -805.313782       -812.172668           6.267342
# 212        1.0     -815.496765       -821.029724           4.824737
# 213        1.0     -796.830139       -808.029358           9.144926
# 214        1.0     -839.633118       -843.832642           3.691555
# 215        1.0     -798.236511       -807.949280           9.413653
#
#      summary.best_val_step  summary._step  summary._runtime  summary.val/loss  \
# 0                   7500.0         7500.0             504.0       -985.213257
# 1                   7500.0         7500.0             504.0       -950.221252
# 2                   7500.0         7500.0             503.0       -951.101135
# 3                   7500.0         7500.0             501.0       -731.328308
# 4                   7500.0         7500.0             504.0       -937.759216
# ..                     ...            ...               ...               ...
# 211                 7500.0         7500.0            1095.0        812.172668
# 212                 7500.0         7500.0            1094.0        821.029724
# 213                 7500.0         7500.0            1095.0        808.029358
# 214                 5000.0         7500.0            1081.0        843.832642
# 215                 7500.0         7500.0            1129.0        807.949280
#
#      summary.best_val_elbo  summary._wandb.runtime  \
# 0               985.213257                     505
# 1               950.221252                     506
# 2               951.101135                     505
# 3               731.328308                     503
# 4               937.759216                     506
# ..                     ...                     ...
# 211            -812.172668                    1098
# 212            -821.029724                    1098
# 213            -808.029358                    1099
# 214            -828.974121                    1081
# 215            -807.949280                    1132
#
#                             summary.prior_samples.path  \
# 0    media/images/prior_samples_7500_a60ee450c455b1...
# 1    media/images/prior_samples_7500_a8e418c14edf47...
# 2    media/images/prior_samples_7500_60ed53aab47521...
# 3    media/images/prior_samples_7500_3990419dc4b70f...
# 4    media/images/prior_samples_7500_0a44b3027394e9...
# ..                                                 ...
# 211  media/images/prior_samples_7500_42a0f480f10357...
# 212  media/images/prior_samples_7500_e61b2f28c4286d...
# 213  media/images/prior_samples_7500_4296fe31bbac21...
# 214  media/images/prior_samples_7500_2e91cb012893e5...
# 215  media/images/prior_samples_7500_0340ad58a1f9ad...
#
#      summary.prior_samples.size summary.prior_samples._type  \
# 0                      123091.0                  image-file
# 1                      124439.0                  image-file
# 2                      123813.0                  image-file
# 3                      126715.0                  image-file
# 4                      124239.0                  image-file
# ..                          ...                         ...
# 211                    249961.0                  image-file
# 212                    249702.0                  image-file
# 213                    253463.0                  image-file
# 214                    254705.0                  image-file
# 215                    252429.0                  image-file
#
#      summary.prior_samples.width summary.prior_samples.format  \
# 0                        19200.0                          png
# 1                        19200.0                          png
# 2                        19200.0                          png
# 3                        19200.0                          png
# 4                        19200.0                          png
# ..                           ...                          ...
# 211                      19200.0                          png
# 212                      19200.0                          png
# 213                      19200.0                          png
# 214                      19200.0                          png
# 215                      19200.0                          png
#
#      summary.prior_samples.height  \
# 0                           800.0
# 1                           800.0
# 2                           800.0
# 3                           800.0
# 4                           800.0
# ..                            ...
# 211                        1600.0
# 212                        1600.0
# 213                        1600.0
# 214                        1600.0
# 215                        1600.0
#
#                           summary.prior_samples.sha256  \
# 0    a60ee450c455b1743d70cabb2259a2daf6acc726819653...
# 1    a8e418c14edf478a87a2cbe176d989724494658aa844b0...
# 2    60ed53aab475211f0b9d650f926e081177e8c514512b60...
# 3    3990419dc4b70fa4a95443832c4e41ebcf44d407294b22...
# 4    0a44b3027394e93f404c42f7ca01ecb60b031e433c04a7...
# ..                                                 ...
# 211  42a0f480f103572c8c903fac8ee004910495717ed5c5fa...
# 212  e61b2f28c4286dc5fbe731a29a779c9f278f95794f2402...
# 213  4296fe31bbac21dec354a302d089ff1a1396b27ed52a08...
# 214  2e91cb012893e5760c868285bd8fff7c8ed8b2bdb06391...
# 215  0340ad58a1f9ad53fa857cddb9f30e28a9cd4b5d928915...
#
#     summary.best_prior_samples._type  summary.best_prior_samples.width  \
# 0                         image-file                           19200.0
# 1                         image-file                           19200.0
# 2                         image-file                           19200.0
# 3                         image-file                           19200.0
# 4                         image-file                           19200.0
# ..                               ...                               ...
# 211                       image-file                           19200.0
# 212                       image-file                           19200.0
# 213                       image-file                           19200.0
# 214                       image-file                           19200.0
# 215                       image-file                           19200.0
#
#     summary.best_prior_samples.format  summary.best_prior_samples.height  \
# 0                                 png                              800.0
# 1                                 png                              800.0
# 2                                 png                              800.0
# 3                                 png                              800.0
# 4                                 png                              800.0
# ..                                ...                                ...
# 211                               png                             1600.0
# 212                               png                             1600.0
# 213                               png                             1600.0
# 214                               png                             1600.0
# 215                               png                             1600.0
#
#                      summary.best_prior_samples.sha256  \
# 0    a60ee450c455b1743d70cabb2259a2daf6acc726819653...
# 1    a8e418c14edf478a87a2cbe176d989724494658aa844b0...
# 2    60ed53aab475211f0b9d650f926e081177e8c514512b60...
# 3    3990419dc4b70fa4a95443832c4e41ebcf44d407294b22...
# 4    0a44b3027394e93f404c42f7ca01ecb60b031e433c04a7...
# ..                                                 ...
# 211  42a0f480f103572c8c903fac8ee004910495717ed5c5fa...
# 212  e61b2f28c4286dc5fbe731a29a779c9f278f95794f2402...
# 213  4296fe31bbac21dec354a302d089ff1a1396b27ed52a08...
# 214  c5cb678d74653485fca456ee8ab84183ec07924227e7f3...
# 215  0340ad58a1f9ad53fa857cddb9f30e28a9cd4b5d928915...
#
#                        summary.best_prior_samples.path  \
# 0    media/images/best_prior_samples_summary_a60ee4...
# 1    media/images/best_prior_samples_summary_a8e418...
# 2    media/images/best_prior_samples_summary_60ed53...
# 3    media/images/best_prior_samples_summary_399041...
# 4    media/images/best_prior_samples_summary_0a44b3...
# ..                                                 ...
# 211  media/images/best_prior_samples_summary_42a0f4...
# 212  media/images/best_prior_samples_summary_e61b2f...
# 213  media/images/best_prior_samples_summary_4296fe...
# 214  media/images/best_prior_samples_summary_c5cb67...
# 215  media/images/best_prior_samples_summary_0340ad...
#
#      summary.best_prior_samples.size  summary.val_reconstructions.size  \
# 0                           123091.0                          214629.0
# 1                           124439.0                          214785.0
# 2                           123813.0                          214596.0
# 3                           126715.0                          217185.0
# 4                           124239.0                          214934.0
# ..                               ...                               ...
# 211                         249961.0                          301328.0
# 212                         249702.0                          295060.0
# 213                         253463.0                          297945.0
# 214                         262643.0                          298589.0
# 215                         252429.0                          289717.0
#
#     summary.val_reconstructions._type  summary.val_reconstructions.width  \
# 0                          image-file                            19200.0
# 1                          image-file                            19200.0
# 2                          image-file                            19200.0
# 3                          image-file                            19200.0
# 4                          image-file                            19200.0
# ..                                ...                                ...
# 211                        image-file                            19200.0
# 212                        image-file                            19200.0
# 213                        image-file                            19200.0
# 214                        image-file                            19200.0
# 215                        image-file                            19200.0
#
#     summary.val_reconstructions.format  summary.val_reconstructions.height  \
# 0                                  png                              1600.0
# 1                                  png                              1600.0
# 2                                  png                              1600.0
# 3                                  png                              1600.0
# 4                                  png                              1600.0
# ..                                 ...                                 ...
# 211                                png                              2400.0
# 212                                png                              2400.0
# 213                                png                              2400.0
# 214                                png                              2400.0
# 215                                png                              2400.0
#
#                     summary.val_reconstructions.sha256  \
# 0    a8b91fedca696e4d1d809dcc5fec281e4bc83623db8b4e...
# 1    ca8c9b84a53ba431d70449a64876c6a65492dcc85108c6...
# 2    7ae54a2857b60729a6bc6cf0337633dad937b955d3586d...
# 3    34d9115ce449848d1ebd044a99d7ab276a8e78eb5346f6...
# 4    d1bd8042384ee2053213cddcb088f3f6a11cbe66210618...
# ..                                                 ...
# 211  bcf35f98ca5a34e01d0d370ae1207497b77ac5d9b54143...
# 212  a888d3c3f13483d95f6a39947fe4abba7d5300b1fe699b...
# 213  5a7853d7b7cf71b0a3d7c9f946921bc302a97cb4b0018e...
# 214  34ed8765efbda076dfa60d5dfad229fad37636501c55bf...
# 215  29b1d5154e5b35385e7b19e532f6e826ea441a2bd07835...
#
#                       summary.val_reconstructions.path  summary.val/η_kld  \
# 0    media/images/val_reconstructions_7500_a8b91fed...                NaN
# 1    media/images/val_reconstructions_7500_ca8c9b84...                NaN
# 2    media/images/val_reconstructions_7500_7ae54a28...                NaN
# 3    media/images/val_reconstructions_7500_34d9115c...                NaN
# 4    media/images/val_reconstructions_7500_d1bd8042...                NaN
# ..                                                 ...                ...
# 211  media/images/val_reconstructions_7500_bcf35f98...           0.591440
# 212  media/images/val_reconstructions_7500_a888d3c3...           0.708256
# 213  media/images/val_reconstructions_7500_5a7853d7...           2.054381
# 214  media/images/val_reconstructions_7500_34ed8765...           0.508105
# 215  media/images/val_reconstructions_7500_29b1d515...           0.299127
#
#      summary.best_val_η_kld  summary.train/η_kld  config.α  config.β  \
# 0                       NaN                  NaN      1.00        10
# 1                       NaN                  NaN      1.00        10
# 2                       NaN                  NaN      1.00        10
# 3                       NaN                  NaN      1.00        10
# 4                       NaN                  NaN      1.00        10
# ..                      ...                  ...       ...       ...
# 211                0.591440             0.124223      0.01        10
# 212                0.708256             0.046709      0.01        10
# 213                2.054381             0.669107      0.01        10
# 214                0.963510             0.130195      0.01        10
# 215                0.299127             0.064539      0.01        10
#
#      config.seed config.dataset  \
# 0              2          MNIST
# 1              0          MNIST
# 2              1          MNIST
# 3              1          MNIST
# 4              2          MNIST
# ..           ...            ...
# 211            0          MNIST
# 212            0          MNIST
# 213            2          MNIST
# 214            1          MNIST
# 215            0          MNIST
#
#                                         config.pp_eval  \
# 0    value_range(-1, 1)|random_rotate(-90, 90, fill...
# 1    value_range(-1, 1)|random_rotate(-180, 180, fi...
# 2    value_range(-1, 1)|random_rotate(-180, 180, fi...
# 3    value_range(-1, 1)|random_rotate(-90, 90, fill...
# 4    value_range(-1, 1)|random_rotate(-180, 180, fi...
# ..                                                 ...
# 211  value_range(-1, 1)|random_rotate(-60, 60, fill...
# 212  value_range(-1, 1)|random_rotate(-45, 45, fill...
# 213  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 214  value_range(-1, 1)|random_rotate(-15, 15, fill...
# 215  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
#
#                                        config.pp_train config.val_split  \
# 0    value_range(-1, 1)|random_rotate(-90, 90, fill...    train[:10000]
# 1    value_range(-1, 1)|random_rotate(-180, 180, fi...    train[:10000]
# 2    value_range(-1, 1)|random_rotate(-180, 180, fi...    train[:10000]
# 3    value_range(-1, 1)|random_rotate(-90, 90, fill...    train[:10000]
# 4    value_range(-1, 1)|random_rotate(-180, 180, fi...    train[:10000]
# ..                                                 ...              ...
# 211  value_range(-1, 1)|random_rotate(-60, 60, fill...    train[:10000]
# 212  value_range(-1, 1)|random_rotate(-45, 45, fill...    train[:10000]
# 213  value_range(-1, 1)|random_rotate(-0, 0, fill_v...    train[:10000]
# 214  value_range(-1, 1)|random_rotate(-15, 15, fill...    train[:10000]
# 215  value_range(-1, 1)|random_rotate(-0, 0, fill_v...    train[:10000]
#
#      config.batch_size  config.eval_every config.model_name config.optim_name  \
# 0                  512                500               VAE             adamw
# 1                  512                500               VAE             adamw
# 2                  512                500               VAE             adamw
# 3                  512                500               VAE             adamw
# 4                  512                500               VAE             adamw
# ..                 ...                ...               ...               ...
# 211                512                500             LIVAE             adamw
# 212                512                500             LIVAE             adamw
# 213                512                500             LIVAE             adamw
# 214                512                500             LIVAE             adamw
# 215                512                500             LIVAE             adamw
#
#      config.total_steps config.train_split  config.learning_rate  \
# 0                  7501      train[10000:]                0.0001
# 1                  7501      train[10000:]                0.0001
# 2                  7501      train[10000:]                0.0001
# 3                  7501      train[10000:]                0.0001
# 4                  7501      train[10000:]                0.0001
# ..                  ...                ...                   ...
# 211                7501      train[10000:]                0.0001
# 212                7501      train[10000:]                0.0001
# 213                7501      train[10000:]                0.0001
# 214                7501      train[10000:]                0.0001
# 215                7501      train[10000:]                0.0001
#
#           config.lr_schedule_name config.β_schedule_name  \
# 0    warmup_cosine_decay_schedule  cosine_decay_schedule
# 1    warmup_cosine_decay_schedule  cosine_decay_schedule
# 2    warmup_cosine_decay_schedule  cosine_decay_schedule
# 3    warmup_cosine_decay_schedule  cosine_decay_schedule
# 4    warmup_cosine_decay_schedule  cosine_decay_schedule
# ..                            ...                    ...
# 211  warmup_cosine_decay_schedule  cosine_decay_schedule
# 212  warmup_cosine_decay_schedule  cosine_decay_schedule
# 213  warmup_cosine_decay_schedule  cosine_decay_schedule
# 214  warmup_cosine_decay_schedule  cosine_decay_schedule
# 215  warmup_cosine_decay_schedule  cosine_decay_schedule
#
#      config.repeat_after_batch  config.data_rotation_angle  \
# 0                         True                          90
# 1                         True                         180
# 2                         True                         180
# 3                         True                          90
# 4                         True                         180
# ..                         ...                         ...
# 211                       True                          60
# 212                       True                          45
# 213                       True                           0
# 214                       True                          15
# 215                       True                           0
#
#      config.shuffle_buffer_size config.model.X_given_Z.hidden_dims  \
# 0                         50000                     [256, 128, 64]
# 1                         50000                     [256, 128, 64]
# 2                         50000                     [256, 128, 64]
# 3                         50000                     [256, 128, 64]
# 4                         50000                     [256, 128, 64]
# ..                          ...                                ...
# 211                       50000                                NaN
# 212                       50000                                NaN
# 213                       50000                                NaN
# 214                       50000                                NaN
# 215                       50000                                NaN
#
#     config.model.Z_given_X.hidden_dims  config.model.latent_dim  \
# 0                       [64, 128, 256]                      128
# 1                       [64, 128, 256]                      128
# 2                       [64, 128, 256]                      128
# 3                       [64, 128, 256]                      128
# 4                       [64, 128, 256]                      128
# ..                                 ...                      ...
# 211                     [64, 128, 256]                      128
# 212                     [64, 128, 256]                      128
# 213                     [64, 128, 256]                      128
# 214                     [64, 128, 256]                      128
# 215                     [64, 128, 256]                      128
#
#      config.optim.weight_decay  config.lr_schedule.end_value  \
# 0                       0.0001                        0.0001
# 1                       0.0001                        0.0001
# 2                       0.0001                        0.0001
# 3                       0.0001                        0.0001
# 4                       0.0001                        0.0001
# ..                         ...                           ...
# 211                     0.0001                        0.0001
# 212                     0.0001                        0.0001
# 213                     0.0001                        0.0001
# 214                     0.0001                        0.0001
# 215                     0.0001                        0.0001
#
#      config.lr_schedule.peak_value  config.lr_schedule.decay_steps  \
# 0                            0.001                            7501
# 1                            0.001                            7501
# 2                            0.001                            7501
# 3                            0.001                            7501
# 4                            0.001                            7501
# ..                             ...                             ...
# 211                          0.001                            7501
# 212                          0.001                            7501
# 213                          0.001                            7501
# 214                          0.001                            7501
# 215                          0.001                            7501
#
#      config.lr_schedule.warmup_steps  config.β_schedule.alpha  \
# 0                               1000                      0.1
# 1                               1000                      0.1
# 2                               1000                      0.1
# 3                               1000                      0.1
# 4                               1000                      0.1
# ..                               ...                      ...
# 211                             1000                      0.1
# 212                             1000                      0.1
# 213                             1000                      0.1
# 214                             1000                      0.1
# 215                             1000                      0.1
#
#      config.β_schedule.decay_steps config.α_schedule_name  \
# 0                             7501                    NaN
# 1                             7501                    NaN
# 2                             7501                    NaN
# 3                             7501                    NaN
# 4                             7501                    NaN
# ..                             ...                    ...
# 211                           7501  cosine_decay_schedule
# 212                           7501  cosine_decay_schedule
# 213                           7501  cosine_decay_schedule
# 214                           7501  cosine_decay_schedule
# 215                           7501  cosine_decay_schedule
#
#                                    config.model.bounds  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 211  [0.25, 0.25, 3.141592653589793, 0.25, 0.25, 0....
# 212  [0.25, 0.25, 3.141592653589793, 0.25, 0.25, 0....
# 213  [0.25, 0.25, 3.141592653589793, 0.25, 0.25, 0....
# 214  [0.25, 0.25, 3.141592653589793, 0.25, 0.25, 0....
# 215  [0.25, 0.25, 3.141592653589793, 0.25, 0.25, 0....
#
#     config.model.Eta_given_X.base.hidden_dims  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 211                                  [64, 32]
# 212                                  [64, 32]
# 213                                  [64, 32]
# 214                                  [64, 32]
# 215                                  [64, 32]
#
#      config.model.Eta_given_X.bijector.num_bins  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 211                                         4.0
# 212                                         4.0
# 213                                         4.0
# 214                                         4.0
# 215                                         4.0
#
#      config.model.Eta_given_X.bijector.num_layers  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 211                                           2.0
# 212                                           2.0
# 213                                           2.0
# 214                                           2.0
# 215                                           2.0
#
#     config.model.Eta_given_X.bijector.hidden_dims  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 211                                      [64, 32]
# 212                                      [64, 32]
# 213                                      [64, 32]
# 214                                      [64, 32]
# 215                                      [64, 32]
#
#     config.model.Eta_given_Z.base.hidden_dims  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 211                                  [64, 32]
# 212                                  [64, 32]
# 213                                  [64, 32]
# 214                                  [64, 32]
# 215                                  [64, 32]
#
#      config.model.Eta_given_Z.bijector.num_bins  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 211                                         4.0
# 212                                         4.0
# 213                                         4.0
# 214                                         4.0
# 215                                         4.0
#
#      config.model.Eta_given_Z.bijector.num_layers  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 211                                           2.0
# 212                                           2.0
# 213                                           2.0
# 214                                           2.0
# 215                                           2.0
#
#     config.model.Eta_given_Z.bijector.hidden_dims  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 211                                      [64, 32]
# 212                                      [64, 32]
# 213                                      [64, 32]
# 214                                      [64, 32]
# 215                                      [64, 32]
#
#     config.model.Xhat_given_Z.hidden_dims  config.α_schedule.alpha  \
# 0                                     NaN                      NaN
# 1                                     NaN                      NaN
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
# ..                                    ...                      ...
# 211                        [256, 128, 64]                    100.0
# 212                        [256, 128, 64]                    100.0
# 213                        [256, 128, 64]                    100.0
# 214                        [256, 128, 64]                    100.0
# 215                        [256, 128, 64]                    100.0
#
#      config.α_schedule.decay_steps config.model.Eta.base.hidden_dims  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
# ..                             ...                               ...
# 211                         6750.0                               NaN
# 212                         6750.0                               NaN
# 213                         6750.0                               NaN
# 214                         6750.0                               NaN
# 215                         6750.0                               NaN
#
#      config.model.Eta.bijector.num_bins  config.model.Eta.bijector.num_layers  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
# ..                                  ...                                   ...
# 211                                 NaN                                   NaN
# 212                                 NaN                                   NaN
# 213                                 NaN                                   NaN
# 214                                 NaN                                   NaN
# 215                                 NaN                                   NaN
#
#     config.model.Eta.bijector.hidden_dims transformation_type
# 0                                     NaN      general_affine
# 1                                     NaN      general_affine
# 2                                     NaN      general_affine
# 3                                     NaN      general_affine
# 4                                     NaN      general_affine
# ..                                    ...                 ...
# 211                                   NaN      general_affine
# 212                                   NaN      general_affine
# 213                                   NaN      general_affine
# 214                                   NaN      general_affine
# 215                                   NaN      general_affine
#
# [144 rows x 95 columns]

# %%
# compare VAE and LIVAE, under general affine transformation
plot_df = df_filtered[df_filtered['config.model_name'].isin(['VAE', 'LIVAE'])]
plot_df = plot_df[plot_df['transformation_type'] == 'general_affine']

sns.lineplot(x="config.data_rotation_angle", y="summary.best_val_ll",
             hue="config.model_name", style="transformation_type",
             data=plot_df)
# Out:
# <AxesSubplot:xlabel='config.data_rotation_angle', ylabel='summary.best_val_ll'>

# %%
# compare LIVAE under general affine transformation and under rotation only
plot_df = df_filtered[df_filtered['config.model_name'].isin(['LIVAE'])]
plot_df = plot_df[plot_df['transformation_type'].isin(['general_affine', 'rotation_only'])]

sns.lineplot(x="config.data_rotation_angle", y="summary.best_val_ll",
             hue="config.model_name", style="transformation_type",
             data=plot_df)
# Out:
# <AxesSubplot:xlabel='config.data_rotation_angle', ylabel='summary.best_val_ll'>

# %%
# compare LIVAE, LIVAE_NO_CONJ1, and LIVAE_NO_CONJ3 under general affine transformation
plot_df = df_filtered[df_filtered['config.model_name'].isin(['LIVAE', 'LIVAE_NO_CONJ1', 'LIVAE_NO_CONJ3'])]
plot_df = plot_df[plot_df['transformation_type'] == 'general_affine']

sns.lineplot(x="config.data_rotation_angle", y="summary.best_val_ll",
             hue="config.model_name", style="transformation_type",
             data=plot_df)
# Out:
# <AxesSubplot:xlabel='config.data_rotation_angle', ylabel='summary.best_val_ll'>
