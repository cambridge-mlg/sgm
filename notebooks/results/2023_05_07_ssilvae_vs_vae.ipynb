# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
# figure size in inches
rcParams['figure.figsize'] = 12.,8.

import seaborn as sns
import pandas as pd
import wandb

pd.set_option('display.max_columns', None)

# %%
api = wandb.Api()
entity, project = "invariance-learners", "neurips2023experiments"  # set to your entity and project 
runs = api.runs(entity + "/" + project)

# %%
summary_list, config_list, name_list, tags, ids, states = [], [], [], [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append(
        {k: v for k,v in run.config.items()
         if not k.startswith('_')})

    # .name is the human-readable name of the run.
    name_list.append(run.name)

    tags.append(run.tags)

    ids.append(run.id)

    states.append(run.state)

runs_df = pd.DataFrame({
    "summary": summary_list,
    "config": config_list,
    "name": name_list,
    "tags": tags,
    "id": ids,
    "state": states
    })

runs_df
# Out:
#                                                 summary  \
# 0     {'γ': 1, '_step': 7500, 'σ_vae': 0.15352293848...
# 1     {'prior_samples': {'path': 'media/images/prior...
# 2     {'val_reconstructions': {'format': 'png', 'hei...
# 3     {'val/elbo': 818.6686401367188, 'val/iwlb': 84...
# 4     {'γ': 1, 'σ_vae': 0.15552674233913422, 'train/...
# ...                                                 ...
# 2828  {'_step': 7500, 'best_val_loss': -962.90612792...
# 2829  {'α': 1, 'β': 1.0000003576278689, 'γ': 1, 'σ':...
# 2830  {'val/loss': -765.7479858398438, 'train/loss':...
# 2831  {'val/ll': 662.0555419921875, 'val/elbo': 614....
# 2832  {'α': 1, '_step': 7500, '_timestamp': 16834837...
#
#                                                  config                  name  \
# 0     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...  royal-butterfly-2833
# 1     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...     pretty-night-2829
# 2     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...     laced-flower-2829
# 3     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...     gallant-snow-2829
# 4     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...    ethereal-snow-2829
# ...                                                 ...                   ...
# 2828  {'α': 1, 'β': 10, 'γ': 1, 'seed': 1, 'model': ...      legendary-hill-4
# 2829  {'α': 1, 'β': 10, 'γ': 1, 'seed': 2, 'model': ...      wandering-fog-20
# 2830  {'α': 1, 'β': 10, 'γ': 1, 'seed': 0, 'model': ...        iconic-field-8
# 2831  {'α': 1, 'β': 10, 'γ': 1, 'seed': 1, 'model': ...          kind-shape-6
# 2832  {'α': 1, 'β': 10, 'γ': 1, 'seed': 0, 'model': ...         swift-sound-6
#
#                                            tags        id     state
# 0                     [hais_sweep, seeds, test]  xu8mwy4d  finished
# 1                     [hais_sweep, seeds, test]  x0rukt8r  finished
# 2                     [hais_sweep, seeds, test]  2fmdgudf  finished
# 3                     [hais_sweep, seeds, test]  235prfk6  finished
# 4                     [hais_sweep, seeds, test]  1k0bukun  finished
# ...                                         ...       ...       ...
# 2828  [VAE, angle_sweep, hidden, num_trn_sweep]  1o0kl4md  finished
# 2829  [VAE, angle_sweep, hidden, num_trn_sweep]  1b9bni7k  finished
# 2830  [VAE, angle_sweep, hidden, num_trn_sweep]  1awux98q  finished
# 2831  [VAE, angle_sweep, hidden, num_trn_sweep]  1adk4z59  finished
# 2832  [VAE, angle_sweep, hidden, num_trn_sweep]  194qbeyj  finished
#
# [2833 rows x 6 columns]

# %%
df_expanded = runs_df.join(pd.json_normalize(runs_df['summary'], record_prefix='summary.').add_prefix('summary.')).drop('summary', axis='columns')
df_expanded = df_expanded.join(pd.json_normalize(runs_df['config'], record_prefix='config').add_prefix('config.')).drop('config', axis='columns')

df_expanded.columns
# Out:
# Index(['name', 'tags', 'id', 'state', 'summary.γ', 'summary._step',
#        'summary.σ_vae', 'summary.train/elbo', 'summary.best_val_iwlb',
#        'summary.best_val_ll',
#        ...
#        'config.model.Η_given_Xhat.base.dropout_rate',
#        'config.model.Η_given_Xhat.trunk.conv_dims',
#        'config.model.Η_given_Xhat.trunk.dense_dims',
#        'config.model.Η_given_Xhat.trunk.dropout_rate',
#        'config.model.Η_given_Xhat.num_bins',
#        'config.model.Η_given_Xhat.num_layers',
#        'config.model.Η_given_Xhat.conditioner.hidden_dims',
#        'config.model.Η_given_Xhat.conditioner.dropout_rate',
#        'config.γ_schedule.alpha', 'config.γ_schedule.decay_steps'],
#       dtype='object', length=155)

# %%
df_expanded
# Out:
#                       name                                       tags  \
# 0     royal-butterfly-2833                  [hais_sweep, seeds, test]
# 1        pretty-night-2829                  [hais_sweep, seeds, test]
# 2        laced-flower-2829                  [hais_sweep, seeds, test]
# 3        gallant-snow-2829                  [hais_sweep, seeds, test]
# 4       ethereal-snow-2829                  [hais_sweep, seeds, test]
# ...                    ...                                        ...
# 2828      legendary-hill-4  [VAE, angle_sweep, hidden, num_trn_sweep]
# 2829      wandering-fog-20  [VAE, angle_sweep, hidden, num_trn_sweep]
# 2830        iconic-field-8  [VAE, angle_sweep, hidden, num_trn_sweep]
# 2831          kind-shape-6  [VAE, angle_sweep, hidden, num_trn_sweep]
# 2832         swift-sound-6  [VAE, angle_sweep, hidden, num_trn_sweep]
#
#             id     state  summary.γ  summary._step  summary.σ_vae  \
# 0     xu8mwy4d  finished        1.0         7500.0       0.153523
# 1     x0rukt8r  finished        1.0         7500.0       0.151608
# 2     2fmdgudf  finished        1.0         7500.0       0.155986
# 3     235prfk6  finished        1.0         7500.0       0.159109
# 4     1k0bukun  finished        1.0         7500.0       0.155527
# ...        ...       ...        ...            ...            ...
# 2828  1o0kl4md  finished        1.0         7500.0            NaN
# 2829  1b9bni7k  finished        1.0         7500.0            NaN
# 2830  1awux98q  finished        1.0         7500.0            NaN
# 2831  1adk4z59  finished        1.0         7500.0            NaN
# 2832  194qbeyj  finished        1.0         7500.0            NaN
#
#       summary.train/elbo  summary.best_val_iwlb  summary.best_val_ll  \
# 0             857.291504             881.660828           898.150024
# 1             875.469971             893.204956           909.345825
# 2             863.153381             882.272644           897.235046
# 3             822.100586             842.843567           858.143250
# 4             836.291687             857.521851           873.665039
# ...                  ...                    ...                  ...
# 2828          993.594849                    NaN          1011.685425
# 2829          791.203369                    NaN           825.955933
# 2830          752.699829                    NaN           811.662109
# 2831          617.340210                    NaN           662.055542
# 2832          605.020752                    NaN           640.746948
#
#       summary.α  summary.val/iwlb  summary._timestamp  summary.train/z_kld  \
# 0           1.0        881.660828        1.686826e+09            40.890144
# 1           1.0        893.204956        1.686826e+09            41.640083
# 2           1.0        882.272644        1.686826e+09            39.933468
# 3           1.0        842.843567        1.686826e+09            39.537228
# 4           1.0        857.521851        1.686826e+09            41.097160
# ...         ...               ...                 ...                  ...
# 2828        1.0               NaN        1.683484e+09            48.114330
# 2829        1.0               NaN        1.683484e+09            42.263580
# 2830        1.0               NaN        1.683484e+09            46.122520
# 2831        1.0               NaN        1.683484e+09            47.304882
# 2832        1.0               NaN        1.683484e+09            38.985451
#
#       summary.train/ll  summary.learing_rate  summary.best_val_elbo  \
# 0           898.181763                0.0001             857.338745
# 1           917.110229                0.0001             867.779846
# 2           903.086914                0.0001             857.240356
# 3           861.637878                0.0001             818.668640
# 4           877.388916                0.0001             832.618652
# ...                ...                   ...                    ...
# 2828       1041.709229                0.0001             962.906128
# 2829        833.467041                0.0001             783.578796
# 2830        798.822449                0.0001             765.747986
# 2831        664.645142                0.0001             614.263550
# 2832        644.006348                0.0001             600.745300
#
#       summary.val/elbo  summary.val/z_kld  summary._runtime  \
# 0           857.338745          40.811390             378.0
# 1           867.779846          41.566097             375.0
# 2           857.240356          39.994659             374.0
# 3           818.668640          39.474514             375.0
# 4           832.618652          41.046291             375.0
# ...                ...                ...               ...
# 2828        962.906128          48.779335             337.0
# 2829        783.578796          42.377045             338.0
# 2830        765.747986          45.914223             338.0
# 2831        614.263550          47.792023             334.0
# 2832        600.745300          40.001568             336.0
#
#       summary.train/loss  summary.best_val_step  summary.hais_mll  \
# 0            -857.291504                 7500.0        830.242615
# 1            -875.469971                 7500.0       1177.353271
# 2            -863.153381                 7500.0       3166.605469
# 3            -822.100586                 7500.0        798.265808
# 4            -836.291687                 7500.0       2831.162109
# ...                  ...                    ...               ...
# 2828         -993.594849                 7500.0               NaN
# 2829         -791.203369                 7500.0               NaN
# 2830         -752.699829                 7500.0               NaN
# 2831         -617.340210                 7500.0               NaN
# 2832         -605.020752                 7500.0               NaN
#
#       summary.best_val_loss  summary.β  summary.val/ll  summary.val/loss  \
# 0               -857.338745        1.0      898.150024       -857.338745
# 1               -867.779846        1.0      909.345825       -867.779846
# 2               -857.240356        1.0      897.235046       -857.240356
# 3               -818.668640        1.0      858.143250       -818.668640
# 4               -832.618652        1.0      873.665039       -832.618652
# ...                     ...        ...             ...               ...
# 2828            -962.906128        1.0     1011.685425       -962.906128
# 2829            -783.578796        1.0      825.955933       -783.578796
# 2830            -765.747986        1.0      811.662109       -765.747986
# 2831            -614.263550        1.0      662.055542       -614.263550
# 2832            -600.745300        1.0      640.746948       -600.745300
#
#       summary.best_val_z_kld  summary._wandb.runtime  \
# 0                  40.811390                  9665.0
# 1                  41.566097                  6051.0
# 2                  39.994659                  3342.0
# 3                  39.474514                  6053.0
# 4                  41.046291                  6055.0
# ...                      ...                     ...
# 2828               48.779335                   338.0
# 2829               42.377045                   338.0
# 2830               45.914223                   339.0
# 2831               47.792023                   336.0
# 2832               40.001568                   337.0
#
#       summary.prior_samples.size summary.prior_samples._type  \
# 0                       109822.0                  image-file
# 1                       109534.0                  image-file
# 2                       109870.0                  image-file
# 3                       109832.0                  image-file
# 4                       109868.0                  image-file
# ...                          ...                         ...
# 2828                    109110.0                  image-file
# 2829                    110445.0                  image-file
# 2830                    110989.0                  image-file
# 2831                    112471.0                  image-file
# 2832                    112474.0                  image-file
#
#       summary.prior_samples.width summary.prior_samples.format  \
# 0                         16000.0                          png
# 1                         16000.0                          png
# 2                         16000.0                          png
# 3                         16000.0                          png
# 4                         16000.0                          png
# ...                           ...                          ...
# 2828                      16000.0                          png
# 2829                      16000.0                          png
# 2830                      16000.0                          png
# 2831                      16000.0                          png
# 2832                      16000.0                          png
#
#       summary.prior_samples.height  \
# 0                            800.0
# 1                            800.0
# 2                            800.0
# 3                            800.0
# 4                            800.0
# ...                            ...
# 2828                         800.0
# 2829                         800.0
# 2830                         800.0
# 2831                         800.0
# 2832                         800.0
#
#                            summary.prior_samples.sha256  \
# 0     42324203d49a5dd7b7055b5019901f1741466d3b1339ec...
# 1     be8a200d4ad37b476e1c43b244f0a63ceafc8295d7658d...
# 2     9aca781fc767b7d6b14c54e6d96e934d3ba93d3197f290...
# 3     441a173cf53166af9f5a7b98da7b00993a60c9f1ea4265...
# 4     f51d0872c7d7720b48213f75eb30716b2d5e61628c55cf...
# ...                                                 ...
# 2828  e07683e51f3eb3c5537686e73690dbbb8a6521124b32f9...
# 2829  a10f004dcd17da1118dc16c27b17aab78bfcf8a1b439cc...
# 2830  5c6968c26e1f17de905210cd3f1a5c3958ad5adca3ad67...
# 2831  6e4c60f46093870d22e1973a22d86fb2d8ff8aa9c56ba8...
# 2832  b81dcaa2d1e80408604659b7e19b4008553eb3837b4344...
#
#                              summary.prior_samples.path  \
# 0     media/images/prior_samples_7500_42324203d49a5d...
# 1     media/images/prior_samples_7500_be8a200d4ad37b...
# 2     media/images/prior_samples_7500_9aca781fc767b7...
# 3     media/images/prior_samples_7500_441a173cf53166...
# 4     media/images/prior_samples_7500_f51d0872c7d772...
# ...                                                 ...
# 2828  media/images/prior_samples_7500_e07683e51f3eb3...
# 2829  media/images/prior_samples_7500_a10f004dcd17da...
# 2830  media/images/prior_samples_7500_5c6968c26e1f17...
# 2831  media/images/prior_samples_7500_6e4c60f4609387...
# 2832  media/images/prior_samples_7500_b81dcaa2d1e804...
#
#       summary.val_reconstructions.width summary.val_reconstructions.format  \
# 0                               16000.0                                png
# 1                               16000.0                                png
# 2                               16000.0                                png
# 3                               16000.0                                png
# 4                               16000.0                                png
# ...                                 ...                                ...
# 2828                            16000.0                                png
# 2829                            16000.0                                png
# 2830                            16000.0                                png
# 2831                            16000.0                                png
# 2832                            16000.0                                png
#
#       summary.val_reconstructions.height  \
# 0                                 1600.0
# 1                                 1600.0
# 2                                 1600.0
# 3                                 1600.0
# 4                                 1600.0
# ...                                  ...
# 2828                              1600.0
# 2829                              1600.0
# 2830                              1600.0
# 2831                              1600.0
# 2832                              1600.0
#
#                      summary.val_reconstructions.sha256  \
# 0     5fd2e4be0d9e47d41ffd3a69f0e4189fb9d8c72794d9c2...
# 1     62e5b127ec288a26d6e021f2093f83e2181be85ef1f0b2...
# 2     20f0f10ddd97e8bee24837836bff03a20cfb49b41aabcf...
# 3     488d1f4c0b246cff6ba35a710f5f17c3d94bb84cc3674d...
# 4     dbd6bc1abf1f09130a5c82f4fb4e8fff56d2201eca33c9...
# ...                                                 ...
# 2828  77f9af96e8d9ab7fdf5d219f4342c24e30df6b308ad302...
# 2829  a6bcd8335f17cdb7900bd0cf8704e0928a83a4c12b3702...
# 2830  4a2c5bff4d808162faa770a0b3cdfd1862c308e922b968...
# 2831  fbf1d7819fe5ef85b57ad1ce8be8e3b200237abc502a0d...
# 2832  0250c64b229847a61eb96377060796834f5d98b2aa5075...
#
#                        summary.val_reconstructions.path  \
# 0     media/images/val_reconstructions_7500_5fd2e4be...
# 1     media/images/val_reconstructions_7500_62e5b127...
# 2     media/images/val_reconstructions_7500_20f0f10d...
# 3     media/images/val_reconstructions_7500_488d1f4c...
# 4     media/images/val_reconstructions_7500_dbd6bc1a...
# ...                                                 ...
# 2828  media/images/val_reconstructions_7500_77f9af96...
# 2829  media/images/val_reconstructions_7500_a6bcd833...
# 2830  media/images/val_reconstructions_7500_4a2c5bff...
# 2831  media/images/val_reconstructions_7500_fbf1d781...
# 2832  media/images/val_reconstructions_7500_0250c64b...
#
#       summary.val_reconstructions.size summary.val_reconstructions._type  \
# 0                             161343.0                        image-file
# 1                             161353.0                        image-file
# 2                             161373.0                        image-file
# 3                             161731.0                        image-file
# 4                             161728.0                        image-file
# ...                                ...                               ...
# 2828                          186766.0                        image-file
# 2829                          181735.0                        image-file
# 2830                          181811.0                        image-file
# 2831                          183362.0                        image-file
# 2832                          183538.0                        image-file
#
#                         summary.best_prior_samples.path  \
# 0     media/images/best_prior_samples_summary_423242...
# 1     media/images/best_prior_samples_summary_be8a20...
# 2     media/images/best_prior_samples_summary_9aca78...
# 3     media/images/best_prior_samples_summary_441a17...
# 4     media/images/best_prior_samples_summary_f51d08...
# ...                                                 ...
# 2828  media/images/best_prior_samples_summary_e07683...
# 2829  media/images/best_prior_samples_summary_a10f00...
# 2830  media/images/best_prior_samples_summary_5c6968...
# 2831  media/images/best_prior_samples_summary_6e4c60...
# 2832  media/images/best_prior_samples_summary_b81dca...
#
#       summary.best_prior_samples.size summary.best_prior_samples._type  \
# 0                            109822.0                       image-file
# 1                            109534.0                       image-file
# 2                            109870.0                       image-file
# 3                            109832.0                       image-file
# 4                            109868.0                       image-file
# ...                               ...                              ...
# 2828                         109110.0                       image-file
# 2829                         110445.0                       image-file
# 2830                         110989.0                       image-file
# 2831                         112471.0                       image-file
# 2832                         112474.0                       image-file
#
#       summary.best_prior_samples.width summary.best_prior_samples.format  \
# 0                              16000.0                               png
# 1                              16000.0                               png
# 2                              16000.0                               png
# 3                              16000.0                               png
# 4                              16000.0                               png
# ...                                ...                               ...
# 2828                           16000.0                               png
# 2829                           16000.0                               png
# 2830                           16000.0                               png
# 2831                           16000.0                               png
# 2832                           16000.0                               png
#
#       summary.best_prior_samples.height  \
# 0                                 800.0
# 1                                 800.0
# 2                                 800.0
# 3                                 800.0
# 4                                 800.0
# ...                                 ...
# 2828                              800.0
# 2829                              800.0
# 2830                              800.0
# 2831                              800.0
# 2832                              800.0
#
#                       summary.best_prior_samples.sha256  \
# 0     42324203d49a5dd7b7055b5019901f1741466d3b1339ec...
# 1     be8a200d4ad37b476e1c43b244f0a63ceafc8295d7658d...
# 2     9aca781fc767b7d6b14c54e6d96e934d3ba93d3197f290...
# 3     441a173cf53166af9f5a7b98da7b00993a60c9f1ea4265...
# 4     f51d0872c7d7720b48213f75eb30716b2d5e61628c55cf...
# ...                                                 ...
# 2828  e07683e51f3eb3c5537686e73690dbbb8a6521124b32f9...
# 2829  a10f004dcd17da1118dc16c27b17aab78bfcf8a1b439cc...
# 2830  5c6968c26e1f17de905210cd3f1a5c3958ad5adca3ad67...
# 2831  6e4c60f46093870d22e1973a22d86fb2d8ff8aa9c56ba8...
# 2832  b81dcaa2d1e80408604659b7e19b4008553eb3837b4344...
#
#       summary.train/q_H_ent  summary.train/xhat_ll  summary.best_val_xhat_ll  \
# 0                       NaN                    NaN                       NaN
# 1                       NaN                    NaN                       NaN
# 2                       NaN                    NaN                       NaN
# 3                       NaN                    NaN                       NaN
# 4                       NaN                    NaN                       NaN
# ...                     ...                    ...                       ...
# 2828                    NaN                    NaN                       NaN
# 2829                    NaN                    NaN                       NaN
# 2830                    NaN                    NaN                       NaN
# 2831                    NaN                    NaN                       NaN
# 2832                    NaN                    NaN                       NaN
#
#       summary.best_val_ll_unorm  summary.train/q_η_ce  summary.val/p_q_H_cent  \
# 0                           NaN                   NaN                     NaN
# 1                           NaN                   NaN                     NaN
# 2                           NaN                   NaN                     NaN
# 3                           NaN                   NaN                     NaN
# 4                           NaN                   NaN                     NaN
# ...                         ...                   ...                     ...
# 2828                        NaN                   NaN                     NaN
# 2829                        NaN                   NaN                     NaN
# 2830                        NaN                   NaN                     NaN
# 2831                        NaN                   NaN                     NaN
# 2832                        NaN                   NaN                     NaN
#
#       summary.best_val_xhat_ll_unorm  summary.train/η_kld  summary.val/q_η_ce  \
# 0                                NaN                  NaN                 NaN
# 1                                NaN                  NaN                 NaN
# 2                                NaN                  NaN                 NaN
# 3                                NaN                  NaN                 NaN
# 4                                NaN                  NaN                 NaN
# ...                              ...                  ...                 ...
# 2828                             NaN                  NaN                 NaN
# 2829                             NaN                  NaN                 NaN
# 2830                             NaN                  NaN                 NaN
# 2831                             NaN                  NaN                 NaN
# 2832                             NaN                  NaN                 NaN
#
#       summary.val/xhat_ll_unorm  summary.val/q_H_ent  \
# 0                           NaN                  NaN
# 1                           NaN                  NaN
# 2                           NaN                  NaN
# 3                           NaN                  NaN
# 4                           NaN                  NaN
# ...                         ...                  ...
# 2828                        NaN                  NaN
# 2829                        NaN                  NaN
# 2830                        NaN                  NaN
# 2831                        NaN                  NaN
# 2832                        NaN                  NaN
#
#       summary.best_val_q_H_ent  summary.σ  summary.best_val_p_q_H_cent  \
# 0                          NaN        NaN                          NaN
# 1                          NaN        NaN                          NaN
# 2                          NaN        NaN                          NaN
# 3                          NaN        NaN                          NaN
# 4                          NaN        NaN                          NaN
# ...                        ...        ...                          ...
# 2828                       NaN   0.135332                          NaN
# 2829                       NaN   0.177140                          NaN
# 2830                       NaN   0.179890                          NaN
# 2831                       NaN   0.209894                          NaN
# 2832                       NaN   0.211257                          NaN
#
#       summary.val/η_kld  summary.val/xhat_ll  summary.train/p_η_ce  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   NaN                  NaN                   NaN
# 4                   NaN                  NaN                   NaN
# ...                 ...                  ...                   ...
# 2828                NaN                  NaN                   NaN
# 2829                NaN                  NaN                   NaN
# 2830                NaN                  NaN                   NaN
# 2831                NaN                  NaN                   NaN
# 2832                NaN                  NaN                   NaN
#
#       summary.best_val_η_kld  summary.best_val_q_η_ce  summary.val/ll_unorm  \
# 0                        NaN                      NaN                   NaN
# 1                        NaN                      NaN                   NaN
# 2                        NaN                      NaN                   NaN
# 3                        NaN                      NaN                   NaN
# 4                        NaN                      NaN                   NaN
# ...                      ...                      ...                   ...
# 2828                     NaN                      NaN                   NaN
# 2829                     NaN                      NaN                   NaN
# 2830                     NaN                      NaN                   NaN
# 2831                     NaN                      NaN                   NaN
# 2832                     NaN                      NaN                   NaN
#
#       summary.train/ll_unorm  summary.best_val_p_η_ce  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2828                     NaN                      NaN
# 2829                     NaN                      NaN
# 2830                     NaN                      NaN
# 2831                     NaN                      NaN
# 2832                     NaN                      NaN
#
#       summary.train/p_q_H_cent  summary.train/xhat_ll_unorm  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ...                        ...                          ...
# 2828                       NaN                          NaN
# 2829                       NaN                          NaN
# 2830                       NaN                          NaN
# 2831                       NaN                          NaN
# 2832                       NaN                          NaN
#
#       summary.val/p_η_ce  config.α  config.β  config.γ  config.seed  \
# 0                    NaN         1        10         1            2
# 1                    NaN         1        10         1            2
# 2                    NaN         1        10         1            2
# 3                    NaN         1        10         1            2
# 4                    NaN         1        10         1            2
# ...                  ...       ...       ...       ...          ...
# 2828                 NaN         1        10         1            1
# 2829                 NaN         1        10         1            2
# 2830                 NaN         1        10         1            0
# 2831                 NaN         1        10         1            1
# 2832                 NaN         1        10         1            0
#
#      config.dataset                                     config.pp_eval  \
# 0             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 1             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 2             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 3             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 4             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# ...             ...                                                ...
# 2828          MNIST  value_range(-1, 1)|random_rotate(-15, 15, fill...
# 2829          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2830          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2831          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2832          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
#
#                                         config.pp_train config.run_hais  \
# 0     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 1     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 2     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 3     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 4     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# ...                                                 ...             ...
# 2828  value_range(-1, 1)|random_rotate(-15, 15, fill...             NaN
# 2829  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2830  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2831  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2832  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
#
#      config.run_iwlb config.val_split  config.batch_size  config.eval_every  \
# 0               True    train[:10000]                512                500
# 1               True    train[:10000]                512                500
# 2               True    train[:10000]                512                500
# 3               True    train[:10000]                512                500
# 4               True    train[:10000]                512                500
# ...              ...              ...                ...                ...
# 2828             NaN    train[:10000]                512                500
# 2829             NaN    train[:10000]                512                500
# 2830             NaN    train[:10000]                512                500
# 2831             NaN    train[:10000]                512                500
# 2832             NaN    train[:10000]                512                500
#
#      config.model_name config.optim_name  config.total_steps  \
# 0                  VAE             adamw                7501
# 1                  VAE             adamw                7501
# 2                  VAE             adamw                7501
# 3                  VAE             adamw                7501
# 4                  VAE             adamw                7501
# ...                ...               ...                 ...
# 2828               VAE             adamw                7501
# 2829               VAE             adamw                7501
# 2830               VAE             adamw                7501
# 2831               VAE             adamw                7501
# 2832               VAE             adamw                7501
#
#       config.train_split config.learning_rate  config.batch_size_eval  \
# 0     train[10000:60000]               0.0001                   128.0
# 1     train[10000:60000]               0.0001                   128.0
# 2     train[10000:60000]               0.0001                   128.0
# 3     train[10000:60000]               0.0001                   128.0
# 4     train[10000:60000]               0.0001                   128.0
# ...                  ...                  ...                     ...
# 2828  train[10000:20000]               0.0001                     NaN
# 2829  train[10000:50000]               0.0001                     NaN
# 2830  train[10000:50000]               0.0001                     NaN
# 2831  train[10000:30000]               0.0001                     NaN
# 2832  train[10000:30000]               0.0001                     NaN
#
#            config.lr_schedule_name config.β_schedule_name  \
# 0     warmup_cosine_decay_schedule  cosine_decay_schedule
# 1     warmup_cosine_decay_schedule  cosine_decay_schedule
# 2     warmup_cosine_decay_schedule  cosine_decay_schedule
# 3     warmup_cosine_decay_schedule  cosine_decay_schedule
# 4     warmup_cosine_decay_schedule  cosine_decay_schedule
# ...                            ...                    ...
# 2828  warmup_cosine_decay_schedule  cosine_decay_schedule
# 2829  warmup_cosine_decay_schedule  cosine_decay_schedule
# 2830  warmup_cosine_decay_schedule  cosine_decay_schedule
# 2831  warmup_cosine_decay_schedule  cosine_decay_schedule
# 2832  warmup_cosine_decay_schedule  cosine_decay_schedule
#
#       config.repeat_after_batch  config.shuffle_buffer_size  \
# 0                          True                       50000
# 1                          True                       50000
# 2                          True                       50000
# 3                          True                       50000
# 4                          True                       50000
# ...                         ...                         ...
# 2828                       True                       50000
# 2829                       True                       50000
# 2830                       True                       50000
# 2831                       True                       50000
# 2832                       True                       50000
#
#       config.hais.num_steps  config.hais.step_size  config.hais.num_chains  \
# 0                     100.0                  0.010                   200.0
# 1                      60.0                  0.010                   200.0
# 2                      30.0                  0.010                   200.0
# 3                      60.0                  0.008                   200.0
# 4                      60.0                  0.005                   200.0
# ...                     ...                    ...                     ...
# 2828                    NaN                    NaN                     NaN
# 2829                    NaN                    NaN                     NaN
# 2830                    NaN                    NaN                     NaN
# 2831                    NaN                    NaN                     NaN
# 2832                    NaN                    NaN                     NaN
#
#       config.hais.num_leapfrog_steps  config.iwlb.num_samples  \
# 0                                2.0                    100.0
# 1                                2.0                    100.0
# 2                                2.0                    100.0
# 3                                2.0                    100.0
# 4                                2.0                    100.0
# ...                              ...                      ...
# 2828                             NaN                      NaN
# 2829                             NaN                      NaN
# 2830                             NaN                      NaN
# 2831                             NaN                      NaN
# 2832                             NaN                      NaN
#
#      config.model.X_given_Z.conv_dims config.model.X_given_Z.dense_dims  \
# 0                      [256, 128, 64]                             [256]
# 1                      [256, 128, 64]                             [256]
# 2                      [256, 128, 64]                             [256]
# 3                      [256, 128, 64]                             [256]
# 4                      [256, 128, 64]                             [256]
# ...                               ...                               ...
# 2828                   [256, 128, 64]                             [256]
# 2829                   [256, 128, 64]                             [256]
# 2830                   [256, 128, 64]                             [256]
# 2831                   [256, 128, 64]                             [256]
# 2832                   [256, 128, 64]                             [256]
#
#       config.model.X_given_Z.max_2strides config.model.Z_given_X.conv_dims  \
# 0                                     2.0                   [64, 128, 256]
# 1                                     2.0                   [64, 128, 256]
# 2                                     2.0                   [64, 128, 256]
# 3                                     2.0                   [64, 128, 256]
# 4                                     2.0                   [64, 128, 256]
# ...                                   ...                              ...
# 2828                                  NaN                   [64, 128, 256]
# 2829                                  NaN                   [64, 128, 256]
# 2830                                  NaN                   [64, 128, 256]
# 2831                                  NaN                   [64, 128, 256]
# 2832                                  NaN                   [64, 128, 256]
#
#      config.model.Z_given_X.dense_dims  config.model.Z_given_X.max_2strides  \
# 0                                [256]                                  2.0
# 1                                [256]                                  2.0
# 2                                [256]                                  2.0
# 3                                [256]                                  2.0
# 4                                [256]                                  2.0
# ...                                ...                                  ...
# 2828                             [256]                                  NaN
# 2829                             [256]                                  NaN
# 2830                             [256]                                  NaN
# 2831                             [256]                                  NaN
# 2832                             [256]                                  NaN
#
#       config.model.latent_dim  config.optim.weight_decay  \
# 0                          16                     0.0001
# 1                          16                     0.0001
# 2                          16                     0.0001
# 3                          16                     0.0001
# 4                          16                     0.0001
# ...                       ...                        ...
# 2828                      128                     0.0001
# 2829                      128                     0.0001
# 2830                      128                     0.0001
# 2831                      128                     0.0001
# 2832                      128                     0.0001
#
#       config.lr_schedule.end_value  config.lr_schedule.peak_value  \
# 0                           0.0001                          0.001
# 1                           0.0001                          0.001
# 2                           0.0001                          0.001
# 3                           0.0001                          0.001
# 4                           0.0001                          0.001
# ...                            ...                            ...
# 2828                        0.0001                          0.001
# 2829                        0.0001                          0.001
# 2830                        0.0001                          0.001
# 2831                        0.0001                          0.001
# 2832                        0.0001                          0.001
#
#       config.lr_schedule.decay_steps  config.lr_schedule.warmup_steps  \
# 0                             7501.0                            750.0
# 1                             7501.0                            750.0
# 2                             7501.0                            750.0
# 3                             7501.0                            750.0
# 4                             7501.0                            750.0
# ...                              ...                              ...
# 2828                          7501.0                            750.0
# 2829                          7501.0                            750.0
# 2830                          7501.0                            750.0
# 2831                          7501.0                            750.0
# 2832                          7501.0                            750.0
#
#       config.β_schedule.alpha  config.β_schedule.decay_steps config.optim  \
# 0                         0.1                           7501          NaN
# 1                         0.1                           7501          NaN
# 2                         0.1                           7501          NaN
# 3                         0.1                           7501          NaN
# 4                         0.1                           7501          NaN
# ...                       ...                            ...          ...
# 2828                      0.1                           7501          NaN
# 2829                      0.1                           7501          NaN
# 2830                      0.1                           7501          NaN
# 2831                      0.1                           7501          NaN
# 2832                      0.1                           7501          NaN
#
#       config.reset_step config.lr_schedule config.partition_fn  \
# 0                   NaN                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2                   NaN                NaN                 NaN
# 3                   NaN                NaN                 NaN
# 4                   NaN                NaN                 NaN
# ...                 ...                ...                 ...
# 2828                NaN                NaN                 NaN
# 2829                NaN                NaN                 NaN
# 2830                NaN                NaN                 NaN
# 2831                NaN                NaN                 NaN
# 2832                NaN                NaN                 NaN
#
#       config.β_end_value  config.γ_end_value config.partition_names  \
# 0                    NaN                 NaN                    NaN
# 1                    NaN                 NaN                    NaN
# 2                    NaN                 NaN                    NaN
# 3                    NaN                 NaN                    NaN
# 4                    NaN                 NaN                    NaN
# ...                  ...                 ...                    ...
# 2828                 NaN                 NaN                    NaN
# 2829                 NaN                 NaN                    NaN
# 2830                 NaN                 NaN                    NaN
# 2831                 NaN                 NaN                    NaN
# 2832                 NaN                 NaN                    NaN
#
#      config.β_schedule_half config.γ_schedule_half config.γ_schedule_name  \
# 0                       NaN                    NaN                    NaN
# 1                       NaN                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                       NaN                    NaN                    NaN
# ...                     ...                    ...                    ...
# 2828                    NaN                    NaN                    NaN
# 2829                    NaN                    NaN                    NaN
# 2830                    NaN                    NaN                    NaN
# 2831                    NaN                    NaN                    NaN
# 2832                    NaN                    NaN                    NaN
#
#      config.lr_schedule_halfs config.model.bounds config.model.offset  \
# 0                         NaN                 NaN                 NaN
# 1                         NaN                 NaN                 NaN
# 2                         NaN                 NaN                 NaN
# 3                         NaN                 NaN                 NaN
# 4                         NaN                 NaN                 NaN
# ...                       ...                 ...                 ...
# 2828                      NaN                 NaN                 NaN
# 2829                      NaN                 NaN                 NaN
# 2830                      NaN                 NaN                 NaN
# 2831                      NaN                 NaN                 NaN
# 2832                      NaN                 NaN                 NaN
#
#      config.model.Η_given_X.base.conv_dims  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 2828                                   NaN
# 2829                                   NaN
# 2830                                   NaN
# 2831                                   NaN
# 2832                                   NaN
#
#      config.model.Η_given_X.base.dense_dims  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 2828                                    NaN
# 2829                                    NaN
# 2830                                    NaN
# 2831                                    NaN
# 2832                                    NaN
#
#       config.model.Η_given_X.base.dropout_rate  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 2828                                       NaN
# 2829                                       NaN
# 2830                                       NaN
# 2831                                       NaN
# 2832                                       NaN
#
#      config.model.Η_given_X.trunk.conv_dims  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 2828                                    NaN
# 2829                                    NaN
# 2830                                    NaN
# 2831                                    NaN
# 2832                                    NaN
#
#      config.model.Η_given_X.trunk.dense_dims  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 2828                                     NaN
# 2829                                     NaN
# 2830                                     NaN
# 2831                                     NaN
# 2832                                     NaN
#
#       config.model.Η_given_X.trunk.dropout_rate  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2828                                        NaN
# 2829                                        NaN
# 2830                                        NaN
# 2831                                        NaN
# 2832                                        NaN
#
#       config.model.Η_given_X.num_bins  config.model.Η_given_X.num_layers  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ...                               ...                                ...
# 2828                              NaN                                NaN
# 2829                              NaN                                NaN
# 2830                              NaN                                NaN
# 2831                              NaN                                NaN
# 2832                              NaN                                NaN
#
#      config.model.Η_given_X.conditioner.hidden_dims  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 2828                                            NaN
# 2829                                            NaN
# 2830                                            NaN
# 2831                                            NaN
# 2832                                            NaN
#
#       config.model.Η_given_X.conditioner.dropout_rate  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 2828                                              NaN
# 2829                                              NaN
# 2830                                              NaN
# 2831                                              NaN
# 2832                                              NaN
#
#      config.model.Xhat_given_Z.conv_dims config.model.Xhat_given_Z.dense_dims  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 2828                                 NaN                                  NaN
# 2829                                 NaN                                  NaN
# 2830                                 NaN                                  NaN
# 2831                                 NaN                                  NaN
# 2832                                 NaN                                  NaN
#
#      config.model.Z_given_Xhat.conv_dims config.model.Z_given_Xhat.dense_dims  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 2828                                 NaN                                  NaN
# 2829                                 NaN                                  NaN
# 2830                                 NaN                                  NaN
# 2831                                 NaN                                  NaN
# 2832                                 NaN                                  NaN
#
#      config.model.Η_given_Xhat.base.conv_dims  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 2828                                      NaN
# 2829                                      NaN
# 2830                                      NaN
# 2831                                      NaN
# 2832                                      NaN
#
#      config.model.Η_given_Xhat.base.dense_dims  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 2828                                       NaN
# 2829                                       NaN
# 2830                                       NaN
# 2831                                       NaN
# 2832                                       NaN
#
#       config.model.Η_given_Xhat.base.dropout_rate  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 2828                                          NaN
# 2829                                          NaN
# 2830                                          NaN
# 2831                                          NaN
# 2832                                          NaN
#
#      config.model.Η_given_Xhat.trunk.conv_dims  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 2828                                       NaN
# 2829                                       NaN
# 2830                                       NaN
# 2831                                       NaN
# 2832                                       NaN
#
#      config.model.Η_given_Xhat.trunk.dense_dims  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2828                                        NaN
# 2829                                        NaN
# 2830                                        NaN
# 2831                                        NaN
# 2832                                        NaN
#
#       config.model.Η_given_Xhat.trunk.dropout_rate  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2828                                           NaN
# 2829                                           NaN
# 2830                                           NaN
# 2831                                           NaN
# 2832                                           NaN
#
#       config.model.Η_given_Xhat.num_bins  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 2828                                 NaN
# 2829                                 NaN
# 2830                                 NaN
# 2831                                 NaN
# 2832                                 NaN
#
#       config.model.Η_given_Xhat.num_layers  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 2828                                   NaN
# 2829                                   NaN
# 2830                                   NaN
# 2831                                   NaN
# 2832                                   NaN
#
#      config.model.Η_given_Xhat.conditioner.hidden_dims  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 2828                                               NaN
# 2829                                               NaN
# 2830                                               NaN
# 2831                                               NaN
# 2832                                               NaN
#
#       config.model.Η_given_Xhat.conditioner.dropout_rate  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2828                                                NaN
# 2829                                                NaN
# 2830                                                NaN
# 2831                                                NaN
# 2832                                                NaN
#
#       config.γ_schedule.alpha  config.γ_schedule.decay_steps
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
# ...                       ...                            ...
# 2828                      NaN                            NaN
# 2829                      NaN                            NaN
# 2830                      NaN                            NaN
# 2831                      NaN                            NaN
# 2832                      NaN                            NaN
#
# [2833 rows x 155 columns]

# %%
# take only completed runs
df_filtered = df_expanded[df_expanded['state'] == 'finished']

# take only runs with certain tags
tags_to_keep = ['angle_sweep', 'num_trn_sweep']
df_filtered = df_filtered[df_filtered['tags'].apply(lambda x: all(tag in x for tag in tags_to_keep))]

# take only runs without certain tags
tags_to_remove = ['hidden']
df_filtered = df_filtered[~df_filtered['tags'].apply(lambda x: any(tag in x for tag in tags_to_remove))]

# remove runs with config.γ = 30
df_filtered = df_filtered[df_filtered['config.γ'] != 30]

df_filtered
# Out:
#                         name                               tags        id  \
# 228        neat-morning-2604       [angle_sweep, num_trn_sweep]  3v2z42ya
# 229    decent-armadillo-2604       [angle_sweep, num_trn_sweep]  1r83gl7h
# 230        peachy-salad-2603       [angle_sweep, num_trn_sweep]  urio6xtf
# 234       balmy-terrain-2599       [angle_sweep, num_trn_sweep]  27ik34go
# 235         daily-plant-2598       [angle_sweep, num_trn_sweep]  3lzxj71k
# ...                      ...                                ...       ...
# 2708       revived-salad-125  [VAE, angle_sweep, num_trn_sweep]  2ztibt3i
# 2709     sparkling-brook-124  [VAE, angle_sweep, num_trn_sweep]  2l5w77tq
# 2710       gentle-cosmos-123  [VAE, angle_sweep, num_trn_sweep]  1iw1wbzz
# 2711  youthful-firebrand-121  [VAE, angle_sweep, num_trn_sweep]  13clxplo
# 2712   earnest-firebrand-121  [VAE, angle_sweep, num_trn_sweep]  106kr6jk
#
#          state  summary.γ  summary._step  summary.σ_vae  summary.train/elbo  \
# 228   finished        1.0        30002.0       0.296482          489.596405
# 229   finished        1.0        30002.0       0.267001          754.026611
# 230   finished        1.0        30002.0       0.277146          591.685059
# 234   finished        1.0        15002.0       0.305598          394.158142
# 235   finished        1.0        15002.0       0.284103          586.118164
# ...        ...        ...            ...            ...                 ...
# 2708  finished        1.0         3500.0            NaN          648.325623
# 2709  finished        1.0         3500.0            NaN          725.587158
# 2710  finished        1.0         3500.0            NaN          733.868774
# 2711  finished        1.0         3500.0            NaN          743.314819
# 2712  finished        1.0         3500.0            NaN          731.629761
#
#       summary.best_val_iwlb  summary.best_val_ll  summary.α  summary.val/iwlb  \
# 228                     NaN           114.700180        1.0               NaN
# 229                     NaN          -190.680786        1.0               NaN
# 230                     NaN           110.679733        1.0               NaN
# 234                     NaN          -134.886414        1.0               NaN
# 235                     NaN           109.270767        1.0               NaN
# ...                     ...                  ...        ...               ...
# 2708                    NaN           -12.967476        1.0               NaN
# 2709                    NaN           -17.853235        1.0               NaN
# 2710                    NaN            -1.534682        1.0               NaN
# 2711                    NaN           -28.276007        1.0               NaN
# 2712                    NaN           -37.524078        1.0               NaN
#
#       summary._timestamp  summary.train/z_kld  summary.train/ll  \
# 228         1.683820e+09            10.614752         82.208099
# 229         1.683820e+09            10.700976        156.480026
# 230         1.683820e+09            11.780323        176.978790
# 234         1.683819e+09            10.205248         87.911636
# 235         1.683819e+09             9.923243        157.573761
# ...                  ...                  ...               ...
# 2708        1.683500e+09            21.653360        777.663879
# 2709        1.683500e+09            22.702517        861.192139
# 2710        1.683500e+09            22.613205        868.940186
# 2711        1.683500e+09            22.476322        877.568848
# 2712        1.683500e+09            22.857588        868.161011
#
#       summary.learing_rate  summary.best_val_elbo  summary.val/elbo  \
# 228               0.000100             526.438904        526.309265
# 229               0.000100             388.829865        387.224731
# 230               0.000100             373.298859        373.298859
# 234               0.000100             193.488480        193.488480
# 235               0.000100             534.624756        534.624756
# ...                    ...                    ...               ...
# 2708              0.000679            -132.128571       -812.294617
# 2709              0.000679            -136.886383       -982.687927
# 2710              0.000679            -126.746780       -908.463745
# 2711              0.000679            -154.763947      -1054.208008
# 2712              0.000679            -166.565826      -1146.102905
#
#       summary.val/z_kld  summary._runtime  summary.train/loss  \
# 228           11.450831            2036.0         -489.596405
# 229           11.569624            2029.0         -754.026611
# 230           12.193434            2033.0         -591.685059
# 234           11.060308            1098.0         -394.158142
# 235           10.859709            1102.0         -586.118164
# ...                 ...               ...                 ...
# 2708          21.691372             169.0         -648.325623
# 2709          22.455305             167.0         -725.587158
# 2710          22.675585             168.0         -733.868774
# 2711          22.684629             169.0         -743.314819
# 2712          22.988750             169.0         -731.629761
#
#       summary.best_val_step  summary.hais_mll  summary.best_val_loss  \
# 228                 29000.0               NaN            -526.438904
# 229                 28500.0               NaN            -388.829865
# 230                 30000.0               NaN            -373.298859
# 234                 15000.0               NaN            -193.488480
# 235                 15000.0               NaN            -534.624756
# ...                     ...               ...                    ...
# 2708                 2500.0               NaN             132.128571
# 2709                 2500.0               NaN             136.886383
# 2710                 2500.0               NaN             126.746780
# 2711                 2500.0               NaN             154.763947
# 2712                 2500.0               NaN             166.565826
#
#       summary.β  summary.val/ll  summary.val/loss  summary.best_val_z_kld  \
# 228    1.000000      109.169159       -526.309265               10.909563
# 229    1.000000     -195.234604       -387.224731               10.415270
# 230    1.000000      110.679733       -373.298859               12.193434
# 234    1.000000     -134.886414       -193.488480               11.060308
# 235    1.000000      109.270767       -534.624756               10.859709
# ...         ...             ...               ...                     ...
# 2708   5.971253     -682.770081        812.294617               15.374546
# 2709   5.971253     -848.601624        982.687927               15.358038
# 2710   5.971253     -773.062012        908.463745               16.155266
# 2711   5.971253     -918.752441       1054.208008               16.319880
# 2712   5.971253    -1008.830933       1146.102905               16.649385
#
#       summary._wandb.runtime  summary.prior_samples.size  \
# 228                   2036.0                    283468.0
# 229                   2029.0                    280351.0
# 230                   2034.0                    283732.0
# 234                   1099.0                    286942.0
# 235                   1103.0                    283793.0
# ...                      ...                         ...
# 2708                   170.0                    110106.0
# 2709                   168.0                    111898.0
# 2710                   169.0                    111269.0
# 2711                   170.0                    110039.0
# 2712                   169.0                    110522.0
#
#      summary.prior_samples._type  summary.prior_samples.width  \
# 228                   image-file                      16000.0
# 229                   image-file                      16000.0
# 230                   image-file                      16000.0
# 234                   image-file                      16000.0
# 235                   image-file                      16000.0
# ...                          ...                          ...
# 2708                  image-file                      16000.0
# 2709                  image-file                      16000.0
# 2710                  image-file                      16000.0
# 2711                  image-file                      16000.0
# 2712                  image-file                      16000.0
#
#      summary.prior_samples.format  summary.prior_samples.height  \
# 228                           png                        2400.0
# 229                           png                        2400.0
# 230                           png                        2400.0
# 234                           png                        2400.0
# 235                           png                        2400.0
# ...                           ...                           ...
# 2708                          png                         800.0
# 2709                          png                         800.0
# 2710                          png                         800.0
# 2711                          png                         800.0
# 2712                          png                         800.0
#
#                            summary.prior_samples.sha256  \
# 228   df03c0f4219505a9532a12df139ceaa3f726a8ba72ede1...
# 229   1fcf7805ea85c1fb1f160298995202b20da19725ea18f9...
# 230   421dc448dd193e0a4215564e34f995700616f6a538aae4...
# 234   1f792534e55ff4ac94c15e5b4661804e1b27223c5e3855...
# 235   026070d2487a64c3149992531a24865846b96719415b5f...
# ...                                                 ...
# 2708  5c01787f635c49a6577409c9769f379c449c5d4547ca55...
# 2709  ebb8fc0d44574fccf6ab844bfe8921816f11e29ea6bdda...
# 2710  6bc4e0b5d63d477e8836f67859f1435b4694eed1d69e7a...
# 2711  2177e0801dcadc3133e10d1757efe9673f9657c51aaf35...
# 2712  1de3db601e9d4b6b90caeae476c851e718ea6a27de0261...
#
#                              summary.prior_samples.path  \
# 228   media/images/prior_samples_30000_df03c0f421950...
# 229   media/images/prior_samples_30000_1fcf7805ea85c...
# 230   media/images/prior_samples_30000_421dc448dd193...
# 234   media/images/prior_samples_15000_1f792534e55ff...
# 235   media/images/prior_samples_15000_026070d2487a6...
# ...                                                 ...
# 2708  media/images/prior_samples_3500_5c01787f635c49...
# 2709  media/images/prior_samples_3500_ebb8fc0d44574f...
# 2710  media/images/prior_samples_3500_6bc4e0b5d63d47...
# 2711  media/images/prior_samples_3500_2177e0801dcadc...
# 2712  media/images/prior_samples_3500_1de3db601e9d4b...
#
#       summary.val_reconstructions.width summary.val_reconstructions.format  \
# 228                             16000.0                                png
# 229                             16000.0                                png
# 230                             16000.0                                png
# 234                             16000.0                                png
# 235                             16000.0                                png
# ...                                 ...                                ...
# 2708                            16000.0                                png
# 2709                            16000.0                                png
# 2710                            16000.0                                png
# 2711                            16000.0                                png
# 2712                            16000.0                                png
#
#       summary.val_reconstructions.height  \
# 228                               3200.0
# 229                               3200.0
# 230                               3200.0
# 234                               3200.0
# 235                               3200.0
# ...                                  ...
# 2708                              1600.0
# 2709                              1600.0
# 2710                              1600.0
# 2711                              1600.0
# 2712                              1600.0
#
#                      summary.val_reconstructions.sha256  \
# 228   c4c7020aa4f7ab189fb1271d224803ce813e04519a75b6...
# 229   3048e78fe0ae59ccd73bcaf9395dc23a8147886f58016a...
# 230   595c5e03f81e6259cef45947b37634530cb9c8888afcdb...
# 234   913e38724de2f9ce662ec4c50651b3fb21a62593d34e77...
# 235   9c449e0a361ef0faccc6bf4eb1f602bc574be49fee69c7...
# ...                                                 ...
# 2708  5f3e0fabf08ea32d209240bae41856d7eb1668c097dd0f...
# 2709  5b2b68244aefa3e5c6b3fc10a1de2437285f542a340e20...
# 2710  b46d8a55f0d3ab4d825de41f79f399940b074f6603c338...
# 2711  6533e572a873e34a064723278b0034357d0df72d88c6d8...
# 2712  b29d95a6ac768629f0ef007df3ef85f0670084180a6121...
#
#                        summary.val_reconstructions.path  \
# 228   media/images/val_reconstructions_30000_c4c7020...
# 229   media/images/val_reconstructions_30000_3048e78...
# 230   media/images/val_reconstructions_30000_595c5e0...
# 234   media/images/val_reconstructions_15000_913e387...
# 235   media/images/val_reconstructions_15000_9c449e0...
# ...                                                 ...
# 2708  media/images/val_reconstructions_3500_5f3e0fab...
# 2709  media/images/val_reconstructions_3500_5b2b6824...
# 2710  media/images/val_reconstructions_3500_b46d8a55...
# 2711  media/images/val_reconstructions_3500_6533e572...
# 2712  media/images/val_reconstructions_3500_b29d95a6...
#
#       summary.val_reconstructions.size summary.val_reconstructions._type  \
# 228                           334206.0                        image-file
# 229                           328247.0                        image-file
# 230                           333961.0                        image-file
# 234                           335381.0                        image-file
# 235                           333598.0                        image-file
# ...                                ...                               ...
# 2708                          181622.0                        image-file
# 2709                          182560.0                        image-file
# 2710                          181927.0                        image-file
# 2711                          180919.0                        image-file
# 2712                          182198.0                        image-file
#
#                         summary.best_prior_samples.path  \
# 228   media/images/best_prior_samples_summary_aaf633...
# 229   media/images/best_prior_samples_summary_9c31d8...
# 230   media/images/best_prior_samples_summary_421dc4...
# 234   media/images/best_prior_samples_summary_1f7925...
# 235   media/images/best_prior_samples_summary_026070...
# ...                                                 ...
# 2708  media/images/best_prior_samples_summary_ac8395...
# 2709  media/images/best_prior_samples_summary_46703d...
# 2710  media/images/best_prior_samples_summary_9d7749...
# 2711  media/images/best_prior_samples_summary_6e0541...
# 2712  media/images/best_prior_samples_summary_834037...
#
#       summary.best_prior_samples.size summary.best_prior_samples._type  \
# 228                          284194.0                       image-file
# 229                          280414.0                       image-file
# 230                          283732.0                       image-file
# 234                          286942.0                       image-file
# 235                          283793.0                       image-file
# ...                               ...                              ...
# 2708                         114910.0                       image-file
# 2709                         117406.0                       image-file
# 2710                         115538.0                       image-file
# 2711                         115385.0                       image-file
# 2712                         115673.0                       image-file
#
#       summary.best_prior_samples.width summary.best_prior_samples.format  \
# 228                            16000.0                               png
# 229                            16000.0                               png
# 230                            16000.0                               png
# 234                            16000.0                               png
# 235                            16000.0                               png
# ...                                ...                               ...
# 2708                           16000.0                               png
# 2709                           16000.0                               png
# 2710                           16000.0                               png
# 2711                           16000.0                               png
# 2712                           16000.0                               png
#
#       summary.best_prior_samples.height  \
# 228                              2400.0
# 229                              2400.0
# 230                              2400.0
# 234                              2400.0
# 235                              2400.0
# ...                                 ...
# 2708                              800.0
# 2709                              800.0
# 2710                              800.0
# 2711                              800.0
# 2712                              800.0
#
#                       summary.best_prior_samples.sha256  \
# 228   aaf63364bdc249120e8f785e9ebce2ec9834fc5dde3383...
# 229   9c31d89079c8b728f721951f227483a08bd1abb9e31e86...
# 230   421dc448dd193e0a4215564e34f995700616f6a538aae4...
# 234   1f792534e55ff4ac94c15e5b4661804e1b27223c5e3855...
# 235   026070d2487a64c3149992531a24865846b96719415b5f...
# ...                                                 ...
# 2708  ac83958a3dfcfcf2e8348a28eb00f76d5ca76e29464988...
# 2709  46703dede64b5d9532bfde0ec152021e3893bc2d65d9da...
# 2710  9d7749d627e782974ed97c429ac0266bad43d06c68dc67...
# 2711  6e0541befb0a43efeb5ffe1def5cdad1690be0eb716a51...
# 2712  83403752187494ec49797c440359ef12315d03af878dfa...
#
#       summary.train/q_H_ent  summary.train/xhat_ll  summary.best_val_xhat_ll  \
# 228              -15.029465             443.602997                450.219177
# 229              -14.673339             633.702148                619.113464
# 230              -15.189302             453.325317                534.232605
# 234              -14.382898             341.459106                365.974579
# 235              -14.968637             464.239655                464.790283
# ...                     ...                    ...                       ...
# 2708                    NaN                    NaN                       NaN
# 2709                    NaN                    NaN                       NaN
# 2710                    NaN                    NaN                       NaN
# 2711                    NaN                    NaN                       NaN
# 2712                    NaN                    NaN                       NaN
#
#       summary.best_val_ll_unorm  summary.train/q_η_ce  summary.val/p_q_H_cent  \
# 228                  114.700180              0.272692               -5.347524
# 229                 -190.680786              0.428023               -5.116583
# 230                  110.679733              0.528271               -5.067750
# 234                 -134.886414              0.560345               -4.769657
# 235                  109.270767              0.341107               -5.187531
# ...                         ...                   ...                     ...
# 2708                        NaN                   NaN                     NaN
# 2709                        NaN                   NaN                     NaN
# 2710                        NaN                   NaN                     NaN
# 2711                        NaN                   NaN                     NaN
# 2712                        NaN                   NaN                     NaN
#
#       summary.best_val_xhat_ll_unorm  summary.train/η_kld  summary.val/q_η_ce  \
# 228                       450.219177            10.110899            0.264476
# 229                       619.113464            10.082487            0.430013
# 230                       534.232605            10.791254            0.563269
# 234                       365.974579             9.683526            0.612256
# 235                       464.790283            10.227505            0.392911
# ...                              ...                  ...                 ...
# 2708                             NaN                  NaN                 NaN
# 2709                             NaN                  NaN                 NaN
# 2710                             NaN                  NaN                 NaN
# 2711                             NaN                  NaN                 NaN
# 2712                             NaN                  NaN                 NaN
#
#       summary.val/xhat_ll_unorm  summary.val/q_H_ent  \
# 228                  455.109833           -15.701793
# 229                  620.918640           -15.649943
# 230                  534.232605          -131.788376
# 234                  365.974579           -15.145207
# 235                  464.790283           -16.562578
# ...                         ...                  ...
# 2708                        NaN                  NaN
# 2709                        NaN                  NaN
# 2710                        NaN                  NaN
# 2711                        NaN                  NaN
# 2712                        NaN                  NaN
#
#       summary.best_val_q_H_ent  summary.σ  summary.best_val_p_q_H_cent  \
# 228                 -15.693443   0.363993                    -5.358073
# 229                 -15.647629   0.362998                    -5.114695
# 230                -131.788376   0.355619                    -5.067750
# 234                 -15.145207   0.367079                    -4.769657
# 235                 -16.562578   0.362662                    -5.187531
# ...                        ...        ...                          ...
# 2708                       NaN   0.127277                          NaN
# 2709                       NaN   0.124159                          NaN
# 2710                       NaN   0.123707                          NaN
# 2711                       NaN   0.119227                          NaN
# 2712                       NaN   0.118339                          NaN
#
#       summary.val/η_kld  summary.val/xhat_ll  summary.train/p_η_ce  \
# 228           10.354270           455.109833              0.186864
# 229           10.533361           620.918640              0.270778
# 230          126.720634           534.232605              0.329928
# 234           10.375552           365.974579              0.380614
# 235           11.375049           464.790283              0.234737
# ...                 ...                  ...                   ...
# 2708                NaN                  NaN                   NaN
# 2709                NaN                  NaN                   NaN
# 2710                NaN                  NaN                   NaN
# 2711                NaN                  NaN                   NaN
# 2712                NaN                  NaN                   NaN
#
#       summary.best_val_η_kld  summary.best_val_q_η_ce  summary.val/ll_unorm  \
# 228                10.335371                 0.264465            109.169159
# 229                10.532934                 0.429940           -195.234604
# 230               126.720634                 0.563269            110.679733
# 234                10.375552                 0.612256           -134.886414
# 235                11.375049                 0.392911            109.270767
# ...                      ...                      ...                   ...
# 2708                     NaN                      NaN                   NaN
# 2709                     NaN                      NaN                   NaN
# 2710                     NaN                      NaN                   NaN
# 2711                     NaN                      NaN                   NaN
# 2712                     NaN                      NaN                   NaN
#
#       summary.train/ll_unorm  summary.best_val_p_η_ce  \
# 228                82.208099                 0.198533
# 229               156.480026                 0.274304
# 230               176.978790                 0.347710
# 234                87.911636                 0.406320
# 235               157.573761                 0.246021
# ...                      ...                      ...
# 2708                     NaN                      NaN
# 2709                     NaN                      NaN
# 2710                     NaN                      NaN
# 2711                     NaN                      NaN
# 2712                     NaN                      NaN
#
#       summary.train/p_q_H_cent  summary.train/xhat_ll_unorm  \
# 228                  -4.918566                   443.602997
# 229                  -4.590852                   633.702148
# 230                  -4.398048                   453.325317
# 234                  -4.699372                   341.459106
# 235                  -4.741133                   464.239655
# ...                        ...                          ...
# 2708                       NaN                          NaN
# 2709                       NaN                          NaN
# 2710                       NaN                          NaN
# 2711                       NaN                          NaN
# 2712                       NaN                          NaN
#
#       summary.val/p_η_ce  config.α  config.β  config.γ  config.seed  \
# 228             0.198413         1        10        10            2
# 229             0.276348         1        10        10            1
# 230             0.347710         1        10        10            0
# 234             0.406320         1        10        10            2
# 235             0.246021         1        10        10            0
# ...                  ...       ...       ...       ...          ...
# 2708                 NaN         1        10         1            5
# 2709                 NaN         1        10         1            0
# 2710                 NaN         1        10         1            3
# 2711                 NaN         1        10         1            2
# 2712                 NaN         1        10         1            1
#
#      config.dataset                                     config.pp_eval  \
# 228           MNIST  value_range(-1, 1)|random_rotate(-180, 180, fi...
# 229           MNIST  value_range(-1, 1)|random_rotate(-180, 180, fi...
# 230           MNIST  value_range(-1, 1)|random_rotate(-180, 180, fi...
# 234           MNIST  value_range(-1, 1)|random_rotate(-180, 180, fi...
# 235           MNIST  value_range(-1, 1)|random_rotate(-180, 180, fi...
# ...             ...                                                ...
# 2708          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2709          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2710          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2711          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2712          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
#
#                                         config.pp_train config.run_hais  \
# 228   value_range(-1, 1)|random_rotate(-180, 180, fi...             NaN
# 229   value_range(-1, 1)|random_rotate(-180, 180, fi...             NaN
# 230   value_range(-1, 1)|random_rotate(-180, 180, fi...             NaN
# 234   value_range(-1, 1)|random_rotate(-180, 180, fi...             NaN
# 235   value_range(-1, 1)|random_rotate(-180, 180, fi...             NaN
# ...                                                 ...             ...
# 2708  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2709  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2710  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2711  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2712  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
#
#      config.run_iwlb config.val_split  config.batch_size  config.eval_every  \
# 228              NaN    train[:10000]                512                500
# 229              NaN    train[:10000]                512                500
# 230              NaN    train[:10000]                512                500
# 234              NaN    train[:10000]                512                500
# 235              NaN    train[:10000]                512                500
# ...              ...              ...                ...                ...
# 2708             NaN    train[:10000]                512                500
# 2709             NaN    train[:10000]                512                500
# 2710             NaN    train[:10000]                512                500
# 2711             NaN    train[:10000]                512                500
# 2712             NaN    train[:10000]                512                500
#
#      config.model_name config.optim_name  config.total_steps  \
# 228            SSILVAE    [adamw, adamw]               30003
# 229            SSILVAE    [adamw, adamw]               30003
# 230            SSILVAE    [adamw, adamw]               30003
# 234            SSILVAE    [adamw, adamw]               15003
# 235            SSILVAE    [adamw, adamw]               15003
# ...                ...               ...                 ...
# 2708               VAE             adamw                3501
# 2709               VAE             adamw                3501
# 2710               VAE             adamw                3501
# 2711               VAE             adamw                3501
# 2712               VAE             adamw                3501
#
#       config.train_split config.learning_rate  config.batch_size_eval  \
# 228   train[10000:60000]     [0.0003, 0.0001]                     NaN
# 229   train[10000:60000]     [0.0003, 0.0001]                     NaN
# 230   train[10000:60000]     [0.0003, 0.0001]                     NaN
# 234   train[10000:60000]     [0.0003, 0.0001]                     NaN
# 235   train[10000:60000]     [0.0003, 0.0001]                     NaN
# ...                  ...                  ...                     ...
# 2708  train[10000:11000]               0.0001                     NaN
# 2709  train[10000:11000]               0.0001                     NaN
# 2710  train[10000:11000]               0.0001                     NaN
# 2711  train[10000:11000]               0.0001                     NaN
# 2712  train[10000:11000]               0.0001                     NaN
#
#                                 config.lr_schedule_name  \
# 228   [warmup_cosine_decay_schedule, warmup_cosine_d...
# 229   [warmup_cosine_decay_schedule, warmup_cosine_d...
# 230   [warmup_cosine_decay_schedule, warmup_cosine_d...
# 234   [warmup_cosine_decay_schedule, warmup_cosine_d...
# 235   [warmup_cosine_decay_schedule, warmup_cosine_d...
# ...                                                 ...
# 2708                       warmup_cosine_decay_schedule
# 2709                       warmup_cosine_decay_schedule
# 2710                       warmup_cosine_decay_schedule
# 2711                       warmup_cosine_decay_schedule
# 2712                       warmup_cosine_decay_schedule
#
#      config.β_schedule_name  config.repeat_after_batch  \
# 228   cosine_decay_schedule                       True
# 229   cosine_decay_schedule                       True
# 230   cosine_decay_schedule                       True
# 234   cosine_decay_schedule                       True
# 235   cosine_decay_schedule                       True
# ...                     ...                        ...
# 2708  cosine_decay_schedule                       True
# 2709  cosine_decay_schedule                       True
# 2710  cosine_decay_schedule                       True
# 2711  cosine_decay_schedule                       True
# 2712  cosine_decay_schedule                       True
#
#       config.shuffle_buffer_size  config.hais.num_steps  \
# 228                        50000                    NaN
# 229                        50000                    NaN
# 230                        50000                    NaN
# 234                        50000                    NaN
# 235                        50000                    NaN
# ...                          ...                    ...
# 2708                       50000                    NaN
# 2709                       50000                    NaN
# 2710                       50000                    NaN
# 2711                       50000                    NaN
# 2712                       50000                    NaN
#
#       config.hais.step_size  config.hais.num_chains  \
# 228                     NaN                     NaN
# 229                     NaN                     NaN
# 230                     NaN                     NaN
# 234                     NaN                     NaN
# 235                     NaN                     NaN
# ...                     ...                     ...
# 2708                    NaN                     NaN
# 2709                    NaN                     NaN
# 2710                    NaN                     NaN
# 2711                    NaN                     NaN
# 2712                    NaN                     NaN
#
#       config.hais.num_leapfrog_steps  config.iwlb.num_samples  \
# 228                              NaN                      NaN
# 229                              NaN                      NaN
# 230                              NaN                      NaN
# 234                              NaN                      NaN
# 235                              NaN                      NaN
# ...                              ...                      ...
# 2708                             NaN                      NaN
# 2709                             NaN                      NaN
# 2710                             NaN                      NaN
# 2711                             NaN                      NaN
# 2712                             NaN                      NaN
#
#      config.model.X_given_Z.conv_dims config.model.X_given_Z.dense_dims  \
# 228                               NaN                               NaN
# 229                               NaN                               NaN
# 230                               NaN                               NaN
# 234                               NaN                               NaN
# 235                               NaN                               NaN
# ...                               ...                               ...
# 2708                   [256, 128, 64]                             [256]
# 2709                   [256, 128, 64]                             [256]
# 2710                   [256, 128, 64]                             [256]
# 2711                   [256, 128, 64]                             [256]
# 2712                   [256, 128, 64]                             [256]
#
#       config.model.X_given_Z.max_2strides config.model.Z_given_X.conv_dims  \
# 228                                   NaN                              NaN
# 229                                   NaN                              NaN
# 230                                   NaN                              NaN
# 234                                   NaN                              NaN
# 235                                   NaN                              NaN
# ...                                   ...                              ...
# 2708                                  NaN                   [64, 128, 256]
# 2709                                  NaN                   [64, 128, 256]
# 2710                                  NaN                   [64, 128, 256]
# 2711                                  NaN                   [64, 128, 256]
# 2712                                  NaN                   [64, 128, 256]
#
#      config.model.Z_given_X.dense_dims  config.model.Z_given_X.max_2strides  \
# 228                                NaN                                  NaN
# 229                                NaN                                  NaN
# 230                                NaN                                  NaN
# 234                                NaN                                  NaN
# 235                                NaN                                  NaN
# ...                                ...                                  ...
# 2708                             [256]                                  NaN
# 2709                             [256]                                  NaN
# 2710                             [256]                                  NaN
# 2711                             [256]                                  NaN
# 2712                             [256]                                  NaN
#
#       config.model.latent_dim  config.optim.weight_decay  \
# 228                       128                        NaN
# 229                       128                        NaN
# 230                       128                        NaN
# 234                       128                        NaN
# 235                       128                        NaN
# ...                       ...                        ...
# 2708                      128                     0.0001
# 2709                      128                     0.0001
# 2710                      128                     0.0001
# 2711                      128                     0.0001
# 2712                      128                     0.0001
#
#       config.lr_schedule.end_value  config.lr_schedule.peak_value  \
# 228                            NaN                            NaN
# 229                            NaN                            NaN
# 230                            NaN                            NaN
# 234                            NaN                            NaN
# 235                            NaN                            NaN
# ...                            ...                            ...
# 2708                        0.0001                          0.001
# 2709                        0.0001                          0.001
# 2710                        0.0001                          0.001
# 2711                        0.0001                          0.001
# 2712                        0.0001                          0.001
#
#       config.lr_schedule.decay_steps  config.lr_schedule.warmup_steps  \
# 228                              NaN                              NaN
# 229                              NaN                              NaN
# 230                              NaN                              NaN
# 234                              NaN                              NaN
# 235                              NaN                              NaN
# ...                              ...                              ...
# 2708                          7501.0                            750.0
# 2709                          7501.0                            750.0
# 2710                          7501.0                            750.0
# 2711                          7501.0                            750.0
# 2712                          7501.0                            750.0
#
#       config.β_schedule.alpha  config.β_schedule.decay_steps  \
# 228                       0.1                          15001
# 229                       0.1                          15001
# 230                       0.1                          15001
# 234                       0.1                           7501
# 235                       0.1                           7501
# ...                       ...                            ...
# 2708                      0.1                           7501
# 2709                      0.1                           7501
# 2710                      0.1                           7501
# 2711                      0.1                           7501
# 2712                      0.1                           7501
#
#                                           config.optim  config.reset_step  \
# 228   [weight_decay: 0.0001\n, weight_decay: 0.0001\n]            15001.0
# 229   [weight_decay: 0.0001\n, weight_decay: 0.0001\n]            15001.0
# 230   [weight_decay: 0.0001\n, weight_decay: 0.0001\n]            15001.0
# 234   [weight_decay: 0.0001\n, weight_decay: 0.0001\n]             7501.0
# 235   [weight_decay: 0.0001\n, weight_decay: 0.0001\n]             7501.0
# ...                                                ...                ...
# 2708                                               NaN                NaN
# 2709                                               NaN                NaN
# 2710                                               NaN                NaN
# 2711                                               NaN                NaN
# 2712                                               NaN                NaN
#
#                                      config.lr_schedule  \
# 228   [decay_steps: 15001\nend_value: 0.0003\npeak_v...
# 229   [decay_steps: 15001\nend_value: 0.0003\npeak_v...
# 230   [decay_steps: 15001\nend_value: 0.0003\npeak_v...
# 234   [decay_steps: 7501\nend_value: 0.0003\npeak_va...
# 235   [decay_steps: 7501\nend_value: 0.0003\npeak_va...
# ...                                                 ...
# 2708                                                NaN
# 2709                                                NaN
# 2710                                                NaN
# 2711                                                NaN
# 2712                                                NaN
#
#                              config.partition_fn  config.β_end_value  \
# 228   config_config.get_config.<locals>.<lambda>                 1.0
# 229   config_config.get_config.<locals>.<lambda>                 1.0
# 230   config_config.get_config.<locals>.<lambda>                 1.0
# 234   config_config.get_config.<locals>.<lambda>                 1.0
# 235   config_config.get_config.<locals>.<lambda>                 1.0
# ...                                          ...                 ...
# 2708                                         NaN                 NaN
# 2709                                         NaN                 NaN
# 2710                                         NaN                 NaN
# 2711                                         NaN                 NaN
# 2712                                         NaN                 NaN
#
#       config.γ_end_value config.partition_names config.β_schedule_half  \
# 228                  1.0            [SSIL, VAE]                 second
# 229                  1.0            [SSIL, VAE]                 second
# 230                  1.0            [SSIL, VAE]                 second
# 234                  1.0            [SSIL, VAE]                 second
# 235                  1.0            [SSIL, VAE]                 second
# ...                  ...                    ...                    ...
# 2708                 NaN                    NaN                    NaN
# 2709                 NaN                    NaN                    NaN
# 2710                 NaN                    NaN                    NaN
# 2711                 NaN                    NaN                    NaN
# 2712                 NaN                    NaN                    NaN
#
#      config.γ_schedule_half config.γ_schedule_name config.lr_schedule_halfs  \
# 228                   first  cosine_decay_schedule          [first, second]
# 229                   first  cosine_decay_schedule          [first, second]
# 230                   first  cosine_decay_schedule          [first, second]
# 234                   first  cosine_decay_schedule          [first, second]
# 235                   first  cosine_decay_schedule          [first, second]
# ...                     ...                    ...                      ...
# 2708                    NaN                    NaN                      NaN
# 2709                    NaN                    NaN                      NaN
# 2710                    NaN                    NaN                      NaN
# 2711                    NaN                    NaN                      NaN
# 2712                    NaN                    NaN                      NaN
#
#                               config.model.bounds config.model.offset  \
# 228   [0.25, 0.25, 3.141592653589793, 0.25, 0.25]     [0, 0, 0, 0, 0]
# 229   [0.25, 0.25, 3.141592653589793, 0.25, 0.25]     [0, 0, 0, 0, 0]
# 230   [0.25, 0.25, 3.141592653589793, 0.25, 0.25]     [0, 0, 0, 0, 0]
# 234   [0.25, 0.25, 3.141592653589793, 0.25, 0.25]     [0, 0, 0, 0, 0]
# 235   [0.25, 0.25, 3.141592653589793, 0.25, 0.25]     [0, 0, 0, 0, 0]
# ...                                           ...                 ...
# 2708                                          NaN                 NaN
# 2709                                          NaN                 NaN
# 2710                                          NaN                 NaN
# 2711                                          NaN                 NaN
# 2712                                          NaN                 NaN
#
#      config.model.Η_given_X.base.conv_dims  \
# 228                                     []
# 229                                     []
# 230                                     []
# 234                                     []
# 235                                     []
# ...                                    ...
# 2708                                   NaN
# 2709                                   NaN
# 2710                                   NaN
# 2711                                   NaN
# 2712                                   NaN
#
#      config.model.Η_given_X.base.dense_dims  \
# 228                            [64, 32, 16]
# 229                            [64, 32, 16]
# 230                            [64, 32, 16]
# 234                            [64, 32, 16]
# 235                            [64, 32, 16]
# ...                                     ...
# 2708                                    NaN
# 2709                                    NaN
# 2710                                    NaN
# 2711                                    NaN
# 2712                                    NaN
#
#       config.model.Η_given_X.base.dropout_rate  \
# 228                                        0.0
# 229                                        0.0
# 230                                        0.0
# 234                                        0.0
# 235                                        0.0
# ...                                        ...
# 2708                                       NaN
# 2709                                       NaN
# 2710                                       NaN
# 2711                                       NaN
# 2712                                       NaN
#
#      config.model.Η_given_X.trunk.conv_dims  \
# 228                           [32, 64, 128]
# 229                           [32, 64, 128]
# 230                           [32, 64, 128]
# 234                           [32, 64, 128]
# 235                           [32, 64, 128]
# ...                                     ...
# 2708                                    NaN
# 2709                                    NaN
# 2710                                    NaN
# 2711                                    NaN
# 2712                                    NaN
#
#      config.model.Η_given_X.trunk.dense_dims  \
# 228                                    [256]
# 229                                    [256]
# 230                                    [256]
# 234                                    [256]
# 235                                    [256]
# ...                                      ...
# 2708                                     NaN
# 2709                                     NaN
# 2710                                     NaN
# 2711                                     NaN
# 2712                                     NaN
#
#       config.model.Η_given_X.trunk.dropout_rate  \
# 228                                         0.0
# 229                                         0.0
# 230                                         0.0
# 234                                         0.0
# 235                                         0.0
# ...                                         ...
# 2708                                        NaN
# 2709                                        NaN
# 2710                                        NaN
# 2711                                        NaN
# 2712                                        NaN
#
#       config.model.Η_given_X.num_bins  config.model.Η_given_X.num_layers  \
# 228                               5.0                                1.0
# 229                               5.0                                1.0
# 230                               5.0                                1.0
# 234                               5.0                                1.0
# 235                               5.0                                1.0
# ...                               ...                                ...
# 2708                              NaN                                NaN
# 2709                              NaN                                NaN
# 2710                              NaN                                NaN
# 2711                              NaN                                NaN
# 2712                              NaN                                NaN
#
#      config.model.Η_given_X.conditioner.hidden_dims  \
# 228                                      [256, 128]
# 229                                      [256, 128]
# 230                                      [256, 128]
# 234                                      [256, 128]
# 235                                      [256, 128]
# ...                                             ...
# 2708                                            NaN
# 2709                                            NaN
# 2710                                            NaN
# 2711                                            NaN
# 2712                                            NaN
#
#       config.model.Η_given_X.conditioner.dropout_rate  \
# 228                                               0.0
# 229                                               0.0
# 230                                               0.0
# 234                                               0.0
# 235                                               0.0
# ...                                               ...
# 2708                                              NaN
# 2709                                              NaN
# 2710                                              NaN
# 2711                                              NaN
# 2712                                              NaN
#
#      config.model.Xhat_given_Z.conv_dims config.model.Xhat_given_Z.dense_dims  \
# 228                       [256, 128, 64]                                [256]
# 229                       [256, 128, 64]                                [256]
# 230                       [256, 128, 64]                                [256]
# 234                       [256, 128, 64]                                [256]
# 235                       [256, 128, 64]                                [256]
# ...                                  ...                                  ...
# 2708                                 NaN                                  NaN
# 2709                                 NaN                                  NaN
# 2710                                 NaN                                  NaN
# 2711                                 NaN                                  NaN
# 2712                                 NaN                                  NaN
#
#      config.model.Z_given_Xhat.conv_dims config.model.Z_given_Xhat.dense_dims  \
# 228                       [64, 128, 256]                                [256]
# 229                       [64, 128, 256]                                [256]
# 230                       [64, 128, 256]                                [256]
# 234                       [64, 128, 256]                                [256]
# 235                       [64, 128, 256]                                [256]
# ...                                  ...                                  ...
# 2708                                 NaN                                  NaN
# 2709                                 NaN                                  NaN
# 2710                                 NaN                                  NaN
# 2711                                 NaN                                  NaN
# 2712                                 NaN                                  NaN
#
#      config.model.Η_given_Xhat.base.conv_dims  \
# 228                                        []
# 229                                        []
# 230                                        []
# 234                                        []
# 235                                        []
# ...                                       ...
# 2708                                      NaN
# 2709                                      NaN
# 2710                                      NaN
# 2711                                      NaN
# 2712                                      NaN
#
#      config.model.Η_given_Xhat.base.dense_dims  \
# 228                               [64, 32, 16]
# 229                               [64, 32, 16]
# 230                               [64, 32, 16]
# 234                               [64, 32, 16]
# 235                               [64, 32, 16]
# ...                                        ...
# 2708                                       NaN
# 2709                                       NaN
# 2710                                       NaN
# 2711                                       NaN
# 2712                                       NaN
#
#       config.model.Η_given_Xhat.base.dropout_rate  \
# 228                                           0.0
# 229                                           0.0
# 230                                           0.0
# 234                                           0.0
# 235                                           0.0
# ...                                           ...
# 2708                                          NaN
# 2709                                          NaN
# 2710                                          NaN
# 2711                                          NaN
# 2712                                          NaN
#
#      config.model.Η_given_Xhat.trunk.conv_dims  \
# 228                              [32, 64, 128]
# 229                              [32, 64, 128]
# 230                              [32, 64, 128]
# 234                              [32, 64, 128]
# 235                              [32, 64, 128]
# ...                                        ...
# 2708                                       NaN
# 2709                                       NaN
# 2710                                       NaN
# 2711                                       NaN
# 2712                                       NaN
#
#      config.model.Η_given_Xhat.trunk.dense_dims  \
# 228                                       [256]
# 229                                       [256]
# 230                                       [256]
# 234                                       [256]
# 235                                       [256]
# ...                                         ...
# 2708                                        NaN
# 2709                                        NaN
# 2710                                        NaN
# 2711                                        NaN
# 2712                                        NaN
#
#       config.model.Η_given_Xhat.trunk.dropout_rate  \
# 228                                            0.0
# 229                                            0.0
# 230                                            0.0
# 234                                            0.0
# 235                                            0.0
# ...                                            ...
# 2708                                           NaN
# 2709                                           NaN
# 2710                                           NaN
# 2711                                           NaN
# 2712                                           NaN
#
#       config.model.Η_given_Xhat.num_bins  \
# 228                                  5.0
# 229                                  5.0
# 230                                  5.0
# 234                                  5.0
# 235                                  5.0
# ...                                  ...
# 2708                                 NaN
# 2709                                 NaN
# 2710                                 NaN
# 2711                                 NaN
# 2712                                 NaN
#
#       config.model.Η_given_Xhat.num_layers  \
# 228                                    1.0
# 229                                    1.0
# 230                                    1.0
# 234                                    1.0
# 235                                    1.0
# ...                                    ...
# 2708                                   NaN
# 2709                                   NaN
# 2710                                   NaN
# 2711                                   NaN
# 2712                                   NaN
#
#      config.model.Η_given_Xhat.conditioner.hidden_dims  \
# 228                                         [256, 128]
# 229                                         [256, 128]
# 230                                         [256, 128]
# 234                                         [256, 128]
# 235                                         [256, 128]
# ...                                                ...
# 2708                                               NaN
# 2709                                               NaN
# 2710                                               NaN
# 2711                                               NaN
# 2712                                               NaN
#
#       config.model.Η_given_Xhat.conditioner.dropout_rate  \
# 228                                                 0.0
# 229                                                 0.0
# 230                                                 0.0
# 234                                                 0.0
# 235                                                 0.0
# ...                                                 ...
# 2708                                                NaN
# 2709                                                NaN
# 2710                                                NaN
# 2711                                                NaN
# 2712                                                NaN
#
#       config.γ_schedule.alpha  config.γ_schedule.decay_steps
# 228                       0.1                        15001.0
# 229                       0.1                        15001.0
# 230                       0.1                        15001.0
# 234                       0.1                         7501.0
# 235                       0.1                         7501.0
# ...                       ...                            ...
# 2708                      NaN                            NaN
# 2709                      NaN                            NaN
# 2710                      NaN                            NaN
# 2711                      NaN                            NaN
# 2712                      NaN                            NaN
#
# [2141 rows x 155 columns]

# %%
# create rotation angle column
# we take the 'config.pp_train', which is a string of the form 'value_range(-1, 1)|random_rotate(-θ, θ, fill_value=-1)|keep(["image"])'
# where θ is the rotation angle. Let's use a regex to extract θ, which is an integer. 
# For example if we see the pattern 'random_rotate(-30, 30, fill_value=-1)', we want to extract 30.
# And if we see the pattern 'random_rotate(-150, 150, fill_value=-1)', we want to extract 150.
# And if we see the pattern 'random_rotate(0, 0, fill_value=-1)', we want to extract 0.
df_filtered['rotation_angle'] = df_filtered['config.pp_train'].str.extract(r'random_rotate\(-?\d+, (\d+), fill_value=-1\)').astype(int)

# create number of training samples column
# we take the 'config.train_split' column, which is a string of the form 'train[x:y]', where x and y are integers
# representing the start and end indices of the train split. Let's use a regex to extract y-x, which is the number of training samples.
# For example if we see the pattern 'train[0:1000]', we want to extract 1000-0=1000.
# And if we see the pattern 'train[0:10000]', we want to extract 10000-0=10000.
# And if we see the pattern 'train[10000:20000]', we want to extract 20000-10000=10000.
upper = df_filtered['config.train_split'].str.extract(r'train\[\d+:(\d+)\]').astype(int)
lower = df_filtered['config.train_split'].str.extract(r'train\[(\d+):\d+\]').astype(int)
df_filtered['num_trn'] = upper - lower

# %%
df_filtered['config.total_steps'].unique()
# Out:
# array([30003, 15003, 10003,  7003, 15001,  7501,  5001,  3501])

# %%
df_filtered['num_trn'].unique()
# Out:
# array([50000, 30000, 10000,  3000,  1000])

# %%
# create a sns lineplot, where the x-axis is the rotation angle, the y-axis is the best validation log-likelihood,
# and the hue is the number of training samples
plot_df = df_filtered[['rotation_angle', 'summary.best_val_ll', 'num_trn', 'config.total_steps', 'config.model_name']]

plot_df = plot_df[
    plot_df['config.total_steps'].isin([7501, 15003]) & plot_df['num_trn'].isin([50_000])
]

# map config.total_steps to consistent values, if they are in this dict
new_vals = {30003: 15001, 15003: 7501, 10003: 5001, 7003: 3501}
plot_df = plot_df.replace({'config.total_steps': new_vals})

g = sns.relplot(
    x="rotation_angle", y="summary.best_val_ll", hue="config.model_name", style="num_trn", col="config.total_steps",
    markers=True,
    # palette=sns.color_palette('viridis', as_cmap=True),
    kind="line",
    col_wrap=2,
    facet_kws=dict(sharey=False, sharex=False),
    data=plot_df
)
g.set_axis_labels('Rotation angle', 'Best validation log-likelihood')
g.set_titles('Total steps: {col_name}')
for ax in g.axes:
    ax.set_xticks(plot_df['rotation_angle'].unique())
    ax.set_xticklabels(plot_df['rotation_angle'].unique(), rotation=45)
plt.show()

# %%
# create a sns lineplot, where the x-axis is the rotation angle, the y-axis is the best validation log-likelihood,
# and the hue is the number of training samples
plot_df = df_filtered[['rotation_angle', 'summary.best_val_ll', 'num_trn', 'config.total_steps', 'config.model_name']]

# map config.total_steps to consistent values, if they are in this dict
new_vals = {30003: 15001, 15003: 7501, 10003: 5001, 7003: 3501}
plot_df = plot_df.replace({'config.total_steps': new_vals})

g = sns.relplot(
    x="rotation_angle", y="summary.best_val_ll", hue="config.model_name", style="num_trn", col="config.total_steps",
    markers=True,
    # palette=sns.color_palette('viridis', as_cmap=True),
    kind="line",
    col_wrap=2,
    facet_kws=dict(sharey=False, sharex=False),
    data=plot_df
)
g.set_axis_labels('Rotation angle', 'Best validation log-likelihood')
g.set_titles('Total steps: {col_name}')
for ax in g.axes:
    ax.set_xticks(plot_df['rotation_angle'].unique())
    ax.set_xticklabels(plot_df['rotation_angle'].unique(), rotation=45)
plt.show()

# %%
plot_df = df_filtered[['rotation_angle', 'summary.best_val_ll', 'num_trn', 'config.total_steps', 'config.model_name']]
# take only runs with config.model_name = 'VAE'
plot_df = plot_df[plot_df['config.model_name'] == 'VAE']
g = sns.relplot(
    x="num_trn", y="summary.best_val_ll", hue="rotation_angle", style="rotation_angle", col="config.total_steps",
    markers=True,
    palette=sns.color_palette('viridis', as_cmap=True),
    kind="line",
    col_wrap=2,
    facet_kws=dict(sharey=False, sharex=False),
    data=plot_df
)
g.set_axis_labels('Num Trn', 'Best validation log-likelihood')
g.set_titles('Total steps: {col_name}')
for ax in g.axes:
    ax.set_xticks(plot_df['num_trn'].unique())
    ax.set_xticklabels(plot_df['num_trn'].unique(), rotation=45)
plt.show()

# %%
plot_df = df_filtered[['rotation_angle', 'summary.best_val_ll', 'num_trn', 'config.total_steps']]
plot_df = plot_df[plot_df['config.model_name'] == 'VAE']
g = sns.relplot(
    x="num_trn", y="summary.best_val_ll", hue="config.total_steps", style="config.total_steps", col="rotation_angle",
    markers=True,
    palette=sns.color_palette('viridis', as_cmap=True),
    kind="line",
    col_wrap=3,
    facet_kws=dict(sharey=True, sharex=False),
    data=plot_df
)
plt.show()

# %%
plot_df = df_filtered[['rotation_angle', 'summary.best_val_ll', 'num_trn', 'config.total_steps']]
plot_df = plot_df[plot_df['config.model_name'] == 'VAE']
g = sns.relplot(
    x="config.total_steps", y="summary.best_val_ll", hue="num_trn", style="num_trn", col="rotation_angle",
    markers=True,
    palette=sns.color_palette('viridis', as_cmap=True),
    kind="line",
    col_wrap=3,
    facet_kws=dict(sharey=True, sharex=False),
    data=plot_df
)
plt.show()
