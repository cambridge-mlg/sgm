# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams
# figure size in inches
rcParams['figure.figsize'] = 12.,8.

import seaborn as sns
import pandas as pd
import wandb

pd.set_option('display.max_columns', None)

# %%
api = wandb.Api()
entity, project = "invariance-learners", "neurips2023experiments"  # set to your entity and project 
runs = api.runs(entity + "/" + project)

# %%
summary_list, config_list, name_list, tags, ids, states = [], [], [], [], [], []
for run in runs: 
    # .summary contains the output keys/values for metrics like accuracy.
    #  We call ._json_dict to omit large files 
    summary_list.append(run.summary._json_dict)

    # .config contains the hyperparameters.
    #  We remove special values that start with _.
    config_list.append(
        {k: v for k,v in run.config.items()
         if not k.startswith('_')})

    # .name is the human-readable name of the run.
    name_list.append(run.name)

    tags.append(run.tags)

    ids.append(run.id)

    states.append(run.state)

runs_df = pd.DataFrame({
    "summary": summary_list,
    "config": config_list,
    "name": name_list,
    "tags": tags,
    "id": ids,
    "state": states
    })

runs_df
# Out:
#                                                 summary  \
# 0     {'val_reconstructions': {'size': 161343, '_typ...
# 1     {'train/z_kld': 41.64008331298828, 'learing_ra...
# 2     {'val/ll': 897.2350463867188, 'best_val_iwlb':...
# 3     {'prior_samples': {'sha256': '441a173cf53166af...
# 4     {'val/iwlb': 857.5218505859375, 'best_val_elbo...
# ...                                                 ...
# 2828  {'val/z_kld': 48.779335021972656, 'best_val_el...
# 2829  {'train/elbo': 791.203369140625, 'best_val_ll'...
# 2830  {'best_val_z_kld': 45.91422271728515, 'val/ll'...
# 2831  {'_wandb': {'runtime': 336}, '_timestamp': 168...
# 2832  {'_timestamp': 1683483704, 'best_val_loss': -6...
#
#                                                  config                  name  \
# 0     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...  royal-butterfly-2833
# 1     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...     pretty-night-2829
# 2     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...     laced-flower-2829
# 3     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...     gallant-snow-2829
# 4     {'α': 1, 'β': 10, 'γ': 1, 'hais': {'num_steps'...    ethereal-snow-2829
# ...                                                 ...                   ...
# 2828  {'α': 1, 'β': 10, 'γ': 1, 'seed': 1, 'model': ...      legendary-hill-4
# 2829  {'α': 1, 'β': 10, 'γ': 1, 'seed': 2, 'model': ...      wandering-fog-20
# 2830  {'α': 1, 'β': 10, 'γ': 1, 'seed': 0, 'model': ...        iconic-field-8
# 2831  {'α': 1, 'β': 10, 'γ': 1, 'seed': 1, 'model': ...          kind-shape-6
# 2832  {'α': 1, 'β': 10, 'γ': 1, 'seed': 0, 'model': ...         swift-sound-6
#
#                                            tags        id     state
# 0                     [hais_sweep, seeds, test]  xu8mwy4d  finished
# 1                     [hais_sweep, seeds, test]  x0rukt8r  finished
# 2                     [hais_sweep, seeds, test]  2fmdgudf  finished
# 3                     [hais_sweep, seeds, test]  235prfk6  finished
# 4                     [hais_sweep, seeds, test]  1k0bukun  finished
# ...                                         ...       ...       ...
# 2828  [VAE, angle_sweep, hidden, num_trn_sweep]  1o0kl4md  finished
# 2829  [VAE, angle_sweep, hidden, num_trn_sweep]  1b9bni7k  finished
# 2830  [VAE, angle_sweep, hidden, num_trn_sweep]  1awux98q  finished
# 2831  [VAE, angle_sweep, hidden, num_trn_sweep]  1adk4z59  finished
# 2832  [VAE, angle_sweep, hidden, num_trn_sweep]  194qbeyj  finished
#
# [2833 rows x 6 columns]

# %%
df_expanded = runs_df.join(pd.json_normalize(runs_df['summary'], record_prefix='summary.').add_prefix('summary.')).drop('summary', axis='columns')
df_expanded = df_expanded.join(pd.json_normalize(runs_df['config'], record_prefix='config').add_prefix('config.')).drop('config', axis='columns')

df_expanded.columns
# Out:
# Index(['name', 'tags', 'id', 'state', 'summary.β', 'summary.val/ll',
#        'summary.val/z_kld', 'summary.best_val_iwlb', 'summary.best_val_loss',
#        'summary.train/ll',
#        ...
#        'config.model.Η_given_Xhat.base.dropout_rate',
#        'config.model.Η_given_Xhat.trunk.conv_dims',
#        'config.model.Η_given_Xhat.trunk.dense_dims',
#        'config.model.Η_given_Xhat.trunk.dropout_rate',
#        'config.model.Η_given_Xhat.num_bins',
#        'config.model.Η_given_Xhat.num_layers',
#        'config.model.Η_given_Xhat.conditioner.hidden_dims',
#        'config.model.Η_given_Xhat.conditioner.dropout_rate',
#        'config.γ_schedule.alpha', 'config.γ_schedule.decay_steps'],
#       dtype='object', length=155)

# %%
df_expanded
# Out:
#                       name                                       tags  \
# 0     royal-butterfly-2833                  [hais_sweep, seeds, test]
# 1        pretty-night-2829                  [hais_sweep, seeds, test]
# 2        laced-flower-2829                  [hais_sweep, seeds, test]
# 3        gallant-snow-2829                  [hais_sweep, seeds, test]
# 4       ethereal-snow-2829                  [hais_sweep, seeds, test]
# ...                    ...                                        ...
# 2828      legendary-hill-4  [VAE, angle_sweep, hidden, num_trn_sweep]
# 2829      wandering-fog-20  [VAE, angle_sweep, hidden, num_trn_sweep]
# 2830        iconic-field-8  [VAE, angle_sweep, hidden, num_trn_sweep]
# 2831          kind-shape-6  [VAE, angle_sweep, hidden, num_trn_sweep]
# 2832         swift-sound-6  [VAE, angle_sweep, hidden, num_trn_sweep]
#
#             id     state  summary.β  summary.val/ll  summary.val/z_kld  \
# 0     xu8mwy4d  finished        1.0      898.150024          40.811390
# 1     x0rukt8r  finished        1.0      909.345825          41.566097
# 2     2fmdgudf  finished        1.0      897.235046          39.994659
# 3     235prfk6  finished        1.0      858.143250          39.474514
# 4     1k0bukun  finished        1.0      873.665039          41.046291
# ...        ...       ...        ...             ...                ...
# 2828  1o0kl4md  finished        1.0     1011.685425          48.779335
# 2829  1b9bni7k  finished        1.0      825.955933          42.377045
# 2830  1awux98q  finished        1.0      811.662109          45.914223
# 2831  1adk4z59  finished        1.0      662.055542          47.792023
# 2832  194qbeyj  finished        1.0      640.746948          40.001568
#
#       summary.best_val_iwlb  summary.best_val_loss  summary.train/ll  \
# 0                881.660828            -857.338745        898.181763
# 1                893.204956            -867.779846        917.110229
# 2                882.272644            -857.240356        903.086914
# 3                842.843567            -818.668640        861.637878
# 4                857.521851            -832.618652        877.388916
# ...                     ...                    ...               ...
# 2828                    NaN            -962.906128       1041.709229
# 2829                    NaN            -783.578796        833.467041
# 2830                    NaN            -765.747986        798.822449
# 2831                    NaN            -614.263550        664.645142
# 2832                    NaN            -600.745300        644.006348
#
#       summary.val/elbo  summary.train/elbo  summary.train/z_kld  summary.γ  \
# 0           857.338745          857.291504            40.890144        1.0
# 1           867.779846          875.469971            41.640083        1.0
# 2           857.240356          863.153381            39.933468        1.0
# 3           818.668640          822.100586            39.537228        1.0
# 4           832.618652          836.291687            41.097160        1.0
# ...                ...                 ...                  ...        ...
# 2828        962.906128          993.594849            48.114330        1.0
# 2829        783.578796          791.203369            42.263580        1.0
# 2830        765.747986          752.699829            46.122520        1.0
# 2831        614.263550          617.340210            47.304882        1.0
# 2832        600.745300          605.020752            38.985451        1.0
#
#       summary.σ_vae  summary.hais_mll  summary.learing_rate  \
# 0          0.153523        830.242615                0.0001
# 1          0.151608       1177.353271                0.0001
# 2          0.155986       3166.605469                0.0001
# 3          0.159109        798.265808                0.0001
# 4          0.155527       2831.162109                0.0001
# ...             ...               ...                   ...
# 2828            NaN               NaN                0.0001
# 2829            NaN               NaN                0.0001
# 2830            NaN               NaN                0.0001
# 2831            NaN               NaN                0.0001
# 2832            NaN               NaN                0.0001
#
#       summary.best_val_elbo  summary._timestamp  summary.val/loss  \
# 0                857.338745        1.686826e+09       -857.338745
# 1                867.779846        1.686826e+09       -867.779846
# 2                857.240356        1.686826e+09       -857.240356
# 3                818.668640        1.686826e+09       -818.668640
# 4                832.618652        1.686826e+09       -832.618652
# ...                     ...                 ...               ...
# 2828             962.906128        1.683484e+09       -962.906128
# 2829             783.578796        1.683484e+09       -783.578796
# 2830             765.747986        1.683484e+09       -765.747986
# 2831             614.263550        1.683484e+09       -614.263550
# 2832             600.745300        1.683484e+09       -600.745300
#
#       summary.train/loss  summary.best_val_step  summary.best_val_z_kld  \
# 0            -857.291504                 7500.0               40.811390
# 1            -875.469971                 7500.0               41.566097
# 2            -863.153381                 7500.0               39.994659
# 3            -822.100586                 7500.0               39.474514
# 4            -836.291687                 7500.0               41.046291
# ...                  ...                    ...                     ...
# 2828         -993.594849                 7500.0               48.779335
# 2829         -791.203369                 7500.0               42.377045
# 2830         -752.699829                 7500.0               45.914223
# 2831         -617.340210                 7500.0               47.792023
# 2832         -605.020752                 7500.0               40.001568
#
#       summary._step  summary.val/iwlb  summary.α  summary._runtime  \
# 0            7500.0        881.660828        1.0             378.0
# 1            7500.0        893.204956        1.0             375.0
# 2            7500.0        882.272644        1.0             374.0
# 3            7500.0        842.843567        1.0             375.0
# 4            7500.0        857.521851        1.0             375.0
# ...             ...               ...        ...               ...
# 2828         7500.0               NaN        1.0             337.0
# 2829         7500.0               NaN        1.0             338.0
# 2830         7500.0               NaN        1.0             338.0
# 2831         7500.0               NaN        1.0             334.0
# 2832         7500.0               NaN        1.0             336.0
#
#       summary.best_val_ll  summary.val_reconstructions.size  \
# 0              898.150024                          161343.0
# 1              909.345825                          161353.0
# 2              897.235046                          161373.0
# 3              858.143250                          161731.0
# 4              873.665039                          161728.0
# ...                   ...                               ...
# 2828          1011.685425                          186766.0
# 2829           825.955933                          181735.0
# 2830           811.662109                          181811.0
# 2831           662.055542                          183362.0
# 2832           640.746948                          183538.0
#
#      summary.val_reconstructions._type  summary.val_reconstructions.width  \
# 0                           image-file                            16000.0
# 1                           image-file                            16000.0
# 2                           image-file                            16000.0
# 3                           image-file                            16000.0
# 4                           image-file                            16000.0
# ...                                ...                                ...
# 2828                        image-file                            16000.0
# 2829                        image-file                            16000.0
# 2830                        image-file                            16000.0
# 2831                        image-file                            16000.0
# 2832                        image-file                            16000.0
#
#      summary.val_reconstructions.format  summary.val_reconstructions.height  \
# 0                                   png                              1600.0
# 1                                   png                              1600.0
# 2                                   png                              1600.0
# 3                                   png                              1600.0
# 4                                   png                              1600.0
# ...                                 ...                                 ...
# 2828                                png                              1600.0
# 2829                                png                              1600.0
# 2830                                png                              1600.0
# 2831                                png                              1600.0
# 2832                                png                              1600.0
#
#                      summary.val_reconstructions.sha256  \
# 0     5fd2e4be0d9e47d41ffd3a69f0e4189fb9d8c72794d9c2...
# 1     62e5b127ec288a26d6e021f2093f83e2181be85ef1f0b2...
# 2     20f0f10ddd97e8bee24837836bff03a20cfb49b41aabcf...
# 3     488d1f4c0b246cff6ba35a710f5f17c3d94bb84cc3674d...
# 4     dbd6bc1abf1f09130a5c82f4fb4e8fff56d2201eca33c9...
# ...                                                 ...
# 2828  77f9af96e8d9ab7fdf5d219f4342c24e30df6b308ad302...
# 2829  a6bcd8335f17cdb7900bd0cf8704e0928a83a4c12b3702...
# 2830  4a2c5bff4d808162faa770a0b3cdfd1862c308e922b968...
# 2831  fbf1d7819fe5ef85b57ad1ce8be8e3b200237abc502a0d...
# 2832  0250c64b229847a61eb96377060796834f5d98b2aa5075...
#
#                        summary.val_reconstructions.path  \
# 0     media/images/val_reconstructions_7500_5fd2e4be...
# 1     media/images/val_reconstructions_7500_62e5b127...
# 2     media/images/val_reconstructions_7500_20f0f10d...
# 3     media/images/val_reconstructions_7500_488d1f4c...
# 4     media/images/val_reconstructions_7500_dbd6bc1a...
# ...                                                 ...
# 2828  media/images/val_reconstructions_7500_77f9af96...
# 2829  media/images/val_reconstructions_7500_a6bcd833...
# 2830  media/images/val_reconstructions_7500_4a2c5bff...
# 2831  media/images/val_reconstructions_7500_fbf1d781...
# 2832  media/images/val_reconstructions_7500_0250c64b...
#
#                       summary.best_prior_samples.sha256  \
# 0     42324203d49a5dd7b7055b5019901f1741466d3b1339ec...
# 1     be8a200d4ad37b476e1c43b244f0a63ceafc8295d7658d...
# 2     9aca781fc767b7d6b14c54e6d96e934d3ba93d3197f290...
# 3     441a173cf53166af9f5a7b98da7b00993a60c9f1ea4265...
# 4     f51d0872c7d7720b48213f75eb30716b2d5e61628c55cf...
# ...                                                 ...
# 2828  e07683e51f3eb3c5537686e73690dbbb8a6521124b32f9...
# 2829  a10f004dcd17da1118dc16c27b17aab78bfcf8a1b439cc...
# 2830  5c6968c26e1f17de905210cd3f1a5c3958ad5adca3ad67...
# 2831  6e4c60f46093870d22e1973a22d86fb2d8ff8aa9c56ba8...
# 2832  b81dcaa2d1e80408604659b7e19b4008553eb3837b4344...
#
#                         summary.best_prior_samples.path  \
# 0     media/images/best_prior_samples_summary_423242...
# 1     media/images/best_prior_samples_summary_be8a20...
# 2     media/images/best_prior_samples_summary_9aca78...
# 3     media/images/best_prior_samples_summary_441a17...
# 4     media/images/best_prior_samples_summary_f51d08...
# ...                                                 ...
# 2828  media/images/best_prior_samples_summary_e07683...
# 2829  media/images/best_prior_samples_summary_a10f00...
# 2830  media/images/best_prior_samples_summary_5c6968...
# 2831  media/images/best_prior_samples_summary_6e4c60...
# 2832  media/images/best_prior_samples_summary_b81dca...
#
#       summary.best_prior_samples.size summary.best_prior_samples._type  \
# 0                            109822.0                       image-file
# 1                            109534.0                       image-file
# 2                            109870.0                       image-file
# 3                            109832.0                       image-file
# 4                            109868.0                       image-file
# ...                               ...                              ...
# 2828                         109110.0                       image-file
# 2829                         110445.0                       image-file
# 2830                         110989.0                       image-file
# 2831                         112471.0                       image-file
# 2832                         112474.0                       image-file
#
#       summary.best_prior_samples.width summary.best_prior_samples.format  \
# 0                              16000.0                               png
# 1                              16000.0                               png
# 2                              16000.0                               png
# 3                              16000.0                               png
# 4                              16000.0                               png
# ...                                ...                               ...
# 2828                           16000.0                               png
# 2829                           16000.0                               png
# 2830                           16000.0                               png
# 2831                           16000.0                               png
# 2832                           16000.0                               png
#
#       summary.best_prior_samples.height  summary._wandb.runtime  \
# 0                                 800.0                  9665.0
# 1                                 800.0                  6051.0
# 2                                 800.0                  3342.0
# 3                                 800.0                  6053.0
# 4                                 800.0                  6055.0
# ...                                 ...                     ...
# 2828                              800.0                   338.0
# 2829                              800.0                   338.0
# 2830                              800.0                   339.0
# 2831                              800.0                   336.0
# 2832                              800.0                   337.0
#
#                              summary.prior_samples.path  \
# 0     media/images/prior_samples_7500_42324203d49a5d...
# 1     media/images/prior_samples_7500_be8a200d4ad37b...
# 2     media/images/prior_samples_7500_9aca781fc767b7...
# 3     media/images/prior_samples_7500_441a173cf53166...
# 4     media/images/prior_samples_7500_f51d0872c7d772...
# ...                                                 ...
# 2828  media/images/prior_samples_7500_e07683e51f3eb3...
# 2829  media/images/prior_samples_7500_a10f004dcd17da...
# 2830  media/images/prior_samples_7500_5c6968c26e1f17...
# 2831  media/images/prior_samples_7500_6e4c60f4609387...
# 2832  media/images/prior_samples_7500_b81dcaa2d1e804...
#
#       summary.prior_samples.size summary.prior_samples._type  \
# 0                       109822.0                  image-file
# 1                       109534.0                  image-file
# 2                       109870.0                  image-file
# 3                       109832.0                  image-file
# 4                       109868.0                  image-file
# ...                          ...                         ...
# 2828                    109110.0                  image-file
# 2829                    110445.0                  image-file
# 2830                    110989.0                  image-file
# 2831                    112471.0                  image-file
# 2832                    112474.0                  image-file
#
#       summary.prior_samples.width summary.prior_samples.format  \
# 0                         16000.0                          png
# 1                         16000.0                          png
# 2                         16000.0                          png
# 3                         16000.0                          png
# 4                         16000.0                          png
# ...                           ...                          ...
# 2828                      16000.0                          png
# 2829                      16000.0                          png
# 2830                      16000.0                          png
# 2831                      16000.0                          png
# 2832                      16000.0                          png
#
#       summary.prior_samples.height  \
# 0                            800.0
# 1                            800.0
# 2                            800.0
# 3                            800.0
# 4                            800.0
# ...                            ...
# 2828                         800.0
# 2829                         800.0
# 2830                         800.0
# 2831                         800.0
# 2832                         800.0
#
#                            summary.prior_samples.sha256  \
# 0     42324203d49a5dd7b7055b5019901f1741466d3b1339ec...
# 1     be8a200d4ad37b476e1c43b244f0a63ceafc8295d7658d...
# 2     9aca781fc767b7d6b14c54e6d96e934d3ba93d3197f290...
# 3     441a173cf53166af9f5a7b98da7b00993a60c9f1ea4265...
# 4     f51d0872c7d7720b48213f75eb30716b2d5e61628c55cf...
# ...                                                 ...
# 2828  e07683e51f3eb3c5537686e73690dbbb8a6521124b32f9...
# 2829  a10f004dcd17da1118dc16c27b17aab78bfcf8a1b439cc...
# 2830  5c6968c26e1f17de905210cd3f1a5c3958ad5adca3ad67...
# 2831  6e4c60f46093870d22e1973a22d86fb2d8ff8aa9c56ba8...
# 2832  b81dcaa2d1e80408604659b7e19b4008553eb3837b4344...
#
#       summary.val/p_q_H_cent  summary.best_val_q_η_ce  \
# 0                        NaN                      NaN
# 1                        NaN                      NaN
# 2                        NaN                      NaN
# 3                        NaN                      NaN
# 4                        NaN                      NaN
# ...                      ...                      ...
# 2828                     NaN                      NaN
# 2829                     NaN                      NaN
# 2830                     NaN                      NaN
# 2831                     NaN                      NaN
# 2832                     NaN                      NaN
#
#       summary.val/xhat_ll_unorm  summary.train/xhat_ll_unorm  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
# ...                         ...                          ...
# 2828                        NaN                          NaN
# 2829                        NaN                          NaN
# 2830                        NaN                          NaN
# 2831                        NaN                          NaN
# 2832                        NaN                          NaN
#
#       summary.val/q_η_ce  summary.val/xhat_ll  summary.train/η_kld  \
# 0                    NaN                  NaN                  NaN
# 1                    NaN                  NaN                  NaN
# 2                    NaN                  NaN                  NaN
# 3                    NaN                  NaN                  NaN
# 4                    NaN                  NaN                  NaN
# ...                  ...                  ...                  ...
# 2828                 NaN                  NaN                  NaN
# 2829                 NaN                  NaN                  NaN
# 2830                 NaN                  NaN                  NaN
# 2831                 NaN                  NaN                  NaN
# 2832                 NaN                  NaN                  NaN
#
#       summary.val/q_H_ent  summary.train/p_η_ce  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 2828                  NaN                   NaN
# 2829                  NaN                   NaN
# 2830                  NaN                   NaN
# 2831                  NaN                   NaN
# 2832                  NaN                   NaN
#
#       summary.best_val_xhat_ll_unorm  summary.σ  summary.val/η_kld  \
# 0                                NaN        NaN                NaN
# 1                                NaN        NaN                NaN
# 2                                NaN        NaN                NaN
# 3                                NaN        NaN                NaN
# 4                                NaN        NaN                NaN
# ...                              ...        ...                ...
# 2828                             NaN   0.135332                NaN
# 2829                             NaN   0.177140                NaN
# 2830                             NaN   0.179890                NaN
# 2831                             NaN   0.209894                NaN
# 2832                             NaN   0.211257                NaN
#
#       summary.best_val_q_H_ent  summary.best_val_p_q_H_cent  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ...                        ...                          ...
# 2828                       NaN                          NaN
# 2829                       NaN                          NaN
# 2830                       NaN                          NaN
# 2831                       NaN                          NaN
# 2832                       NaN                          NaN
#
#       summary.train/q_η_ce  summary.best_val_p_η_ce  summary.train/xhat_ll  \
# 0                      NaN                      NaN                    NaN
# 1                      NaN                      NaN                    NaN
# 2                      NaN                      NaN                    NaN
# 3                      NaN                      NaN                    NaN
# 4                      NaN                      NaN                    NaN
# ...                    ...                      ...                    ...
# 2828                   NaN                      NaN                    NaN
# 2829                   NaN                      NaN                    NaN
# 2830                   NaN                      NaN                    NaN
# 2831                   NaN                      NaN                    NaN
# 2832                   NaN                      NaN                    NaN
#
#       summary.train/ll_unorm  summary.best_val_η_kld  \
# 0                        NaN                     NaN
# 1                        NaN                     NaN
# 2                        NaN                     NaN
# 3                        NaN                     NaN
# 4                        NaN                     NaN
# ...                      ...                     ...
# 2828                     NaN                     NaN
# 2829                     NaN                     NaN
# 2830                     NaN                     NaN
# 2831                     NaN                     NaN
# 2832                     NaN                     NaN
#
#       summary.best_val_xhat_ll  summary.train/p_q_H_cent  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 2828                       NaN                       NaN
# 2829                       NaN                       NaN
# 2830                       NaN                       NaN
# 2831                       NaN                       NaN
# 2832                       NaN                       NaN
#
#       summary.best_val_ll_unorm  summary.val/p_η_ce  summary.val/ll_unorm  \
# 0                           NaN                 NaN                   NaN
# 1                           NaN                 NaN                   NaN
# 2                           NaN                 NaN                   NaN
# 3                           NaN                 NaN                   NaN
# 4                           NaN                 NaN                   NaN
# ...                         ...                 ...                   ...
# 2828                        NaN                 NaN                   NaN
# 2829                        NaN                 NaN                   NaN
# 2830                        NaN                 NaN                   NaN
# 2831                        NaN                 NaN                   NaN
# 2832                        NaN                 NaN                   NaN
#
#       summary.train/q_H_ent  config.α  config.β  config.γ  config.seed  \
# 0                       NaN         1        10         1            2
# 1                       NaN         1        10         1            2
# 2                       NaN         1        10         1            2
# 3                       NaN         1        10         1            2
# 4                       NaN         1        10         1            2
# ...                     ...       ...       ...       ...          ...
# 2828                    NaN         1        10         1            1
# 2829                    NaN         1        10         1            2
# 2830                    NaN         1        10         1            0
# 2831                    NaN         1        10         1            1
# 2832                    NaN         1        10         1            0
#
#      config.dataset                                     config.pp_eval  \
# 0             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 1             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 2             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 3             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 4             MNIST  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# ...             ...                                                ...
# 2828          MNIST  value_range(-1, 1)|random_rotate(-15, 15, fill...
# 2829          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2830          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2831          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
# 2832          MNIST  value_range(-1, 1)|random_rotate(0, 0, fill_va...
#
#                                         config.pp_train config.run_hais  \
# 0     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 1     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 2     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 3     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 4     value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# ...                                                 ...             ...
# 2828  value_range(-1, 1)|random_rotate(-15, 15, fill...             NaN
# 2829  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2830  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2831  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
# 2832  value_range(-1, 1)|random_rotate(0, 0, fill_va...             NaN
#
#      config.run_iwlb config.val_split  config.batch_size  config.eval_every  \
# 0               True    train[:10000]                512                500
# 1               True    train[:10000]                512                500
# 2               True    train[:10000]                512                500
# 3               True    train[:10000]                512                500
# 4               True    train[:10000]                512                500
# ...              ...              ...                ...                ...
# 2828             NaN    train[:10000]                512                500
# 2829             NaN    train[:10000]                512                500
# 2830             NaN    train[:10000]                512                500
# 2831             NaN    train[:10000]                512                500
# 2832             NaN    train[:10000]                512                500
#
#      config.model_name config.optim_name  config.total_steps  \
# 0                  VAE             adamw                7501
# 1                  VAE             adamw                7501
# 2                  VAE             adamw                7501
# 3                  VAE             adamw                7501
# 4                  VAE             adamw                7501
# ...                ...               ...                 ...
# 2828               VAE             adamw                7501
# 2829               VAE             adamw                7501
# 2830               VAE             adamw                7501
# 2831               VAE             adamw                7501
# 2832               VAE             adamw                7501
#
#       config.train_split config.learning_rate  config.batch_size_eval  \
# 0     train[10000:60000]               0.0001                   128.0
# 1     train[10000:60000]               0.0001                   128.0
# 2     train[10000:60000]               0.0001                   128.0
# 3     train[10000:60000]               0.0001                   128.0
# 4     train[10000:60000]               0.0001                   128.0
# ...                  ...                  ...                     ...
# 2828  train[10000:20000]               0.0001                     NaN
# 2829  train[10000:50000]               0.0001                     NaN
# 2830  train[10000:50000]               0.0001                     NaN
# 2831  train[10000:30000]               0.0001                     NaN
# 2832  train[10000:30000]               0.0001                     NaN
#
#            config.lr_schedule_name config.β_schedule_name  \
# 0     warmup_cosine_decay_schedule  cosine_decay_schedule
# 1     warmup_cosine_decay_schedule  cosine_decay_schedule
# 2     warmup_cosine_decay_schedule  cosine_decay_schedule
# 3     warmup_cosine_decay_schedule  cosine_decay_schedule
# 4     warmup_cosine_decay_schedule  cosine_decay_schedule
# ...                            ...                    ...
# 2828  warmup_cosine_decay_schedule  cosine_decay_schedule
# 2829  warmup_cosine_decay_schedule  cosine_decay_schedule
# 2830  warmup_cosine_decay_schedule  cosine_decay_schedule
# 2831  warmup_cosine_decay_schedule  cosine_decay_schedule
# 2832  warmup_cosine_decay_schedule  cosine_decay_schedule
#
#       config.repeat_after_batch  config.shuffle_buffer_size  \
# 0                          True                       50000
# 1                          True                       50000
# 2                          True                       50000
# 3                          True                       50000
# 4                          True                       50000
# ...                         ...                         ...
# 2828                       True                       50000
# 2829                       True                       50000
# 2830                       True                       50000
# 2831                       True                       50000
# 2832                       True                       50000
#
#       config.hais.num_steps  config.hais.step_size  config.hais.num_chains  \
# 0                     100.0                  0.010                   200.0
# 1                      60.0                  0.010                   200.0
# 2                      30.0                  0.010                   200.0
# 3                      60.0                  0.008                   200.0
# 4                      60.0                  0.005                   200.0
# ...                     ...                    ...                     ...
# 2828                    NaN                    NaN                     NaN
# 2829                    NaN                    NaN                     NaN
# 2830                    NaN                    NaN                     NaN
# 2831                    NaN                    NaN                     NaN
# 2832                    NaN                    NaN                     NaN
#
#       config.hais.num_leapfrog_steps  config.iwlb.num_samples  \
# 0                                2.0                    100.0
# 1                                2.0                    100.0
# 2                                2.0                    100.0
# 3                                2.0                    100.0
# 4                                2.0                    100.0
# ...                              ...                      ...
# 2828                             NaN                      NaN
# 2829                             NaN                      NaN
# 2830                             NaN                      NaN
# 2831                             NaN                      NaN
# 2832                             NaN                      NaN
#
#      config.model.X_given_Z.conv_dims config.model.X_given_Z.dense_dims  \
# 0                      [256, 128, 64]                             [256]
# 1                      [256, 128, 64]                             [256]
# 2                      [256, 128, 64]                             [256]
# 3                      [256, 128, 64]                             [256]
# 4                      [256, 128, 64]                             [256]
# ...                               ...                               ...
# 2828                   [256, 128, 64]                             [256]
# 2829                   [256, 128, 64]                             [256]
# 2830                   [256, 128, 64]                             [256]
# 2831                   [256, 128, 64]                             [256]
# 2832                   [256, 128, 64]                             [256]
#
#       config.model.X_given_Z.max_2strides config.model.Z_given_X.conv_dims  \
# 0                                     2.0                   [64, 128, 256]
# 1                                     2.0                   [64, 128, 256]
# 2                                     2.0                   [64, 128, 256]
# 3                                     2.0                   [64, 128, 256]
# 4                                     2.0                   [64, 128, 256]
# ...                                   ...                              ...
# 2828                                  NaN                   [64, 128, 256]
# 2829                                  NaN                   [64, 128, 256]
# 2830                                  NaN                   [64, 128, 256]
# 2831                                  NaN                   [64, 128, 256]
# 2832                                  NaN                   [64, 128, 256]
#
#      config.model.Z_given_X.dense_dims  config.model.Z_given_X.max_2strides  \
# 0                                [256]                                  2.0
# 1                                [256]                                  2.0
# 2                                [256]                                  2.0
# 3                                [256]                                  2.0
# 4                                [256]                                  2.0
# ...                                ...                                  ...
# 2828                             [256]                                  NaN
# 2829                             [256]                                  NaN
# 2830                             [256]                                  NaN
# 2831                             [256]                                  NaN
# 2832                             [256]                                  NaN
#
#       config.model.latent_dim  config.optim.weight_decay  \
# 0                          16                     0.0001
# 1                          16                     0.0001
# 2                          16                     0.0001
# 3                          16                     0.0001
# 4                          16                     0.0001
# ...                       ...                        ...
# 2828                      128                     0.0001
# 2829                      128                     0.0001
# 2830                      128                     0.0001
# 2831                      128                     0.0001
# 2832                      128                     0.0001
#
#       config.lr_schedule.end_value  config.lr_schedule.peak_value  \
# 0                           0.0001                          0.001
# 1                           0.0001                          0.001
# 2                           0.0001                          0.001
# 3                           0.0001                          0.001
# 4                           0.0001                          0.001
# ...                            ...                            ...
# 2828                        0.0001                          0.001
# 2829                        0.0001                          0.001
# 2830                        0.0001                          0.001
# 2831                        0.0001                          0.001
# 2832                        0.0001                          0.001
#
#       config.lr_schedule.decay_steps  config.lr_schedule.warmup_steps  \
# 0                             7501.0                            750.0
# 1                             7501.0                            750.0
# 2                             7501.0                            750.0
# 3                             7501.0                            750.0
# 4                             7501.0                            750.0
# ...                              ...                              ...
# 2828                          7501.0                            750.0
# 2829                          7501.0                            750.0
# 2830                          7501.0                            750.0
# 2831                          7501.0                            750.0
# 2832                          7501.0                            750.0
#
#       config.β_schedule.alpha  config.β_schedule.decay_steps config.optim  \
# 0                         0.1                           7501          NaN
# 1                         0.1                           7501          NaN
# 2                         0.1                           7501          NaN
# 3                         0.1                           7501          NaN
# 4                         0.1                           7501          NaN
# ...                       ...                            ...          ...
# 2828                      0.1                           7501          NaN
# 2829                      0.1                           7501          NaN
# 2830                      0.1                           7501          NaN
# 2831                      0.1                           7501          NaN
# 2832                      0.1                           7501          NaN
#
#       config.reset_step config.lr_schedule config.partition_fn  \
# 0                   NaN                NaN                 NaN
# 1                   NaN                NaN                 NaN
# 2                   NaN                NaN                 NaN
# 3                   NaN                NaN                 NaN
# 4                   NaN                NaN                 NaN
# ...                 ...                ...                 ...
# 2828                NaN                NaN                 NaN
# 2829                NaN                NaN                 NaN
# 2830                NaN                NaN                 NaN
# 2831                NaN                NaN                 NaN
# 2832                NaN                NaN                 NaN
#
#       config.β_end_value  config.γ_end_value config.partition_names  \
# 0                    NaN                 NaN                    NaN
# 1                    NaN                 NaN                    NaN
# 2                    NaN                 NaN                    NaN
# 3                    NaN                 NaN                    NaN
# 4                    NaN                 NaN                    NaN
# ...                  ...                 ...                    ...
# 2828                 NaN                 NaN                    NaN
# 2829                 NaN                 NaN                    NaN
# 2830                 NaN                 NaN                    NaN
# 2831                 NaN                 NaN                    NaN
# 2832                 NaN                 NaN                    NaN
#
#      config.β_schedule_half config.γ_schedule_half config.γ_schedule_name  \
# 0                       NaN                    NaN                    NaN
# 1                       NaN                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                       NaN                    NaN                    NaN
# ...                     ...                    ...                    ...
# 2828                    NaN                    NaN                    NaN
# 2829                    NaN                    NaN                    NaN
# 2830                    NaN                    NaN                    NaN
# 2831                    NaN                    NaN                    NaN
# 2832                    NaN                    NaN                    NaN
#
#      config.lr_schedule_halfs config.model.bounds config.model.offset  \
# 0                         NaN                 NaN                 NaN
# 1                         NaN                 NaN                 NaN
# 2                         NaN                 NaN                 NaN
# 3                         NaN                 NaN                 NaN
# 4                         NaN                 NaN                 NaN
# ...                       ...                 ...                 ...
# 2828                      NaN                 NaN                 NaN
# 2829                      NaN                 NaN                 NaN
# 2830                      NaN                 NaN                 NaN
# 2831                      NaN                 NaN                 NaN
# 2832                      NaN                 NaN                 NaN
#
#      config.model.Η_given_X.base.conv_dims  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 2828                                   NaN
# 2829                                   NaN
# 2830                                   NaN
# 2831                                   NaN
# 2832                                   NaN
#
#      config.model.Η_given_X.base.dense_dims  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 2828                                    NaN
# 2829                                    NaN
# 2830                                    NaN
# 2831                                    NaN
# 2832                                    NaN
#
#       config.model.Η_given_X.base.dropout_rate  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 2828                                       NaN
# 2829                                       NaN
# 2830                                       NaN
# 2831                                       NaN
# 2832                                       NaN
#
#      config.model.Η_given_X.trunk.conv_dims  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 2828                                    NaN
# 2829                                    NaN
# 2830                                    NaN
# 2831                                    NaN
# 2832                                    NaN
#
#      config.model.Η_given_X.trunk.dense_dims  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 2828                                     NaN
# 2829                                     NaN
# 2830                                     NaN
# 2831                                     NaN
# 2832                                     NaN
#
#       config.model.Η_given_X.trunk.dropout_rate  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2828                                        NaN
# 2829                                        NaN
# 2830                                        NaN
# 2831                                        NaN
# 2832                                        NaN
#
#       config.model.Η_given_X.num_bins  config.model.Η_given_X.num_layers  \
# 0                                 NaN                                NaN
# 1                                 NaN                                NaN
# 2                                 NaN                                NaN
# 3                                 NaN                                NaN
# 4                                 NaN                                NaN
# ...                               ...                                ...
# 2828                              NaN                                NaN
# 2829                              NaN                                NaN
# 2830                              NaN                                NaN
# 2831                              NaN                                NaN
# 2832                              NaN                                NaN
#
#      config.model.Η_given_X.conditioner.hidden_dims  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 2828                                            NaN
# 2829                                            NaN
# 2830                                            NaN
# 2831                                            NaN
# 2832                                            NaN
#
#       config.model.Η_given_X.conditioner.dropout_rate  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 2828                                              NaN
# 2829                                              NaN
# 2830                                              NaN
# 2831                                              NaN
# 2832                                              NaN
#
#      config.model.Xhat_given_Z.conv_dims config.model.Xhat_given_Z.dense_dims  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 2828                                 NaN                                  NaN
# 2829                                 NaN                                  NaN
# 2830                                 NaN                                  NaN
# 2831                                 NaN                                  NaN
# 2832                                 NaN                                  NaN
#
#      config.model.Z_given_Xhat.conv_dims config.model.Z_given_Xhat.dense_dims  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
# ...                                  ...                                  ...
# 2828                                 NaN                                  NaN
# 2829                                 NaN                                  NaN
# 2830                                 NaN                                  NaN
# 2831                                 NaN                                  NaN
# 2832                                 NaN                                  NaN
#
#      config.model.Η_given_Xhat.base.conv_dims  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 2828                                      NaN
# 2829                                      NaN
# 2830                                      NaN
# 2831                                      NaN
# 2832                                      NaN
#
#      config.model.Η_given_Xhat.base.dense_dims  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 2828                                       NaN
# 2829                                       NaN
# 2830                                       NaN
# 2831                                       NaN
# 2832                                       NaN
#
#       config.model.Η_given_Xhat.base.dropout_rate  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 2828                                          NaN
# 2829                                          NaN
# 2830                                          NaN
# 2831                                          NaN
# 2832                                          NaN
#
#      config.model.Η_given_Xhat.trunk.conv_dims  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 2828                                       NaN
# 2829                                       NaN
# 2830                                       NaN
# 2831                                       NaN
# 2832                                       NaN
#
#      config.model.Η_given_Xhat.trunk.dense_dims  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2828                                        NaN
# 2829                                        NaN
# 2830                                        NaN
# 2831                                        NaN
# 2832                                        NaN
#
#       config.model.Η_given_Xhat.trunk.dropout_rate  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 2828                                           NaN
# 2829                                           NaN
# 2830                                           NaN
# 2831                                           NaN
# 2832                                           NaN
#
#       config.model.Η_given_Xhat.num_bins  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 2828                                 NaN
# 2829                                 NaN
# 2830                                 NaN
# 2831                                 NaN
# 2832                                 NaN
#
#       config.model.Η_given_Xhat.num_layers  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 2828                                   NaN
# 2829                                   NaN
# 2830                                   NaN
# 2831                                   NaN
# 2832                                   NaN
#
#      config.model.Η_given_Xhat.conditioner.hidden_dims  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 2828                                               NaN
# 2829                                               NaN
# 2830                                               NaN
# 2831                                               NaN
# 2832                                               NaN
#
#       config.model.Η_given_Xhat.conditioner.dropout_rate  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2828                                                NaN
# 2829                                                NaN
# 2830                                                NaN
# 2831                                                NaN
# 2832                                                NaN
#
#       config.γ_schedule.alpha  config.γ_schedule.decay_steps
# 0                         NaN                            NaN
# 1                         NaN                            NaN
# 2                         NaN                            NaN
# 3                         NaN                            NaN
# 4                         NaN                            NaN
# ...                       ...                            ...
# 2828                      NaN                            NaN
# 2829                      NaN                            NaN
# 2830                      NaN                            NaN
# 2831                      NaN                            NaN
# 2832                      NaN                            NaN
#
# [2833 rows x 155 columns]

# %%
# take only completed runs
df_filtered = df_expanded[df_expanded['state'] == 'finished']

# take only runs with certain tags
tags_to_keep = ['hais_sweep']
df_filtered = df_filtered[df_filtered['tags'].apply(lambda x: all(tag in x for tag in tags_to_keep))]

# take only runs without certain tags
tags_to_remove = ['hidden']
df_filtered = df_filtered[~df_filtered['tags'].apply(lambda x: any(tag in x for tag in tags_to_remove))]


df_filtered
# Out:
#                      name                       tags        id     state  \
# 0    royal-butterfly-2833  [hais_sweep, seeds, test]  xu8mwy4d  finished
# 1       pretty-night-2829  [hais_sweep, seeds, test]  x0rukt8r  finished
# 2       laced-flower-2829  [hais_sweep, seeds, test]  2fmdgudf  finished
# 3       gallant-snow-2829  [hais_sweep, seeds, test]  235prfk6  finished
# 4      ethereal-snow-2829  [hais_sweep, seeds, test]  1k0bukun  finished
# ..                    ...                        ...       ...       ...
# 209     proud-puddle-2622         [hais_sweep, test]  2sjzalae  finished
# 210     whole-cherry-2622         [hais_sweep, test]  1cbptsqy  finished
# 211    decent-plasma-2622         [hais_sweep, test]  14jwnx0q  finished
# 212    valiant-totem-2621         [hais_sweep, test]  odigcohz  finished
# 213     fresh-cosmos-2620         [hais_sweep, test]  2zxcnbgq  finished
#
#      summary.β  summary.val/ll  summary.val/z_kld  summary.best_val_iwlb  \
# 0          1.0      898.150024          40.811390             881.660828
# 1          1.0      909.345825          41.566097             893.204956
# 2          1.0      897.235046          39.994659             882.272644
# 3          1.0      858.143250          39.474514             842.843567
# 4          1.0      873.665039          41.046291             857.521851
# ..         ...             ...                ...                    ...
# 209        1.0      869.291870          41.507393             853.530640
# 210        1.0      900.197571          41.294960             884.478271
# 211        1.0      896.482971          40.741451             881.541626
# 212        1.0      915.649963          41.462322             900.531860
# 213        1.0      932.982727          42.563259             916.910645
#
#      summary.best_val_loss  summary.train/ll  summary.val/elbo  \
# 0              -857.338745        898.181763        857.338745
# 1              -867.779846        917.110229        867.779846
# 2              -857.240356        903.086914        857.240356
# 3              -818.668640        861.637878        818.668640
# 4              -832.618652        877.388916        832.618652
# ..                     ...               ...               ...
# 209            -827.784363        867.238892        827.784363
# 210            -858.902649        895.578613        858.902649
# 211            -855.741455        891.036133        855.741455
# 212            -874.187622        912.548828        874.187622
# 213            -890.419434        929.540894        890.419434
#
#      summary.train/elbo  summary.train/z_kld  summary.γ  summary.σ_vae  \
# 0            857.291504            40.890144        1.0       0.153523
# 1            875.469971            41.640083        1.0       0.151608
# 2            863.153381            39.933468        1.0       0.155986
# 3            822.100586            39.537228        1.0       0.159109
# 4            836.291687            41.097160        1.0       0.155527
# ..                  ...                  ...        ...            ...
# 209          826.651306            40.587486        1.0       0.156826
# 210          855.247742            40.330788        1.0       0.153537
# 211          851.130493            39.905514        1.0       0.155063
# 212          871.873901            40.674809        1.0       0.152427
# 213          887.837585            41.703194        1.0       0.149226
#
#      summary.hais_mll  summary.learing_rate  summary.best_val_elbo  \
# 0          830.242615                0.0001             857.338745
# 1         1177.353271                0.0001             867.779846
# 2         3166.605469                0.0001             857.240356
# 3          798.265808                0.0001             818.668640
# 4         2831.162109                0.0001             832.618652
# ..                ...                   ...                    ...
# 209      36715.187500                0.0001             827.784363
# 210      38230.792969                0.0001             858.902649
# 211      25257.800781                0.0001             855.741455
# 212      26548.990234                0.0001             874.187622
# 213      -2385.280029                0.0001             890.419434
#
#      summary._timestamp  summary.val/loss  summary.train/loss  \
# 0          1.686826e+09       -857.338745         -857.291504
# 1          1.686826e+09       -867.779846         -875.469971
# 2          1.686826e+09       -857.240356         -863.153381
# 3          1.686826e+09       -818.668640         -822.100586
# 4          1.686826e+09       -832.618652         -836.291687
# ..                  ...               ...                 ...
# 209        1.686658e+09       -827.784363         -826.651306
# 210        1.686658e+09       -858.902649         -855.247742
# 211        1.686658e+09       -855.741455         -851.130493
# 212        1.686658e+09       -874.187622         -871.873901
# 213        1.686658e+09       -890.419434         -887.837585
#
#      summary.best_val_step  summary.best_val_z_kld  summary._step  \
# 0                   7500.0               40.811390         7500.0
# 1                   7500.0               41.566097         7500.0
# 2                   7500.0               39.994659         7500.0
# 3                   7500.0               39.474514         7500.0
# 4                   7500.0               41.046291         7500.0
# ..                     ...                     ...            ...
# 209                 7500.0               41.507393         7500.0
# 210                 7500.0               41.294960         7500.0
# 211                 7500.0               40.741451         7500.0
# 212                 7500.0               41.462322         7500.0
# 213                 7500.0               42.563259         7500.0
#
#      summary.val/iwlb  summary.α  summary._runtime  summary.best_val_ll  \
# 0          881.660828        1.0             378.0           898.150024
# 1          893.204956        1.0             375.0           909.345825
# 2          882.272644        1.0             374.0           897.235046
# 3          842.843567        1.0             375.0           858.143250
# 4          857.521851        1.0             375.0           873.665039
# ..                ...        ...               ...                  ...
# 209        853.530640        1.0             444.0           869.291870
# 210        884.478271        1.0             443.0           900.197571
# 211        881.541626        1.0             444.0           896.482971
# 212        900.531860        1.0             444.0           915.649963
# 213        916.910645        1.0             441.0           932.982727
#
#      summary.val_reconstructions.size summary.val_reconstructions._type  \
# 0                            161343.0                        image-file
# 1                            161353.0                        image-file
# 2                            161373.0                        image-file
# 3                            161731.0                        image-file
# 4                            161728.0                        image-file
# ..                                ...                               ...
# 209                          161949.0                        image-file
# 210                          161527.0                        image-file
# 211                          161564.0                        image-file
# 212                          161370.0                        image-file
# 213                          161371.0                        image-file
#
#      summary.val_reconstructions.width summary.val_reconstructions.format  \
# 0                              16000.0                                png
# 1                              16000.0                                png
# 2                              16000.0                                png
# 3                              16000.0                                png
# 4                              16000.0                                png
# ..                                 ...                                ...
# 209                            16000.0                                png
# 210                            16000.0                                png
# 211                            16000.0                                png
# 212                            16000.0                                png
# 213                            16000.0                                png
#
#      summary.val_reconstructions.height  \
# 0                                1600.0
# 1                                1600.0
# 2                                1600.0
# 3                                1600.0
# 4                                1600.0
# ..                                  ...
# 209                              1600.0
# 210                              1600.0
# 211                              1600.0
# 212                              1600.0
# 213                              1600.0
#
#                     summary.val_reconstructions.sha256  \
# 0    5fd2e4be0d9e47d41ffd3a69f0e4189fb9d8c72794d9c2...
# 1    62e5b127ec288a26d6e021f2093f83e2181be85ef1f0b2...
# 2    20f0f10ddd97e8bee24837836bff03a20cfb49b41aabcf...
# 3    488d1f4c0b246cff6ba35a710f5f17c3d94bb84cc3674d...
# 4    dbd6bc1abf1f09130a5c82f4fb4e8fff56d2201eca33c9...
# ..                                                 ...
# 209  7b74c9d91be286b47b830cdc50b9b2c7868f3f419c14bd...
# 210  2118ac9378a0acd04aab46002bdfdb875f9befbd256896...
# 211  3d4f4c096da04575d400cbcfe1e51ddb06489201866e1a...
# 212  bf679d4ce5391e56080a8e7ab368d7320419688254ef43...
# 213  432f83795610bce55ee971aecf74992626ba198ff6ece1...
#
#                       summary.val_reconstructions.path  \
# 0    media/images/val_reconstructions_7500_5fd2e4be...
# 1    media/images/val_reconstructions_7500_62e5b127...
# 2    media/images/val_reconstructions_7500_20f0f10d...
# 3    media/images/val_reconstructions_7500_488d1f4c...
# 4    media/images/val_reconstructions_7500_dbd6bc1a...
# ..                                                 ...
# 209  media/images/val_reconstructions_7500_7b74c9d9...
# 210  media/images/val_reconstructions_7500_2118ac93...
# 211  media/images/val_reconstructions_7500_3d4f4c09...
# 212  media/images/val_reconstructions_7500_bf679d4c...
# 213  media/images/val_reconstructions_7500_432f8379...
#
#                      summary.best_prior_samples.sha256  \
# 0    42324203d49a5dd7b7055b5019901f1741466d3b1339ec...
# 1    be8a200d4ad37b476e1c43b244f0a63ceafc8295d7658d...
# 2    9aca781fc767b7d6b14c54e6d96e934d3ba93d3197f290...
# 3    441a173cf53166af9f5a7b98da7b00993a60c9f1ea4265...
# 4    f51d0872c7d7720b48213f75eb30716b2d5e61628c55cf...
# ..                                                 ...
# 209  1d0ebdb976a7c7b0928ccbfe117438daefd0d84473a32c...
# 210  35e5007661b3d29e4f5f096d1e485a9a0a4ea652a2bb0e...
# 211  da412372df6a33d6caf7e14e2f0c4cfb5cd2f9ef2fa1ef...
# 212  61c0cf8bacd0d0671780c1655e2f82ae71bf3d0e204737...
# 213  5c7ff0d6b8b8e89fcb6fafa53bf855f9d9341b42670cbd...
#
#                        summary.best_prior_samples.path  \
# 0    media/images/best_prior_samples_summary_423242...
# 1    media/images/best_prior_samples_summary_be8a20...
# 2    media/images/best_prior_samples_summary_9aca78...
# 3    media/images/best_prior_samples_summary_441a17...
# 4    media/images/best_prior_samples_summary_f51d08...
# ..                                                 ...
# 209  media/images/best_prior_samples_summary_1d0ebd...
# 210  media/images/best_prior_samples_summary_35e500...
# 211  media/images/best_prior_samples_summary_da4123...
# 212  media/images/best_prior_samples_summary_61c0cf...
# 213  media/images/best_prior_samples_summary_5c7ff0...
#
#      summary.best_prior_samples.size summary.best_prior_samples._type  \
# 0                           109822.0                       image-file
# 1                           109534.0                       image-file
# 2                           109870.0                       image-file
# 3                           109832.0                       image-file
# 4                           109868.0                       image-file
# ..                               ...                              ...
# 209                         110342.0                       image-file
# 210                         110586.0                       image-file
# 211                         110359.0                       image-file
# 212                         110143.0                       image-file
# 213                         109865.0                       image-file
#
#      summary.best_prior_samples.width summary.best_prior_samples.format  \
# 0                             16000.0                               png
# 1                             16000.0                               png
# 2                             16000.0                               png
# 3                             16000.0                               png
# 4                             16000.0                               png
# ..                                ...                               ...
# 209                           16000.0                               png
# 210                           16000.0                               png
# 211                           16000.0                               png
# 212                           16000.0                               png
# 213                           16000.0                               png
#
#      summary.best_prior_samples.height  summary._wandb.runtime  \
# 0                                800.0                  9665.0
# 1                                800.0                  6051.0
# 2                                800.0                  3342.0
# 3                                800.0                  6053.0
# 4                                800.0                  6055.0
# ..                                 ...                     ...
# 209                              800.0                   640.0
# 210                              800.0                   809.0
# 211                              800.0                   811.0
# 212                              800.0                   640.0
# 213                              800.0                   639.0
#
#                             summary.prior_samples.path  \
# 0    media/images/prior_samples_7500_42324203d49a5d...
# 1    media/images/prior_samples_7500_be8a200d4ad37b...
# 2    media/images/prior_samples_7500_9aca781fc767b7...
# 3    media/images/prior_samples_7500_441a173cf53166...
# 4    media/images/prior_samples_7500_f51d0872c7d772...
# ..                                                 ...
# 209  media/images/prior_samples_7500_1d0ebdb976a7c7...
# 210  media/images/prior_samples_7500_35e5007661b3d2...
# 211  media/images/prior_samples_7500_da412372df6a33...
# 212  media/images/prior_samples_7500_61c0cf8bacd0d0...
# 213  media/images/prior_samples_7500_5c7ff0d6b8b8e8...
#
#      summary.prior_samples.size summary.prior_samples._type  \
# 0                      109822.0                  image-file
# 1                      109534.0                  image-file
# 2                      109870.0                  image-file
# 3                      109832.0                  image-file
# 4                      109868.0                  image-file
# ..                          ...                         ...
# 209                    110342.0                  image-file
# 210                    110586.0                  image-file
# 211                    110359.0                  image-file
# 212                    110143.0                  image-file
# 213                    109865.0                  image-file
#
#      summary.prior_samples.width summary.prior_samples.format  \
# 0                        16000.0                          png
# 1                        16000.0                          png
# 2                        16000.0                          png
# 3                        16000.0                          png
# 4                        16000.0                          png
# ..                           ...                          ...
# 209                      16000.0                          png
# 210                      16000.0                          png
# 211                      16000.0                          png
# 212                      16000.0                          png
# 213                      16000.0                          png
#
#      summary.prior_samples.height  \
# 0                           800.0
# 1                           800.0
# 2                           800.0
# 3                           800.0
# 4                           800.0
# ..                            ...
# 209                         800.0
# 210                         800.0
# 211                         800.0
# 212                         800.0
# 213                         800.0
#
#                           summary.prior_samples.sha256  \
# 0    42324203d49a5dd7b7055b5019901f1741466d3b1339ec...
# 1    be8a200d4ad37b476e1c43b244f0a63ceafc8295d7658d...
# 2    9aca781fc767b7d6b14c54e6d96e934d3ba93d3197f290...
# 3    441a173cf53166af9f5a7b98da7b00993a60c9f1ea4265...
# 4    f51d0872c7d7720b48213f75eb30716b2d5e61628c55cf...
# ..                                                 ...
# 209  1d0ebdb976a7c7b0928ccbfe117438daefd0d84473a32c...
# 210  35e5007661b3d29e4f5f096d1e485a9a0a4ea652a2bb0e...
# 211  da412372df6a33d6caf7e14e2f0c4cfb5cd2f9ef2fa1ef...
# 212  61c0cf8bacd0d0671780c1655e2f82ae71bf3d0e204737...
# 213  5c7ff0d6b8b8e89fcb6fafa53bf855f9d9341b42670cbd...
#
#      summary.val/p_q_H_cent  summary.best_val_q_η_ce  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
# ..                      ...                      ...
# 209                     NaN                      NaN
# 210                     NaN                      NaN
# 211                     NaN                      NaN
# 212                     NaN                      NaN
# 213                     NaN                      NaN
#
#      summary.val/xhat_ll_unorm  summary.train/xhat_ll_unorm  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# ..                         ...                          ...
# 209                        NaN                          NaN
# 210                        NaN                          NaN
# 211                        NaN                          NaN
# 212                        NaN                          NaN
# 213                        NaN                          NaN
#
#      summary.val/q_η_ce  summary.val/xhat_ll  summary.train/η_kld  \
# 0                   NaN                  NaN                  NaN
# 1                   NaN                  NaN                  NaN
# 2                   NaN                  NaN                  NaN
# 3                   NaN                  NaN                  NaN
# 4                   NaN                  NaN                  NaN
# ..                  ...                  ...                  ...
# 209                 NaN                  NaN                  NaN
# 210                 NaN                  NaN                  NaN
# 211                 NaN                  NaN                  NaN
# 212                 NaN                  NaN                  NaN
# 213                 NaN                  NaN                  NaN
#
#      summary.val/q_H_ent  summary.train/p_η_ce  \
# 0                    NaN                   NaN
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                    NaN                   NaN
# 4                    NaN                   NaN
# ..                   ...                   ...
# 209                  NaN                   NaN
# 210                  NaN                   NaN
# 211                  NaN                   NaN
# 212                  NaN                   NaN
# 213                  NaN                   NaN
#
#      summary.best_val_xhat_ll_unorm  summary.σ  summary.val/η_kld  \
# 0                               NaN        NaN                NaN
# 1                               NaN        NaN                NaN
# 2                               NaN        NaN                NaN
# 3                               NaN        NaN                NaN
# 4                               NaN        NaN                NaN
# ..                              ...        ...                ...
# 209                             NaN        NaN                NaN
# 210                             NaN        NaN                NaN
# 211                             NaN        NaN                NaN
# 212                             NaN        NaN                NaN
# 213                             NaN        NaN                NaN
#
#      summary.best_val_q_H_ent  summary.best_val_p_q_H_cent  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
# ..                        ...                          ...
# 209                       NaN                          NaN
# 210                       NaN                          NaN
# 211                       NaN                          NaN
# 212                       NaN                          NaN
# 213                       NaN                          NaN
#
#      summary.train/q_η_ce  summary.best_val_p_η_ce  summary.train/xhat_ll  \
# 0                     NaN                      NaN                    NaN
# 1                     NaN                      NaN                    NaN
# 2                     NaN                      NaN                    NaN
# 3                     NaN                      NaN                    NaN
# 4                     NaN                      NaN                    NaN
# ..                    ...                      ...                    ...
# 209                   NaN                      NaN                    NaN
# 210                   NaN                      NaN                    NaN
# 211                   NaN                      NaN                    NaN
# 212                   NaN                      NaN                    NaN
# 213                   NaN                      NaN                    NaN
#
#      summary.train/ll_unorm  summary.best_val_η_kld  summary.best_val_xhat_ll  \
# 0                       NaN                     NaN                       NaN
# 1                       NaN                     NaN                       NaN
# 2                       NaN                     NaN                       NaN
# 3                       NaN                     NaN                       NaN
# 4                       NaN                     NaN                       NaN
# ..                      ...                     ...                       ...
# 209                     NaN                     NaN                       NaN
# 210                     NaN                     NaN                       NaN
# 211                     NaN                     NaN                       NaN
# 212                     NaN                     NaN                       NaN
# 213                     NaN                     NaN                       NaN
#
#      summary.train/p_q_H_cent  summary.best_val_ll_unorm  summary.val/p_η_ce  \
# 0                         NaN                        NaN                 NaN
# 1                         NaN                        NaN                 NaN
# 2                         NaN                        NaN                 NaN
# 3                         NaN                        NaN                 NaN
# 4                         NaN                        NaN                 NaN
# ..                        ...                        ...                 ...
# 209                       NaN                        NaN                 NaN
# 210                       NaN                        NaN                 NaN
# 211                       NaN                        NaN                 NaN
# 212                       NaN                        NaN                 NaN
# 213                       NaN                        NaN                 NaN
#
#      summary.val/ll_unorm  summary.train/q_H_ent  config.α  config.β  \
# 0                     NaN                    NaN         1        10
# 1                     NaN                    NaN         1        10
# 2                     NaN                    NaN         1        10
# 3                     NaN                    NaN         1        10
# 4                     NaN                    NaN         1        10
# ..                    ...                    ...       ...       ...
# 209                   NaN                    NaN         1        10
# 210                   NaN                    NaN         1        10
# 211                   NaN                    NaN         1        10
# 212                   NaN                    NaN         1        10
# 213                   NaN                    NaN         1        10
#
#      config.γ  config.seed config.dataset  \
# 0           1            2          MNIST
# 1           1            2          MNIST
# 2           1            2          MNIST
# 3           1            2          MNIST
# 4           1            2          MNIST
# ..        ...          ...            ...
# 209         1            0          MNIST
# 210         1            0          MNIST
# 211         1            0          MNIST
# 212         1            0          MNIST
# 213         1            0          MNIST
#
#                                         config.pp_eval  \
# 0    value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 1    value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 2    value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 3    value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 4    value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# ..                                                 ...
# 209  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 210  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 211  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 212  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
# 213  value_range(-1, 1)|random_rotate(-0, 0, fill_v...
#
#                                        config.pp_train config.run_hais  \
# 0    value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 1    value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 2    value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 3    value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 4    value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# ..                                                 ...             ...
# 209  value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 210  value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 211  value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 212  value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
# 213  value_range(-1, 1)|random_rotate(-0, 0, fill_v...            True
#
#     config.run_iwlb config.val_split  config.batch_size  config.eval_every  \
# 0              True    train[:10000]                512                500
# 1              True    train[:10000]                512                500
# 2              True    train[:10000]                512                500
# 3              True    train[:10000]                512                500
# 4              True    train[:10000]                512                500
# ..              ...              ...                ...                ...
# 209            True    train[:10000]                512                500
# 210            True    train[:10000]                512                500
# 211            True    train[:10000]                512                500
# 212            True    train[:10000]                512                500
# 213            True    train[:10000]                512                500
#
#     config.model_name config.optim_name  config.total_steps  \
# 0                 VAE             adamw                7501
# 1                 VAE             adamw                7501
# 2                 VAE             adamw                7501
# 3                 VAE             adamw                7501
# 4                 VAE             adamw                7501
# ..                ...               ...                 ...
# 209               VAE             adamw                7501
# 210               VAE             adamw                7501
# 211               VAE             adamw                7501
# 212               VAE             adamw                7501
# 213               VAE             adamw                7501
#
#      config.train_split config.learning_rate  config.batch_size_eval  \
# 0    train[10000:60000]               0.0001                   128.0
# 1    train[10000:60000]               0.0001                   128.0
# 2    train[10000:60000]               0.0001                   128.0
# 3    train[10000:60000]               0.0001                   128.0
# 4    train[10000:60000]               0.0001                   128.0
# ..                  ...                  ...                     ...
# 209  train[10000:60000]               0.0001                   256.0
# 210  train[10000:60000]               0.0001                   256.0
# 211  train[10000:60000]               0.0001                   256.0
# 212  train[10000:60000]               0.0001                   256.0
# 213  train[10000:60000]               0.0001                   256.0
#
#           config.lr_schedule_name config.β_schedule_name  \
# 0    warmup_cosine_decay_schedule  cosine_decay_schedule
# 1    warmup_cosine_decay_schedule  cosine_decay_schedule
# 2    warmup_cosine_decay_schedule  cosine_decay_schedule
# 3    warmup_cosine_decay_schedule  cosine_decay_schedule
# 4    warmup_cosine_decay_schedule  cosine_decay_schedule
# ..                            ...                    ...
# 209  warmup_cosine_decay_schedule  cosine_decay_schedule
# 210  warmup_cosine_decay_schedule  cosine_decay_schedule
# 211  warmup_cosine_decay_schedule  cosine_decay_schedule
# 212  warmup_cosine_decay_schedule  cosine_decay_schedule
# 213  warmup_cosine_decay_schedule  cosine_decay_schedule
#
#      config.repeat_after_batch  config.shuffle_buffer_size  \
# 0                         True                       50000
# 1                         True                       50000
# 2                         True                       50000
# 3                         True                       50000
# 4                         True                       50000
# ..                         ...                         ...
# 209                       True                       50000
# 210                       True                       50000
# 211                       True                       50000
# 212                       True                       50000
# 213                       True                       50000
#
#      config.hais.num_steps  config.hais.step_size  config.hais.num_chains  \
# 0                    100.0                  0.010                   200.0
# 1                     60.0                  0.010                   200.0
# 2                     30.0                  0.010                   200.0
# 3                     60.0                  0.008                   200.0
# 4                     60.0                  0.005                   200.0
# ..                     ...                    ...                     ...
# 209                   30.0                  0.100                    10.0
# 210                  100.0                  0.100                    10.0
# 211                  100.0                  0.030                    10.0
# 212                   30.0                  0.030                    10.0
# 213                   30.0                  0.010                    10.0
#
#      config.hais.num_leapfrog_steps  config.iwlb.num_samples  \
# 0                               2.0                    100.0
# 1                               2.0                    100.0
# 2                               2.0                    100.0
# 3                               2.0                    100.0
# 4                               2.0                    100.0
# ..                              ...                      ...
# 209                             2.0                    100.0
# 210                             2.0                    100.0
# 211                             2.0                    100.0
# 212                             2.0                    100.0
# 213                             2.0                    100.0
#
#     config.model.X_given_Z.conv_dims config.model.X_given_Z.dense_dims  \
# 0                     [256, 128, 64]                             [256]
# 1                     [256, 128, 64]                             [256]
# 2                     [256, 128, 64]                             [256]
# 3                     [256, 128, 64]                             [256]
# 4                     [256, 128, 64]                             [256]
# ..                               ...                               ...
# 209                   [256, 128, 64]                             [256]
# 210                   [256, 128, 64]                             [256]
# 211                   [256, 128, 64]                             [256]
# 212                   [256, 128, 64]                             [256]
# 213                   [256, 128, 64]                             [256]
#
#      config.model.X_given_Z.max_2strides config.model.Z_given_X.conv_dims  \
# 0                                    2.0                   [64, 128, 256]
# 1                                    2.0                   [64, 128, 256]
# 2                                    2.0                   [64, 128, 256]
# 3                                    2.0                   [64, 128, 256]
# 4                                    2.0                   [64, 128, 256]
# ..                                   ...                              ...
# 209                                  2.0                   [64, 128, 256]
# 210                                  2.0                   [64, 128, 256]
# 211                                  2.0                   [64, 128, 256]
# 212                                  2.0                   [64, 128, 256]
# 213                                  2.0                   [64, 128, 256]
#
#     config.model.Z_given_X.dense_dims  config.model.Z_given_X.max_2strides  \
# 0                               [256]                                  2.0
# 1                               [256]                                  2.0
# 2                               [256]                                  2.0
# 3                               [256]                                  2.0
# 4                               [256]                                  2.0
# ..                                ...                                  ...
# 209                             [256]                                  2.0
# 210                             [256]                                  2.0
# 211                             [256]                                  2.0
# 212                             [256]                                  2.0
# 213                             [256]                                  2.0
#
#      config.model.latent_dim  config.optim.weight_decay  \
# 0                         16                     0.0001
# 1                         16                     0.0001
# 2                         16                     0.0001
# 3                         16                     0.0001
# 4                         16                     0.0001
# ..                       ...                        ...
# 209                       16                     0.0001
# 210                       16                     0.0001
# 211                       16                     0.0001
# 212                       16                     0.0001
# 213                       16                     0.0001
#
#      config.lr_schedule.end_value  config.lr_schedule.peak_value  \
# 0                          0.0001                          0.001
# 1                          0.0001                          0.001
# 2                          0.0001                          0.001
# 3                          0.0001                          0.001
# 4                          0.0001                          0.001
# ..                            ...                            ...
# 209                        0.0001                          0.001
# 210                        0.0001                          0.001
# 211                        0.0001                          0.001
# 212                        0.0001                          0.001
# 213                        0.0001                          0.001
#
#      config.lr_schedule.decay_steps  config.lr_schedule.warmup_steps  \
# 0                            7501.0                            750.0
# 1                            7501.0                            750.0
# 2                            7501.0                            750.0
# 3                            7501.0                            750.0
# 4                            7501.0                            750.0
# ..                              ...                              ...
# 209                          7501.0                            750.0
# 210                          7501.0                            750.0
# 211                          7501.0                            750.0
# 212                          7501.0                            750.0
# 213                          7501.0                            750.0
#
#      config.β_schedule.alpha  config.β_schedule.decay_steps config.optim  \
# 0                        0.1                           7501          NaN
# 1                        0.1                           7501          NaN
# 2                        0.1                           7501          NaN
# 3                        0.1                           7501          NaN
# 4                        0.1                           7501          NaN
# ..                       ...                            ...          ...
# 209                      0.1                           7501          NaN
# 210                      0.1                           7501          NaN
# 211                      0.1                           7501          NaN
# 212                      0.1                           7501          NaN
# 213                      0.1                           7501          NaN
#
#      config.reset_step config.lr_schedule config.partition_fn  \
# 0                  NaN                NaN                 NaN
# 1                  NaN                NaN                 NaN
# 2                  NaN                NaN                 NaN
# 3                  NaN                NaN                 NaN
# 4                  NaN                NaN                 NaN
# ..                 ...                ...                 ...
# 209                NaN                NaN                 NaN
# 210                NaN                NaN                 NaN
# 211                NaN                NaN                 NaN
# 212                NaN                NaN                 NaN
# 213                NaN                NaN                 NaN
#
#      config.β_end_value  config.γ_end_value config.partition_names  \
# 0                   NaN                 NaN                    NaN
# 1                   NaN                 NaN                    NaN
# 2                   NaN                 NaN                    NaN
# 3                   NaN                 NaN                    NaN
# 4                   NaN                 NaN                    NaN
# ..                  ...                 ...                    ...
# 209                 NaN                 NaN                    NaN
# 210                 NaN                 NaN                    NaN
# 211                 NaN                 NaN                    NaN
# 212                 NaN                 NaN                    NaN
# 213                 NaN                 NaN                    NaN
#
#     config.β_schedule_half config.γ_schedule_half config.γ_schedule_name  \
# 0                      NaN                    NaN                    NaN
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3                      NaN                    NaN                    NaN
# 4                      NaN                    NaN                    NaN
# ..                     ...                    ...                    ...
# 209                    NaN                    NaN                    NaN
# 210                    NaN                    NaN                    NaN
# 211                    NaN                    NaN                    NaN
# 212                    NaN                    NaN                    NaN
# 213                    NaN                    NaN                    NaN
#
#     config.lr_schedule_halfs config.model.bounds config.model.offset  \
# 0                        NaN                 NaN                 NaN
# 1                        NaN                 NaN                 NaN
# 2                        NaN                 NaN                 NaN
# 3                        NaN                 NaN                 NaN
# 4                        NaN                 NaN                 NaN
# ..                       ...                 ...                 ...
# 209                      NaN                 NaN                 NaN
# 210                      NaN                 NaN                 NaN
# 211                      NaN                 NaN                 NaN
# 212                      NaN                 NaN                 NaN
# 213                      NaN                 NaN                 NaN
#
#     config.model.Η_given_X.base.conv_dims  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 209                                   NaN
# 210                                   NaN
# 211                                   NaN
# 212                                   NaN
# 213                                   NaN
#
#     config.model.Η_given_X.base.dense_dims  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 209                                    NaN
# 210                                    NaN
# 211                                    NaN
# 212                                    NaN
# 213                                    NaN
#
#      config.model.Η_given_X.base.dropout_rate  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 209                                       NaN
# 210                                       NaN
# 211                                       NaN
# 212                                       NaN
# 213                                       NaN
#
#     config.model.Η_given_X.trunk.conv_dims  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 209                                    NaN
# 210                                    NaN
# 211                                    NaN
# 212                                    NaN
# 213                                    NaN
#
#     config.model.Η_given_X.trunk.dense_dims  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ..                                      ...
# 209                                     NaN
# 210                                     NaN
# 211                                     NaN
# 212                                     NaN
# 213                                     NaN
#
#      config.model.Η_given_X.trunk.dropout_rate  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 209                                        NaN
# 210                                        NaN
# 211                                        NaN
# 212                                        NaN
# 213                                        NaN
#
#      config.model.Η_given_X.num_bins  config.model.Η_given_X.num_layers  \
# 0                                NaN                                NaN
# 1                                NaN                                NaN
# 2                                NaN                                NaN
# 3                                NaN                                NaN
# 4                                NaN                                NaN
# ..                               ...                                ...
# 209                              NaN                                NaN
# 210                              NaN                                NaN
# 211                              NaN                                NaN
# 212                              NaN                                NaN
# 213                              NaN                                NaN
#
#     config.model.Η_given_X.conditioner.hidden_dims  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 209                                            NaN
# 210                                            NaN
# 211                                            NaN
# 212                                            NaN
# 213                                            NaN
#
#      config.model.Η_given_X.conditioner.dropout_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 209                                              NaN
# 210                                              NaN
# 211                                              NaN
# 212                                              NaN
# 213                                              NaN
#
#     config.model.Xhat_given_Z.conv_dims config.model.Xhat_given_Z.dense_dims  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ..                                  ...                                  ...
# 209                                 NaN                                  NaN
# 210                                 NaN                                  NaN
# 211                                 NaN                                  NaN
# 212                                 NaN                                  NaN
# 213                                 NaN                                  NaN
#
#     config.model.Z_given_Xhat.conv_dims config.model.Z_given_Xhat.dense_dims  \
# 0                                   NaN                                  NaN
# 1                                   NaN                                  NaN
# 2                                   NaN                                  NaN
# 3                                   NaN                                  NaN
# 4                                   NaN                                  NaN
# ..                                  ...                                  ...
# 209                                 NaN                                  NaN
# 210                                 NaN                                  NaN
# 211                                 NaN                                  NaN
# 212                                 NaN                                  NaN
# 213                                 NaN                                  NaN
#
#     config.model.Η_given_Xhat.base.conv_dims  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 209                                      NaN
# 210                                      NaN
# 211                                      NaN
# 212                                      NaN
# 213                                      NaN
#
#     config.model.Η_given_Xhat.base.dense_dims  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 209                                       NaN
# 210                                       NaN
# 211                                       NaN
# 212                                       NaN
# 213                                       NaN
#
#      config.model.Η_given_Xhat.base.dropout_rate  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 209                                          NaN
# 210                                          NaN
# 211                                          NaN
# 212                                          NaN
# 213                                          NaN
#
#     config.model.Η_given_Xhat.trunk.conv_dims  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 209                                       NaN
# 210                                       NaN
# 211                                       NaN
# 212                                       NaN
# 213                                       NaN
#
#     config.model.Η_given_Xhat.trunk.dense_dims  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 209                                        NaN
# 210                                        NaN
# 211                                        NaN
# 212                                        NaN
# 213                                        NaN
#
#      config.model.Η_given_Xhat.trunk.dropout_rate  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ..                                            ...
# 209                                           NaN
# 210                                           NaN
# 211                                           NaN
# 212                                           NaN
# 213                                           NaN
#
#      config.model.Η_given_Xhat.num_bins  config.model.Η_given_Xhat.num_layers  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
# ..                                  ...                                   ...
# 209                                 NaN                                   NaN
# 210                                 NaN                                   NaN
# 211                                 NaN                                   NaN
# 212                                 NaN                                   NaN
# 213                                 NaN                                   NaN
#
#     config.model.Η_given_Xhat.conditioner.hidden_dims  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 209                                               NaN
# 210                                               NaN
# 211                                               NaN
# 212                                               NaN
# 213                                               NaN
#
#      config.model.Η_given_Xhat.conditioner.dropout_rate  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 209                                                NaN
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
#
#      config.γ_schedule.alpha  config.γ_schedule.decay_steps
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
# ..                       ...                            ...
# 209                      NaN                            NaN
# 210                      NaN                            NaN
# 211                      NaN                            NaN
# 212                      NaN                            NaN
# 213                      NaN                            NaN
#
# [154 rows x 155 columns]

# %%
tags_to_remove = ['seeds']
plot_df = df_filtered[~df_filtered['tags'].apply(lambda x: any(tag in x for tag in tags_to_remove))]

plot_df = plot_df[
    ['config.hais.num_chains', 'config.hais.num_steps', 'config.hais.step_size', 'summary.hais_mll', 'summary.best_val_elbo', 'summary.best_val_iwlb']
]

plot_df['mll_diff'] = (plot_df['summary.hais_mll'] - plot_df['summary.best_val_iwlb'])

g = sns.relplot(
    y="mll_diff", hue="config.hais.step_size", style="config.hais.num_steps", x="config.hais.num_chains",
    markers=True,
    data=plot_df
)
plt.show()

# %%
plot_df.sort_values(by='mll_diff', ascending=True).query('mll_diff > 0').head(10)
# Out:
#      config.hais.num_chains  config.hais.num_steps  config.hais.step_size  \
# 104                   300.0                  100.0                  0.005
# 89                    100.0                   30.0                  0.005
# 123                   300.0                   30.0                  0.010
# 87                    100.0                   10.0                  0.010
# 110                   300.0                   30.0                  0.010
# 83                    100.0                  100.0                  0.020
# 113                   300.0                   30.0                  0.005
# 115                   300.0                   10.0                  0.010
# 85                    100.0                   30.0                  0.020
# 107                   300.0                  100.0                  0.020
#
#      summary.hais_mll  summary.best_val_elbo  summary.best_val_iwlb  \
# 104       1732.626831             871.394043             898.562256
# 89        1855.034058             875.555420             902.360718
# 123       2545.593018             836.259644             861.890869
# 87        2679.466064             873.302429             900.583923
# 110       2783.929443             860.927368             887.964966
# 83        5073.360840             868.733826             894.065063
# 113       6281.479004             852.772461             879.861633
# 115       7938.270996             852.355469             878.957336
# 85        9362.480469             884.729431             910.332825
# 107      10101.750000             854.106812             880.325745
#
#         mll_diff
# 104   834.064575
# 89    952.673340
# 123  1683.702148
# 87   1778.882141
# 110  1895.964478
# 83   4179.295776
# 113  5401.617371
# 115  7059.313660
# 85   8452.147644
# 107  9221.424255

# %%
tags_to_keep = ['seeds']
plot_df = df_filtered[df_filtered['tags'].apply(lambda x: any(tag in x for tag in tags_to_keep))]

plot_df = plot_df[
    ['config.hais.num_chains', 'config.hais.num_steps', 'config.hais.step_size',
     'summary.hais_mll', 'summary.best_val_elbo', 'summary.best_val_iwlb', 'config.seed']
]

plot_df['mll_diff'] = (plot_df['summary.hais_mll'] - plot_df['summary.best_val_iwlb'])

plot_df = plot_df.groupby(['config.hais.num_chains', 'config.hais.num_steps', 'config.hais.step_size']).mean().reset_index()

g = sns.relplot(
    y="mll_diff", hue="config.hais.step_size", style="config.hais.num_steps", x="config.hais.num_chains",
    markers=True,
    data=plot_df
)
plt.show()

# %%
plot_df.sort_values(by='mll_diff', ascending=True).query('mll_diff > 0').head(10)
# Out:
#     config.hais.num_chains  config.hais.num_steps  config.hais.step_size  \
# 25                   300.0                  100.0                  0.008
# 14                   200.0                   60.0                  0.010
# 23                   300.0                   60.0                  0.010
# 0                    100.0                   30.0                  0.005
# 22                   300.0                   60.0                  0.008
# 24                   300.0                  100.0                  0.005
# 12                   200.0                   60.0                  0.005
# 11                   200.0                   30.0                  0.010
# 20                   300.0                   30.0                  0.010
# 19                   300.0                   30.0                  0.008
#
#     summary.hais_mll  summary.best_val_elbo  summary.best_val_iwlb  \
# 25        914.229045             865.301737             892.382304
# 14        927.141335             863.710571             890.365051
# 23       1345.718709             864.739705             891.804952
# 0        1473.275594             878.048828             905.228271
# 22       1651.354940             854.977763             882.220235
# 24       1743.727905             852.982198             880.198975
# 12       2225.443481             832.759277             858.716654
# 11       2578.823039             858.670654             884.997965
# 20       2670.877848             860.786438             887.876383
# 19       3084.280111             858.203308             885.038188
#
#     config.seed     mll_diff
# 25          1.0    21.846741
# 14          1.0    36.776283
# 23          1.0   453.913757
# 0           1.0   568.047323
# 22          1.0   769.134705
# 24          1.0   863.528931
# 12          1.0  1366.726827
# 11          1.0  1693.825073
# 20          1.0  1783.001465
# 19          1.0  2199.241923

# %%
tags_to_keep = ['seeds']
plot_df = df_filtered[df_filtered['tags'].apply(lambda x: any(tag in x for tag in tags_to_keep))]

plot_df = plot_df[
    ['config.hais.num_chains', 'config.hais.num_steps', 'config.hais.step_size',
     'summary.hais_mll', 'summary.best_val_elbo', 'summary.best_val_iwlb', 'config.seed']
]

plot_df['abs_mll_diff'] = (plot_df['summary.hais_mll'] - plot_df['summary.best_val_iwlb']).abs()

plot_df[(plot_df['config.hais.num_chains'] == 300) & (plot_df['config.hais.num_steps'] == 100) & (plot_df['config.hais.step_size'] == 0.008)]
# Out:
#     config.hais.num_chains  config.hais.num_steps  config.hais.step_size  \
# 55                   300.0                  100.0                  0.008
# 70                   300.0                  100.0                  0.008
# 74                   300.0                  100.0                  0.008
#
#     summary.hais_mll  summary.best_val_elbo  summary.best_val_iwlb  \
# 55        881.726929             849.624512             873.842224
# 70        970.804260             870.915039             897.919067
# 74        890.155945             875.365662             905.385620
#
#     config.seed  abs_mll_diff
# 55            2      7.884705
# 70            0     72.885193
# 74            1     15.229675
